# %% [markdown]
# # MLB data analysis
# > Final project
#
# - toc: true
# - branch: master
# - badges: true
# - comments: true
# - categories: [fastpages, jupyter]
# - image: images/some_folder/your_image.png
# - hide: false
# - search_exclude: true
# - metadata_key1: metadata_value1
# - metadata_key2: metadata_value2
# - author: Chen Wang

# %% [markdown]
# # Author information:
# ## Name: Chen Wang
# ## Date: 2022/03/13
# ## Project title: Does the crackdown in 2021 impact all the pitchers?

# %% [markdown]
# # Introduction:

# %% [markdown]
# ## What is the research topic from?

# %% [markdown]
# In 2021 in MLB, a new foreign-substance crackdown begins: pitchers will be ejected and suspended for using illegal foreign substances to doctor baseballs as Major League Baseball ramps up its enforcement of an area that has been the talk of baseball in recent weeks. It pushed analysts to do data analysis and predicted which players used substances before.

# %% [markdown]
# In this regard, analysts found that spin rate drop will be easily detected at the watershed: Normally, if pitcher who causally used substances (such as pine tar) before this year will subsequently has an obvious drop. Hence, the quality of pitching decreased affected the pitcher's stableness in the game.

# %% [markdown]
# **Pitchers consider that pine tar can help them increase their pitching quality.**
# ![pine-tar](MLB_data/Pine_tar.png)

# %% [markdown]
# ## Get information from news

# %% [markdown]
# I tried to use **BeautifulSoup** to introduce a piece of news that discussed a pitcher who was famous for its victims after the crackdown.

# %%
#collapse-output
from bs4 import BeautifulSoup
from urllib.request import urlopen
response= urlopen('https://boston.cbslocal.com/2021/06/24/garrett-richards-spin-rates-drop-drastically-adapt-to-mlb-crackdown-substances/')
soup = BeautifulSoup(response, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam-cell.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"103fa8ca15",applicationID:"144794115"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(){}function i(t,e,n,r){return function(){return s.recordSupportability("API/"+e+"/called"),o(t+e,[u.now()].concat(c(arguments)),n?null:this,r),n?void 0:this}}var o=t("handle"),a=t(10),c=t(11),f=t("ee").get("tracer"),u=t("loader"),s=t(4),d=NREUM;"undefined"==typeof window.newrelic&&(newrelic=d);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],l="api-",v=l+"ixn-";a(p,function(t,e){d[e]=i(l,e,!0,"api")}),d.addPageAction=i(l,"addPageAction",!0),d.setCurrentRouteName=i(l,"routeName",!0),e.exports=newrelic,d.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(t,e){var n={},r=this,i="function"==typeof e;return o(v+"tracer",[u.now(),t,n],r),function(){if(f.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return e.apply(this,arguments)}catch(t){throw f.emit("fn-err",[arguments,this,t],n),t}finally{f.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(t,e){m[e]=i(v,e)}),newrelic.noticeError=function(t,e){"string"==typeof t&&(t=new Error(t)),s.recordSupportability("API/noticeError/called"),o("err",[t,u.now(),!1,e])}},{}],2:[function(t,e,n){function r(t){if(NREUM.init){for(var e=NREUM.init,n=t.split("."),r=0;r<n.length-1;r++)if(e=e[n[r]],"object"!=typeof e)return;return e=e[n[n.length-1]]}}e.exports={getConfiguration:r}},{}],3:[function(t,e,n){var r=!1;try{var i=Object.defineProperty({},"passive",{get:function(){r=!0}});window.addEventListener("testPassive",null,i),window.removeEventListener("testPassive",null,i)}catch(o){}e.exports=function(t){return r?{passive:!0,capture:!!t}:!!t}},{}],4:[function(t,e,n){function r(t,e){var n=[a,t,{name:t},e];return o("storeMetric",n,null,"api"),n}function i(t,e){var n=[c,t,{name:t},e];return o("storeEventMetrics",n,null,"api"),n}var o=t("handle"),a="sm",c="cm";e.exports={constants:{SUPPORTABILITY_METRIC:a,CUSTOM_METRIC:c},recordSupportability:r,recordCustom:i}},{}],5:[function(t,e,n){function r(){return c.exists&&performance.now?Math.round(performance.now()):(o=Math.max((new Date).getTime(),o))-a}function i(){return o}var o=(new Date).getTime(),a=o,c=t(12);e.exports=r,e.exports.offset=a,e.exports.getLastTimestamp=i},{}],6:[function(t,e,n){function r(t){return!(!t||!t.protocol||"file:"===t.protocol)}e.exports=r},{}],7:[function(t,e,n){function r(t,e){var n=t.getEntries();n.forEach(function(t){"first-paint"===t.name?l("timing",["fp",Math.floor(t.startTime)]):"first-contentful-paint"===t.name&&l("timing",["fcp",Math.floor(t.startTime)])})}function i(t,e){var n=t.getEntries();if(n.length>0){var r=n[n.length-1];if(u&&u<r.startTime)return;var i=[r],o=a({});o&&i.push(o),l("lcp",i)}}function o(t){t.getEntries().forEach(function(t){t.hadRecentInput||l("cls",[t])})}function a(t){var e=navigator.connection||navigator.mozConnection||navigator.webkitConnection;if(e)return e.type&&(t["net-type"]=e.type),e.effectiveType&&(t["net-etype"]=e.effectiveType),e.rtt&&(t["net-rtt"]=e.rtt),e.downlink&&(t["net-dlink"]=e.downlink),t}function c(t){if(t instanceof y&&!w){var e=Math.round(t.timeStamp),n={type:t.type};a(n),e<=v.now()?n.fid=v.now()-e:e>v.offset&&e<=Date.now()?(e-=v.offset,n.fid=v.now()-e):e=v.now(),w=!0,l("timing",["fi",e,n])}}function f(t){"hidden"===t&&(u=v.now(),l("pageHide",[u]))}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var u,s,d,p,l=t("handle"),v=t(" ...
#   </script>
#   <link href="https://boston.cbslocal.com/xmlrpc.php" rel="pingback"/>
#   <!-- WP Header - Start -->
#   <meta content="mlb, spin rates, drop, bauer, cole, garrett richards, red sox, rays," name="news_keywords"/>
#   <meta content="mlb, spin rates, drop, bauer, cole, garrett richards, red sox, rays, alex cora, boston red sox, garrett richards, michael hurley, mlb, sports news, sticky stuff mlb, red sox, sports" name="keywords"/>
#   <meta content="7446277009" property="fb:pages"/>
#   <meta content="44caXBf4kjHeKKAT7ZZ89NaCX25utL_yRSa-qGpwIhY" name="google-site-verification"/>
#   <title>
#    Garrett Richards’ Spin Rates Drop Drastically As Righty Struggles To Adapt To MLB’s Crackdown On Substances – CBS Boston
#   </title>
#   <meta content="max-image-preview:large" name="robots"/>
#   <!-- Jetpack Site Verification Tags -->
#   <meta content="44caXBf4kjHeKKAT7ZZ89NaCX25utL_yRSa-qGpwIhY" name="google-site-verification"/>
#   <meta content="FDD12CE797EAB78953FDE9ACF7F312A5" name="msvalidate.01"/>
#   <link href="//cdn.cookielaw.org" rel="dns-prefetch"/>
#   <script charset="UTF-8" data-domain-script="7547764e-53b9-4fff-aef7-ce9cb429c721" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript">
#   </script>
#   <link href="//production-cmp.isgprivacy.cbsi.com" rel="dns-prefetch"/>
#   <script charset="UTF-8" src="https://production-cmp.isgprivacy.cbsi.com/dist/optanon-v1.1.0.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    !function(n){var o=window,a="cbsoptanon",c="cmd",d="config";o[a]=o[a]?o[a]:{},o[a][c]=o[a][c]?o[a][c]:[],o[a][d]=o[a][d]?o[a][d]:[],["onScriptsReady","onAdsReady"].forEach(function(n){o[a][n]=o[a][n]||function(){var d=arguments;o[a][c].push(function(){o[a][n].apply(o[a],d)})}})}();
#   </script>
#   <link href="//w3.mp.lura.live" rel="dns-prefetch"/>
#   <link href="//maxcdn.bootstrapcdn.com" rel="dns-prefetch"/>
#   <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
#   <link href="//wayne.cbslocal.com" rel="dns-prefetch"/>
#   <link href="//s.w.org" rel="dns-prefetch"/>
#   <link href="//v0.wordpress.com" rel="dns-prefetch"/>
#   <link href="//jetpack.wordpress.com" rel="dns-prefetch"/>
#   <link href="//s0.wp.com" rel="dns-prefetch"/>
#   <link href="//public-api.wordpress.com" rel="dns-prefetch"/>
#   <link href="//0.gravatar.com" rel="dns-prefetch"/>
#   <link href="//1.gravatar.com" rel="dns-prefetch"/>
#   <link href="//2.gravatar.com" rel="dns-prefetch"/>
#   <link href="https://boston.cbslocal.com/feed/" rel="alternate" title="CBS Boston » Feed" type="application/rss+xml"/>
#   <link href="https://boston.cbslocal.com/_static/??-eJytUEkOwjAM/BDBULEeEG9xElOiOk6URf0+oeXSE1TiZHvsGc0YxqhMkEJSoDzJUwajs+JgkMGJ4WrfUM7wCKFQ2rZ2Az+RyGuyMzcm4oD2Ozly7Z1k8MFWbhudCAcnvRIaZ6kFsl4QP45aXU+eDpRHwZ7SJLNAVEs9lBBX/GjWqF4LOlbsZPi/K+I2SZny3v1tfzqcu8uxu+5ejOa+Gw==" id="all-css-0" media="all" rel="stylesheet" type="text/css"/>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css?ver=4.7.0" id="cbs-font-awesome-css" media="all" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="https://fonts.googleapis.com/css?family=Lato%3A300%2C400%2C700%2C900&amp;ver=1.0.0" id="cbs-lato-font-css" media="all" rel="stylesheet"/>
#   <link href="https://boston.cbslocal.com/_static/??-eJyNy0kKgDAMQNELWaPFcSGepcagQjpAIuLttRcQt5/34UoGY1AKCrqTJwFcxHBExyB6M5UoUsAXOwLyueYkAsltZJR8Yqc/3rwQvzGoZD37qe6a3g6tHasHIeg5IA==" id="all-css-4" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://wayne.cbslocal.com/cbs-local-custom-css/global/cbslocal_custom_global.css?ver=1.0.0" id="cbs-custom-css-css" media="all" rel="stylesheet"/>
#   <link href="https://boston.cbslocal.com/_static/??-..." id="all-css-6" media="all" rel="stylesheet" type="text/css"/>
#   <style id="wp-block-library-inline-css">
#    .has-text-align-justify{text-align:justify;}
#   </style>
#   <script src="https://boston.cbslocal.com/_static/??-eJy1UMsOwjAM+yG6wMTzgPiW0nWjJU3LkoL295SJA7sNJE5WHNuxAo+kTCSxJCAXGyyDObPCaDSCI4O5KZRnSBGH1iFWwVHleQFzjX6WI2HuHDGE2GQsG92M5gLqXn8mTKJv2fbDG2aJVHBdr8X+1GkUqKBJd7Z/RU8IVe5dJaavntNmMuIi8T8KWSwTCZfcUziututdvd/Uh6V/ArEBuj4=" type="text/javascript">
#   </script>
#   <script id="partner__video__anvato-js" src="https://w3.mp.lura.live/player/prod/v3/scripts/anvload.js?ver=5.8.4">
#   </script>
#   <script src="https://boston.cbslocal.com/_static/??-eJyFjc0OwjAMg1+ILTDxe0A8S5dGXaq0nUjKXn/VxIULu1n2ZxuWucOSjbKBTZRIAUftpKAT4IxSfbOigvMTKX+oT5z7qAf4V2x8kDI62SV/Lt7GKLTbmaUGzgqp+CotWdgHsm3iK9vEKz1P1/NtuF+GxzGuCuNU1g==" type="text/javascript">
#   </script>
#   <link href="https://boston.cbslocal.com/wp-json/" rel="https://api.w.org/"/>
#   <link href="https://boston.cbslocal.com/wp-json/wp/v2/posts/1142143" rel="alternate" type="application/json"/>
#   <link href="https://boston.cbslocal.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
#   <link href="https://boston.cbslocal.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
#   <meta content="WordPress 5.8.4" name="generator"/>
#   <link href="https://cbsloc.al/3xN69Up" rel="shortlink"/>
#   <link href="https://boston.cbslocal.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fboston.cbslocal.com%2F2021%2F06%2F24%2Fgarrett-richards-spin-rates-drop-drastically-adapt-to-mlb-crackdown-substances%2F" rel="alternate" type="application/json+oembed"/>
#   <link href="https://boston.cbslocal.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fboston.cbslocal.com%2F2021%2F06%2F24%2Fgarrett-richards-spin-rates-drop-drastically-adapt-to-mlb-crackdown-substances%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
#   <style type="text/css">
#    img#wpstats{display:none}
#   </style>
#   <meta content="Garrett Richards' Spin Rates Drop Drastically As Righty Struggles To Adapt To MLB's Crackdown On Substances" property="og:title"/>
#   <meta content="https://boston.cbslocal.com/wp-content/uploads/sites/3859903/2021/06/GettyImages-1325135584.jpg?w=1500" property="og:image"/>
#   <meta content="https://boston.cbslocal.com/wp-content/uploads/sites/3859903/2021/06/GettyImages-1325135584.jpg?w=1500" property="og:image:secure_url"/>
#   <meta content="1500" property="og:image:width"/>
#   <meta content="844" property="og:image:height"/>
#   <meta content="Garrett Richards' season has taken a turn for the worse, and his start in Tampa was its lowest point." property="og:description"/>
#   <meta content="article" property="og:type"/>
#   <meta content="https://boston.cbslocal.com/2021/06/24/garrett-richards-spin-rates-drop-drastically-adapt-to-mlb-crackdown-substances/" property="og:url"/>
#   <meta content="2021-06-24T09:49:40+00:00" property="article:published_time"/>
#   <meta content="Garrett Richards' season has taken a turn for the worse, and his start in Tampa was its lowest point." property="article:suggested-social-copy"/>
#   <meta content="false" property="article:opinion"/>
#   <meta content="free" property="article:content_tier"/>
#   <meta content="MLB,Red Sox,Sports" property="og:category"/>
#   <meta content="http://www.facebook.com/CBSBoston" property="article:publisher"/>
#   <meta content="http://www.facebook.com/CBSBoston" property="article:author"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="https://boston.cbslocal.com/wp-content/uploads/sites/3859903/2021/06/GettyImages-1325135584.jpg?w=1500" name="twitter:image"/>
#   <meta content="Garrett Richards' Spin Rates Drop Drastically As Righty Struggles To Adapt To MLB's Crackdown On Substances" name="twitter:title">
#    <meta content="Garrett Richards' season has taken a turn for the worse, and his start in Tampa was its lowest point." name="twitter:description"/>
#    <meta content="/wbz" name="twitter:site"/>
#    <link href="https://boston.cbslocal.com/2021/06/24/garrett-richards-spin-rates-drop-drastically-adapt-to-mlb-crackdown-substances/" rel="canonical"/>
#    <style>
#     .main-story-wrapper .basicsection { margin-bottom: 20px; }
# 					.main-story-wrapper .basicsection span strong { display: block; font-size: 18px; margin: 0 auto 15px; }
# 					.main-story-wrapper .basicsection img { float: none !important; margin: 0 auto 15px; }
# 					.main-story-wrapper .basicsection br { margin-bottom: 5px; }
#    </style>
#    <style type="text/css">
#     /* If html does not have either class, do not show lazy loaded images. */
# 				html:not( .jetpack-lazy-images-js-enabled ):not( .js ) .jetpack-lazy-image {
# 					display: none;
# 				}
#    </style>
#    <script>
#     document.documentElement.classList.add(
# 					'jetpack-lazy-images-js-enabled'
# 				);
#    </script>
#    <link href="https://boston.cbslocal.com/2021/06/24/garrett-richards-spin-rates-drop-drastically-adapt-to-mlb-crackdown-substances/?amp" rel="amphtml"/>
#    <script type="application/ld+json">
#     {"@context":"http:\/\/schema.org","@type":"NewsArticle","publisher":{"@context":"http:\/\/schema.org","@type":"NewsMediaOrganization","@id":"https:\/\/boston.cbslocal.com","url":"https:\/\/boston.cbslocal.com","name":"CBS Boston","foundingDate":"1941-07-01T14:30:00+00:00","logo":{"@type":"ImageObject","url":"https:\/\/boston.cbslocal.com\/wp-content\/uploads\/sites\/3859903\/2018\/02\/4_boston_wbz.png?w=220"}},"url":"https:\/\/boston.cbslocal.com\/2021\/06\/24\/garrett-richards-spin-rates-drop-drastically-adapt-to-mlb-crackdown-substances\/","mainEntityOfPage":{"@type":"WebPage","@id":"https:\/\/boston.cbslocal.com\/2021\/06\/24\/garrett-richards-spin-rates-drop-drastically-adapt-to-mlb-crackdown-substances\/"},"headline":"Garrett Richards&#8217; Spin Rates Drop Drastically As Righty Struggles To Adapt To MLB&#8217;s Crackdown On Substances","description":"Garrett Richards' season has taken a turn for the worse, and his start in Tampa was its lowest point.","image":"https:\/\/boston.cbslocal.com\/wp-content\/uploads\/sites\/3859903\/2021\/06\/GettyImages-1325135584.jpg?w=1500","keywords":["MLB","Red Sox","Sports","Alex Cora","Boston Red Sox","Garrett Richards","Michael Hurley","Sports News","Sticky Stuff","sports","Garrett Richards' Spin Rates Drop Drastically As Righty Struggles To Adapt To MLB's Crackdown On Substances"],"datePublished":"2021-06-24T09:49:40+00:00","dateModified":"2021-06-24T09:49:40+00:00","author":{"@type":"Organization","name":"CBS Boston"}}
#    </script>
#    <script>
#     cbs_lib.load_script("//launch.newsinc.com/js/embed.js");
#    </script>
#    <script type="text/javascript">
#     cbs_ads.partners.add("amazon", "3063");if(!window["apstag"]){window["apstag"]={init:function(){window["apstag"]._Q.push(["i",arguments]);},fetchBids:function(){window["apstag"]._Q.push(["f",arguments]);},setDisplayBids:function(){},_Q:[]};}
#    </script>
#    <script type="text/javascript">
#     cbs_ads.partners.add("sharethrough", true);
#    </script>
#    <script>
#     cbs_ads.init("4128","CBS.BOSTON","sports",["garrettrichardsspinratesdropdrasticallyasrightystrugglestoadapttomlbscrackdownonsubstances","post","article","mlb","redsox","sports","alexcora","bostonredsox","garrettrichards","michaelhurley","sportsnews","stickystuff","featuredvideo"],{"page_type":"article"});cbs_ads.refresh.set_timer("3");
#    </script>
#    <link href="//www.googletagmanager.com" rel="dns-prefetch">
#     <script async="" class="optanon-category-4" src="https://www.googletagmanager.com/gtag/js?id=UA-2438645-63" type="text/plain">
#     </script>
#     <noscript>
#      <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=UA-2438645-63" style="display:none;visibility:hidden" width="0">
#      </iframe>
#     </noscript>
#     <script class="optanon-category-4" type="text/plain">
#      window.dataLayer=window.dataLayer || [];function gtag(){dataLayer.push(arguments);}gtag("js",new Date());gtag("set",{"dimension1":"mlb;red-sox;sports;","dimension2":"article"});gtag("config","UA-2438645-63");
#     </script>
#     <link href="https://boston.cbslocal.com/wp-content/uploads/sites/3859903/2019/07/cropped-boston-favicon-5121.png?w=32" rel="icon" sizes="32x32"/>
#     <link href="https://boston.cbslocal.com/wp-content/uploads/sites/3859903/2019/07/cropped-boston-favicon-5121.png?w=192" rel="icon" sizes="192x192"/>
#     <link href="https://boston.cbslocal.com/wp-content/uploads/sites/3859903/2019/07/cropped-boston-favicon-5121.png?w=180" rel="apple-touch-icon"/>
#     <meta content="https://boston.cbslocal.com/wp-content/uploads/sites/3859903/2019/07/cropped-boston-favicon-5121.png?w=270" name="msapplication-TileImage"/>
#     <style id="wp-custom-css" type="text/css">
#      .single-post sup {
# 	vertical-align: super;
# 	font-size: 10px;
# }
#     </style>
#     <!-- Your Google Analytics Plugin is missing the tracking ID -->
#     <!-- WP Header - End -->
#     <meta content="Garrett Richards' season has taken a turn for the worse, and his start in Tampa was its lowest point." name="description"/>
#     <script>
#      //<![CDATA[
# 		window['_cmpWrapper'] = {
# 			loaded: function(callback) { cbsoptanon.cmd.push(function(cmp) { cmp.ot.getState(callback); }); },
# 			getConsentFlag: function(callback) {
# 				window._cmpWrapper.loaded(function(tar, per, fun, soc) {
# 					var consent = 0; var consentState = [ per, fun, tar, soc, false ];
# 					for (var i = 0; i < consentState.length; i++) { if (consentState[i]) { var mask = 1 << i; consent |= mask; } }
# 					callback(consent);
# 				});
# 			}
# 		}
# 		//]]>
#     </script>
#    </link>
#   </meta>
#  </head>
#  <body class="post-template-default single single-post postid-1142143 single-format-standard desktop-display-type and-temp-wide w-breaking-news">
#   <div class="body-wrapper" id="wrapper">
#    <div id="breaking-news">
#     <div class="wrapper">
#      <a class="cbs-thumbnail-link" href="https://bostonbracketchallenge.cbslocal.com/#/registration/login" title="BRACKET CHALLENGE:">
#       <div class="title-wrapper">
#        <strong class="title">
#         BRACKET CHALLENGE:
#        </strong>
#        <em class="description">
#         Enter Your Bracket To Win Up To $1,000
#        </em>
#       </div>
#      </a>
#     </div>
#    </div>
#    <div class="cbs-ad-unit ad_gpt cbs-ad-skin" data-ad_location="skin" id="reptile_skin_1">
#     <script>
#      cbs_load_skin_by_tile(1);
#     </script>
#    </div>
#    <header class="" id="page-header">
#     <div class="wrapper">
#      <a href="https://boston.cbslocal.com" id="header-logo">
#       <img alt="CBS Boston" src="https://boston.cbslocal.com/wp-content/uploads/sites/3859903/2018/02/4_boston_wbz.png?w=220"/>
#      </a>
#      <nav data-item-count="7" id="navigation-main">
#       <ul class="top">
#        <li class="menu-top-item item-0 section-item w-submenu">
#         <div class="cbs-thumbnail-link wo-hover">
#          <div class="title-wrapper">
#           <strong class="title">
#            Menu
#           </strong>
#          </div>
#         </div>
#         <div class="submenu">
#          <div class="wrapper">
#           <div class="embed-item embed-list column-count-2 block-type-wpmenu" id="embed-list-1">
#            <div class="wrapper">
#             <header class="partblock__title block-head-wrapper">
#              <h4 class="title">
#               <a href="https://boston.cbslocal.com/category/sports/">
#                Sports
#               </a>
#              </h4>
#             </header>
#             <div class="block-content-wrapper and-list layout-grid and-columns-3 aspect-ratio-16-9">
#              <a class="cbs-thumbnail-link item-0" href="https://boston.cbslocal.com/category/sports/patriots/" title="Patriots">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Patriots
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-1" href="https://boston.cbslocal.com/category/sports/red-sox/" title="Red Sox">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Red Sox
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-2" href="https://boston.cbslocal.com/category/sports/bruins/" title="Bruins">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Bruins
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-3" href="https://boston.cbslocal.com/category/sports/celtics/" title="Celtics">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Celtics
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-4" href="https://boston.cbslocal.com/category/sports/revolution/" title="Revolution">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Revolution
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-5" href="https://boston.cbslocal.com/live-streaming-video-from-cbs-sports/" title="CBS Sports HQ Live">
#               <div class="title-wrapper">
#                <strong class="title">
#                 CBS Sports HQ Live
#                </strong>
#               </div>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="embed-item embed-list column-count-1 block-type-wpmenu" id="embed-list-2">
#            <div class="wrapper">
#             <header class="partblock__title block-head-wrapper">
#              <h4 class="title">
#               <a href="https://boston.cbslocal.com/video/">
#                Video
#               </a>
#              </h4>
#             </header>
#             <div class="block-content-wrapper and-list layout-grid and-columns-3 aspect-ratio-16-9">
#              <a class="cbs-thumbnail-link item-0" href="https://boston.cbslocal.com/live/" title="CBS News Boston">
#               <div class="title-wrapper">
#                <strong class="title">
#                 CBS News Boston
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-1" href="https://boston.cbslocal.com/live/cbsn/" title="CBS News National">
#               <div class="title-wrapper">
#                <strong class="title">
#                 CBS News National
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-2" href="https://boston.cbslocal.com/live/cbs-sports-hq/" title="CBS Sports HQ Live">
#               <div class="title-wrapper">
#                <strong class="title">
#                 CBS Sports HQ Live
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-3" href="https://boston.cbslocal.com/video/category/news/" title="All News Video">
#               <div class="title-wrapper">
#                <strong class="title">
#                 All News Video
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-4" href="https://boston.cbslocal.com/video/category/sports/" title="All Sports Video">
#               <div class="title-wrapper">
#                <strong class="title">
#                 All Sports Video
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-5" href="https://boston.cbslocal.com/video/category/news-weather-forecast/" title="Weather Forecast">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Weather Forecast
#                </strong>
#               </div>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="menu-top-item item-1 w-link w-submenu">
#         <a class="cbs-thumbnail-link wo-hover" href="https://boston.cbslocal.com/category/news/" title="News">
#          <div class="title-wrapper">
#           <strong class="title">
#            News
#           </strong>
#          </div>
#         </a>
#         <div class="submenu">
#          <div class="wrapper">
#           <div class="embed-item embed-list column-count-2 block-type-wpmenu" id="embed-list-3">
#            <div class="wrapper">
#             <header class="partblock__title block-head-wrapper">
#              <h4 class="title">
#               News Sections
#              </h4>
#             </header>
#             <div class="block-content-wrapper and-list layout-grid and-columns-3 aspect-ratio-16-9">
#              <a class="cbs-thumbnail-link item-0" href="https://boston.cbslocal.com/category/news/" title="All News">
#               <div class="title-wrapper">
#                <strong class="title">
#                 All News
#                </strong>
#                <em class="description">
#                 Local Boston News From WBZ Channel 4 CBS
#                </em>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-1" href="https://boston.cbslocal.com/category/news/local/" title="Local News">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Local News
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-2" href="https://boston.cbslocal.com/category/health/" title="HealthWatch">
#               <div class="title-wrapper">
#                <strong class="title">
#                 HealthWatch
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-3" href="https://boston.cbslocal.com/category/politics/" title="Politics">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Politics
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-4" href="https://boston.cbslocal.com/category/news/business/" title="Business">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Business
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-5" href="https://boston.cbslocal.com/category/news/education/" title="Education">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Education
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-6" href="https://boston.cbslocal.com/category/news/consumer/" title="Consumer">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Consumer
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-7" href="https://boston.cbslocal.com/category/news/entertainment/" title="Entertainment">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Entertainment
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-8" href="https://boston.cbslocal.com/category/only-cbs/" title="CBS+">
#               <div class="title-wrapper">
#                <strong class="title">
#                 CBS+
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-9" href="https://boston.cbslocal.com/tag/boston-news/" title="Boston News">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Boston News
#                </strong>
#               </div>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="embed-item embed-list column-count-1 block-type-wpmenu" id="embed-list-4">
#            <div class="wrapper">
#             <header class="partblock__title block-head-wrapper">
#              <h4 class="title">
#               Exclusively WBZ
#              </h4>
#             </header>
#             <div class="block-content-wrapper and-list layout-grid and-columns-3 aspect-ratio-16-9">
#              <a class="cbs-thumbnail-link item-0" href="https://boston.cbslocal.com/category/i-team/" title="I-Team">
#               <div class="title-wrapper">
#                <strong class="title">
#                 I-Team
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-1" href="https://boston.cbslocal.com/category/wednesdays-child/" title="Wednesday's Child">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Wednesday's Child
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-2" href="https://boston.cbslocal.com/tag/it-happens-here/" title="It Happens Here">
#               <div class="title-wrapper">
#                <strong class="title">
#                 It Happens Here
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-3" href="https://boston.cbslocal.com/tag/boston-next/" title="Boston Next">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Boston Next
#                </strong>
#               </div>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="embed-item embed-list enable-type-icons column-count-3 block-type-grid" id="embed-list-5">
#            <div class="wrapper">
#             <header class="partblock__title block-head-wrapper">
#              <h4 class="title">
#               Latest Headlines
#              </h4>
#             </header>
#             <div class="block-content-wrapper and-list layout-grid and-columns-3 aspect-ratio-16-9">
#              <a class="cbs-thumbnail-link item-1647486854 content-type-video" href="https://boston.cbslocal.com/2022/03/16/boston-woman-helping-romania-ukrainian-refugees/" title="'It Feels Personal': Boston Woman Traveling To Romania To Help Ukrainian Refugees">
#               <div class="thumbnail-wrapper">
#                <span class="balance">
#                 <img data-src="https://boston.cbslocal.com/wp-content/uploads/sites/3859903/2022/03/Ema-David.jpg?w=640&amp;h=360&amp;crop=1" src="https://boston.cbslocal.com/wp-content/themes/cbs-local/images/global/blank_1x1.gif"/>
#                </span>
#               </div>
#               <div class="title-wrapper">
#                <strong class="title">
#                 'It Feels Personal': Boston Woman Traveling To Romania To Help Ukrainian Refugees
#                </strong>
#                <em class="description">
#                 A Boston accountant will complete tax season remotely, spending her free time supporting Ukrainian refugees in Romania.
#                </em>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-1647486696 content-type-video" href="https://boston.cbslocal.com/2022/03/16/economists-say-fed-interest-rate-hike-is-right-move-for-inflation/" title="Economists Say Fed Interest Rate Hike Is Right Move For Inflation">
#               <div class="thumbnail-wrapper">
#                <span class="balance">
#                 <img data-src="https://boston.cbslocal.com/wp-content/uploads/sites/3859903/2022/03/fedreserve.jpg?w=640&amp;h=360&amp;crop=1" src="https://boston.cbslocal.com/wp-content/themes/cbs-local/images/global/blank_1x1.gif"/>
#                </span>
#               </div>
#               <div class="title-wrapper">
#                <strong class="title">
#                 Economists Say Fed Interest Rate Hike Is Right Move For Inflation
#                </strong>
#                <em class="description">
#                 The goal is to curb spending and start to slow the economy, which has seen the highest inflation in 40 years.
#                </em>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-1647485135 content-type-video" href="https://boston.cbslocal.com/2022/03/16/boston-plans-to-replace-historic-gas-lamps-with-energy-saving-led-lights/" title="Boston Plans To Replace Historic Gas Lamps With Energy-Saving LED Lights">
#               <div class="thumbnail-wrapper">
#                <span class="balance">
#                 <img data-src="https://boston.cbslocal.com/wp-content/uploads/sites/3859903/2022/03/lamps-1.jpg?w=640&amp;h=360&amp;crop=1" src="https://boston.cbslocal.com/wp-content/themes/cbs-local/images/global/blank_1x1.gif"/>
#                </span>
#               </div>
#               <div class="title-wrapper">
#                <strong class="title">
#                 Boston Plans To Replace Historic Gas Lamps With Energy-Saving LED Lights
#                </strong>
#                <em class="description">
#                 Boston plans to replace the city's gas lamps with new LED lights.
#                </em>
#               </div>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="menu-top-item item-2 w-link w-submenu">
#         <a class="cbs-thumbnail-link wo-hover" href="https://boston.cbslocal.com/category/weather/" title="Weather">
#          <div class="title-wrapper">
#           <strong class="title">
#            Weather
#           </strong>
#          </div>
#         </a>
#         <div class="submenu">
#          <div class="wrapper">
#           <div class="embed-item embed-list column-count-1 block-type-wpmenu" id="embed-list-6">
#            <div class="wrapper">
#             <header class="partblock__title block-head-wrapper">
#              <h4 class="title">
#               Weather Links
#              </h4>
#             </header>
#             <div class="block-content-wrapper and-list layout-grid and-columns-3 aspect-ratio-16-9">
#              <a class="cbs-thumbnail-link item-0" href="https://boston.cbslocal.com/closings/" title="School Closings">
#               <div class="title-wrapper">
#                <strong class="title">
#                 School Closings
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-1" href="https://boston.cbslocal.com/category/weather/#section-weather-map-3" title="Interactive Radar">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Interactive Radar
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-2" href="https://boston.cbslocal.com/category/beyond-the-forecast/" title="Weather Blog">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Weather Blog
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-3" href="http://apps.cbslocal.com/weather/boston/" title="Weather App">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Weather App
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-4" href="https://boston.cbslocal.com/category/virtual-school-visits/" title="School Visits">
#               <div class="title-wrapper">
#                <strong class="title">
#                 School Visits
#                </strong>
#               </div>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="embed-item embed-list enable-type-icons column-count-2 block-type-grid" id="embed-list-7">
#            <div class="wrapper">
#             <header class="partblock__title block-head-wrapper">
#              <h4 class="title">
#               Video Forecast
#              </h4>
#             </header>
#             <div class="block-content-wrapper and-list layout-grid and-columns-3 aspect-ratio-16-9">
#              <a class="cbs-thumbnail-link item-1647487380 content-type-video" href="https://boston.cbslocal.com/video/6213516-wbz-forecast/" title="WBZ Forecast">
#               <div class="thumbnail-wrapper">
#                <span class="balance">
#                 <img data-src="https://m101675-ucdn.mp.lura.live/anv-iupl/ABA/251/ABA2514BC11A7842BE9E96C148B98786.jpg?Expires=1742083200&amp;KeyName=mcpkey1&amp;Signature=_y_zRww-ZFBgMdjg58A-wZNeM04" src="https://boston.cbslocal.com/wp-content/themes/cbs-local/images/global/blank_1x1.gif"/>
#                </span>
#               </div>
#               <div class="title-wrapper">
#                <strong class="title">
#                 WBZ Forecast
#                </strong>
#                <em class="description">
#                 Jacob Wycoff has an updated weather forecast.
#                </em>
#               </div>
#               <time datetime="2022-03-17T03:23:00+00:00" title="March 16, 2022 at 11:23 pm">
#                3 hours ago
#               </time>
#              </a>
#              <a class="cbs-thumbnail-link item-1647469980 content-type-video" href="https://boston.cbslocal.com/video/6213390-wbz-evening-forecast-for-march-16-2022/" title="WBZ Evening Forecast For March 16, 2022">
#               <div class="thumbnail-wrapper">
#                <span class="balance">
#                 <img data-src="https://m101675-ucdn.mp.lura.live/anv-iupl/ECB/DAC/ECBDAC7AB6AADDB46BBBD5926872FD09.jpg?Expires=1742083200&amp;KeyName=mcpkey1&amp;Signature=CWgMIp26CeFErSWe24_W3nGWdG4" src="https://boston.cbslocal.com/wp-content/themes/cbs-local/images/global/blank_1x1.gif"/>
#                </span>
#               </div>
#               <div class="title-wrapper">
#                <strong class="title">
#                 WBZ Evening Forecast For March 16, 2022
#                </strong>
#                <em class="description">
#                 Jacob Wycoff has your latest weather forecast.
#                </em>
#               </div>
#               <time datetime="2022-03-16T22:33:00+00:00" title="March 16, 2022 at 6:33 pm">
#                8 hours ago
#               </time>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="embed-item embed-list enable-type-icons column-count-2 block-type-grid" id="embed-list-8">
#            <div class="wrapper">
#             <header class="partblock__title block-head-wrapper">
#              <h4 class="title">
#               Weather Blog
#              </h4>
#             </header>
#             <div class="block-content-wrapper and-list layout-grid and-columns-3 aspect-ratio-16-9">
#              <a class="cbs-thumbnail-link item-1647274504 content-type-video" href="https://boston.cbslocal.com/2022/03/14/boston-weather-forecast-march-snow-massachusetts-end-of-winter-wbz-tv/" title="End Of The Snow? Odds Are Against Any More Meaningful Storms This Season">
#               <div class="thumbnail-wrapper">
#                <span class="balance">
#                 <img data-src="https://boston.cbslocal.com/wp-content/uploads/sites/3859903/2022/03/lastsnowJPG.jpg?w=640&amp;h=360&amp;crop=1" src="https://boston.cbslocal.com/wp-content/themes/cbs-local/images/global/blank_1x1.gif"/>
#                </span>
#               </div>
#               <div class="title-wrapper">
#                <strong class="title">
#                 End Of The Snow? Odds Are Against Any More Meaningful Storms This Season
#                </strong>
#                <em class="description">
#                 There is a decent chance that we have seen the last of any meaningful snowfall this season.
#                </em>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-1647064763 content-type-video" href="https://boston.cbslocal.com/2022/03/12/boston-snow-forecast-storm-weather-this-weekend-bombogenesis-wind-advisory/" title="Icy Roads, Wind Advisory Slated For Sunday Morning Across Massachusetts">
#               <div class="thumbnail-wrapper">
#                <span class="balance">
#                 <img data-src="https://boston.cbslocal.com/wp-content/uploads/sites/3859903/2022/03/2020-Wind-Warnings-SNE.jpg?w=640&amp;h=360&amp;crop=1" src="https://boston.cbslocal.com/wp-content/themes/cbs-local/images/global/blank_1x1.gif"/>
#                </span>
#               </div>
#               <div class="title-wrapper">
#                <strong class="title">
#                 Icy Roads, Wind Advisory Slated For Sunday Morning Across Massachusetts
#                </strong>
#                <em class="description">
#                 Rain, snow, wind, cold, bombogenesis, just another weekend in New England.
#                </em>
#               </div>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="menu-top-item item-3 w-link w-submenu">
#         <a class="cbs-thumbnail-link wo-hover" href="https://boston.cbslocal.com/category/sports/" title="Sports">
#          <div class="title-wrapper">
#           <strong class="title">
#            Sports
#           </strong>
#          </div>
#         </a>
#         <div class="submenu">
#          <div class="wrapper">
#           <div class="embed-item embed-list column-count-1 block-type-wpmenu" id="embed-list-9">
#            <div class="wrapper">
#             <header class="partblock__title block-head-wrapper">
#              <h4 class="title">
#               <a href="https://boston.cbslocal.com/category/sports/">
#                All Sports
#               </a>
#              </h4>
#             </header>
#             <div class="block-content-wrapper and-list layout-grid and-columns-3 aspect-ratio-16-9">
#              <a class="cbs-thumbnail-link item-0" href="https://boston.cbslocal.com/category/sports/patriots/" title="Patriots">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Patriots
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-1" href="https://boston.cbslocal.com/category/sports/red-sox/" title="Red Sox">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Red Sox
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-2" href="https://boston.cbslocal.com/category/sports/bruins/" title="Bruins">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Bruins
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-3" href="https://boston.cbslocal.com/category/sports/celtics/" title="Celtics">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Celtics
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-4" href="https://boston.cbslocal.com/category/sports/revolution/" title="Revolution">
#               <div class="title-wrapper">
#                <strong class="title">
#                 Revolution
#                </strong>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-5" href="https://boston.cbslocal.com/live-streaming-video-from-cbs-sports/" title="CBS Sports HQ Live">
#               <div class="title-wrapper">
#                <strong class="title">
#                 CBS Sports HQ Live
#                </strong>
#               </div>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="embed-item embed-list enable-type-icons column-count-5 block-type-grid" id="embed-list-10">
#            <div class="wrapper">
#             <header class="partblock__title block-head-wrapper">
#              <h4 class="title">
#               Latest Headlines
#              </h4>
#             </header>
#             <div class="block-content-wrapper and-list layout-grid and-columns-3 aspect-ratio-16-9">
#              <a class="cbs-thumbnail-link item-1647487876 content-type-video" href="https://boston.cbslocal.com/2022/03/16/kaprizov-scores-twice-as-wild-beat-bruins-4-2/" title="Kaprizov Scores Twice As Wild Beat Bruins 4-2">
#               <div class="thumbnail-wrapper">
#                <span class="balance">
#                 <img data-src="https://boston.cbslocal.com/wp-content/uploads/sites/3859903/2022/03/bruins-3.jpg?w=640&amp;h=360&amp;crop=1" src="https://boston.cbslocal.com/wp-content/themes/cbs-local/images/global/blank_1x1.gif"/>
#                </span>
#               </div>
#               <div class="title-wrapper">
#                <strong class="title">
#                 Kaprizov Scores Twice As Wild Beat Bruins 4-2
#                </strong>
#                <em class="description">
#                 The Minnesota Wild held on for a 4-2 victory over the Boston Bruins on Wednesday night.
#                </em>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-1647466870 content-type-video" href="https://boston.cbslocal.com/2022/03/16/fullback-jakob-johnson-leaves-patriots-signs-with-raiders-in-free-agency/" title="Fullback Jakob Johnson Leaves Patriots, Signs With Raiders In Free Agency">
#               <div class="thumbnail-wrapper">
#                <span class="balance">
#                 <img data-src="https://boston.cbslocal.com/wp-content/uploads/sites/3859903/2022/03/GettyImages-1236668119.jpg?w=640&amp;h=360&amp;crop=1" src="https://boston.cbslocal.com/wp-content/themes/cbs-local/images/global/blank_1x1.gif"/>
#                </span>
#               </div>
#               <div class="title-wrapper">
#                <strong class="title">
#                 Fullback Jakob Johnson Leaves Patriots, Signs With Raiders In Free Agency
#                </strong>
#                <em class="description">
#                 The Patriots have lost another member of their offensive backfield to Josh McDaniels and the Las Vegas Raiders. This time, it's fullback Jakob Johnson.
#                </em>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-1647464710 content-type-video" href="https://boston.cbslocal.com/2022/03/16/scratch-tomas-hertl-off-list-bruins-potential-trade-deadline-acquisitions/" title="You Can Scratch Tomas Hertl Off List Of Bruins' Potential Trade Deadline Acquisitions">
#               <div class="thumbnail-wrapper">
#                <span class="balance">
#                 <img data-src="https://boston.cbslocal.com/wp-content/uploads/sites/3859903/2022/03/GettyImages-1239226090.jpg?w=640&amp;h=360&amp;crop=1" src="https://boston.cbslocal.com/wp-content/themes/cbs-local/images/global/blank_1x1.gif"/>
#                </span>
#               </div>
#               <div class="title-wrapper">
#                <strong class="title">
#                 You Can Scratch Tomas Hertl Off List Of Bruins' Potential Trade Deadline Acquisitions
#                </strong>
#                <em class="description">
#                 For several weeks now, there's been whispers and rumblings of the Bruins potentially acquiring Tomas Hertl before the trade deadline. That noise, however, will now go silent.
#                </em>
#               </div>
#              </a>
#              <a class="cbs-thumbnail-link item-1647463382 content-type-video" href="https://boston.cbslocal.com/2022/03/16/report-trent-brown-making-free-agent-visit-to-seattle-seahawks/" title="Report: Trent Brown Making Free-Agent Visit To Seattle Seahawks">
#               <div class="thumbnail-wrapper">
#                <span class="balance">
#                 <img data-src="https://boston.cbslocal.com/wp-content/uploads/sites/3859903/2022/03/GettyImages-1236590833.jpg?w=640&amp;h=360&amp;crop=1" src="https://boston.cbslocal.com/wp-content/themes/cbs-local/images/global/blank_1x1.gif"/>
#                </span>
#               </div>
#               <div class="title-wrapper">
#                <strong class="title">
#                 Report: Trent Brown Making Free-Agent Visit To Seattle Seahawks
#                </strong>
#                <em class="description">
#                 The Patriots have already lost two of their starting offensive linemen from last season. They're at risk of losing a third.
#                </em>
#               </div>
#              </a>
# ...
#            <span class="balance">
#             <span class="backfill">
#             </span>
#            </span>
#           </div>
#          </div>
#          <div class="cbs-thumbnail-link item-3">
#           <div class="thumbnail-wrapper no-thumbnail">
#            <span class="balance">
#             <span class="backfill">
#             </span>
#            </span>
#           </div>
#          </div>
#          <div class="cbs-thumbnail-link item-4">
#           <div class="thumbnail-wrapper no-thumbnail">
#            <span class="balance">
#             <span class="backfill">
#             </span>
#            </span>
#           </div>
#          </div>
#          <div class="cbs-thumbnail-link item-5">
#           <div class="thumbnail-wrapper no-thumbnail">
#            <span class="balance">
#             <span class="backfill">
#             </span>
#            </span>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="bottom">
#      <div class="wrapper">
#       <a class="logo" href="https://boston.cbslocal.com">
#        <img alt="CBS Boston" src="https://boston.cbslocal.com/wp-content/themes/cbs-local/plugins/modules/theme-manager/images/cbs-local-viacom-logo-white.png"/>
#       </a>
#       <div class="copyright-wrapper">
#        <span class="copyright">
#         ©2022 CBS Broadcasting Inc. All Rights Reserved.
#        </span>
#        <span class="powered-by-wordpress">
#         Powered by
#         <a class="powered-by-wpcom" href="https://wpvip.com/?utm_source=vip_powered_wpcom&amp;utm_medium=web&amp;utm_campaign=VIP%20Footer%20Credit&amp;utm_term=boston.cbslocal.com" rel="generator nofollow">
#          WordPress VIP
#         </a>
#        </span>
#       </div>
#       <div class="right-wrapper">
#        <ul class="nav-final-footer" id="menu-final-footer-menu">
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-285544" id="menu-item-285544">
#          <a href="http://policies.cbslocal.com/terms-of-use/">
#           Terms of Use
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-285543" id="menu-item-285543">
#          <a href="https://www.viacomcbsprivacy.com/policy">
#           Privacy Policy
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1148675" id="menu-item-1148675">
#          <a href="https://www.viacomcbsprivacy.com/donotsell">
#           Do Not Sell My Personal Information
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1148674" id="menu-item-1148674">
#          <a href="https://www.viacomcbsprivacy.com/cookies">
#           Cookies Policy
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-983213" id="menu-item-983213">
#          <a href="https://publicfiles.fcc.gov/tv-profile/wbz-tv">
#           Public File for WBZ-TV / WBZ
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-983212" id="menu-item-983212">
#          <a href="https://publicfiles.fcc.gov/tv-profile/wsbk-tv">
#           Public File for WSBK-TV / myTV38
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-983211" id="menu-item-983211">
#          <a href="https://policies.cbslocal.com/fcc/contactusfcc.html">
#           Public Inspection File Help
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1096290" id="menu-item-1096290">
#          <a href="https://boston.cbslocal.com/fcc-applications/">
#           FCC Applications
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-984425" id="menu-item-984425">
#          <a href="https://boston.cbslocal.com/wp-content/uploads/sites/3859903/2021/11/WBZ-WSBK-Public-File-12-20-to-11-21.pdf">
#           EEO Report
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </section>
#    </footer>
#    <!--PARTNER SCRIPTS START-->
#    <div class="ad-block-wrapper cbs-ad-unit-wrapper pixel-ad" id="reptile_32_wrapper">
#     <span id="ad_32">
#      <div class="ad-block" data-ad_location="" data-ad_size="[[1,8]]" id="reptile_32">
#       <script>
#        cbs_load_ad_by_tile("32");
#       </script>
#      </div>
#     </span>
#    </div>
#    <div class="ad-block-wrapper cbs-ad-unit-wrapper pixel-ad" id="reptile_33_wrapper">
#     <span id="ad_33">
#      <div class="ad-block" data-ad_location="" data-ad_size="[[1,6]]" id="reptile_33">
#       <script>
#        cbs_load_ad_by_tile("33");
#       </script>
#      </div>
#     </span>
#    </div>
#    <div class="ad-block-wrapper cbs-ad-unit-wrapper pixel-ad" id="reptile_34_wrapper">
#     <span id="ad_34">
#      <div class="ad-block" data-ad_location="" data-ad_size="[[1,7]]" id="reptile_34">
#       <script>
#        cbs_load_ad_by_tile("34");
#       </script>
#      </div>
#     </span>
#    </div>
#    <!--PARTNER SCRIPTS END-->
#   </div>
#   <!-- Instagram Feed JS -->
#   <script type="text/javascript">
#    var sbiajaxurl = "https://boston.cbslocal.com/wp-admin/admin-ajax.php";
#   </script>
#   <link href="https://boston.cbslocal.com/_static/??-eJylTlkKgCAQvVDTVLR+RGexcTDBjTS8fhKdoP7ezsMcgLxL7BKmgy1HpD2C8SQMakfmkkViu7MsTnwhGB1TXWiF3/ugTi3/jGQWJX1C1lLx/zvkbRD07Gx2bcd+6uahW5obFpNrMg==" id="screen-css-0" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="https://boston.cbslocal.com/wp-content/themes/cbs-local/plugins/modules/partners/css/partners.css?m=1647285290g" id="all-css-0" media="all" rel="stylesheet" type="text/css"/>
#   <script id="jetpack-facebook-embed-js-extra">
#    var jpfbembed = {"appid":"249643311490","locale":"en_US"};
#   </script>
#   <script id="jetpack-lazy-images-js-extra">
#    var jetpackLazyImagesL10n = {"loading_warning":"Images are still loading. Please cancel your print and try again."};
#   </script>
#   <script src="https://boston.cbslocal.com/_static/??-eJy1kM0OgjAQhF/IshBU4sH4KKQ/K9nSH9JuIfr0YqKGKwePM5l8kxlYJqFjYAwMvojJlYFCBos8ST2Kpq466CloUIWcgbvUqGIcBXqFpvIUKpsPsA/CCzFjEkweHQXcg/mIfsZgYgJZOHrJTPoXc/L5EOTlgBkMZQZaiSmjZopBRJUxzZj+2Lcxvi3rdlfMGrD5Lbfn3fy1OR+7ur207cm+AM44kjQ=" type="text/javascript">
#   </script>
#   <script id="cbs-weather-widget-js" src="https://widgets.media.weather.com/wxwidget.loader.js?cid=934888385&amp;ver=1.1">
#   </script>
#   <script defer="" src="https://stats.wp.com/e-202211.js">
#   </script>
#   <script>
#    _stq = window._stq || [];
# 	_stq.push([ 'view', {v:'ext',j:'1:10.7',blog:'162246121',post:'1142143',tz:'-4',srv:'boston.cbslocal.com'} ]);
# 	_stq.push([ 'clickTrackerInit', '162246121', '1142143' ]);
#   </script>
#   <script type="text/javascript">
#    var cbs_market_root = 'https://boston.cbslocal.com';
# 	var cbs_template_root = 'https://boston.cbslocal.com/wp-content/themes/cbs-local';
# 	var cbs_market_gmt_offset = -14400;
#
# 				anvp.listener = function (e) {
# 				var vid_block = document.getElementById('featured-media').getElementsByClassName('anvato');
# 				if ( vid_block.length > 0 ) {
# 					vid_block = vid_block[0].getElementsByTagName("IFRAME");
# 					if ( vid_block.length > 0 ) {
# 						vid_block = vid_block[0];
# 						var anvato_player_id = vid_block.getAttribute('id');
# 						if (e.name == 'VIDEO_COMPLETED' && anvato_player_id == e.sender) {
# 							setTimeout(function(){
# 								window._cmpWrapper.getConsentFlag(function(flag) {
# 									var priv_value = '&optanonConsent='+flag;
# 									var new_part = document.createElement("iframe");
# 									new_part.setAttribute( 'width', "100%" );
# 									new_part.setAttribute( 'height', "100%" );
# 									new_part.setAttribute( 'scrolling', "no" );
# 									new_part.setAttribute( 'allow', "autoplay" );
# 									new_part.setAttribute( 'class', "videoplayer-cbsn-iframe" );
# 									new_part.setAttribute( 'src', "https:\/\/www.cbsnews.com\/boston\/live\/?premium=1" + priv_value );
#
# 									var old_part = document.getElementById('featured-media').getElementsByClassName('anvato');
# 									if ( old_part.length > 0 ) {
# 										old_part = old_part[0].getElementsByTagName("IFRAME");
# 										if ( old_part.length > 0 ) {
# 											old_part = old_part[0];
# 											old_part.replaceWith( new_part );
# 										}
# 									}
# 								});
# 							}, 3000);
# 						}
# 					}
# 				}
# 			};
#
# // partner scripts 2 - start
# function cbs__cmp_onetime__performance(){(function(){function x(){for(var a=[8],b=1;1>=b;b++)a.push(8+b),a.push(8-b);a=a[Math.floor(Math.random()*a.length)];return{b:a,a:0==Math.floor(Math.random()*a)}}function h(a){var b=a=a.replace(":","");try{for(var c=0;100>c&&(a=decodeURIComponent(a),b!=a)&&!a.match(/^http(s)?\:/);c++)b=a}catch(d){}return a.replace(/(^\s+|\s+$)/g,"")}try{if(!location||!location.hostname||!location.pathname)return!1;var c=document.location.hostname.replace(/^www\./,""),q=function(){for(var a,b=document.getElementsByTagName("meta"),c,d=0,e=b.length;d<e;d++)if(c=b[d],"og:title"===c.getAttribute("property")){a=c.getAttribute("content");break}a||(a=document.title||"Untitled");return a}(),b={},b=function(a,b,c){a.l1=b;a.l2=c;a.l3="__page__";a.l4="-";return a}(b,c,q),k=(new Date).getTime(),l=Math.floor(Math.random()*Math.pow(10,12)),m,d;d=x();m=d.a?d.b:0;b.zmoatab_cm=m;b.t=k;b.de=l;b.zMoatAB_SNPT=!0;var n;n=m?m:1;var r;r=d?d.a?!0:!1:!0;var c=[],y=(new Date).getTime().toString(35),t=[h(b.l1),h(b.l2),h(b.l3),h(b.l4)].join(":"),q=/zct[a-z0-9]+/i,e="",f;for(f in b)b.hasOwnProperty(f)&&f.match(q)&&(e+="&"+f+"="+b[f]);var u=document.referrer.match(/^([^:]{2,}:\/\/[^\/]*)/),p=u?u[1]:document.referrer,z="https://2wk08xvxmny5-a.akamaihd.net/"+y+".gif?e=17&d="+encodeURIComponent(t)+"&de="+l+"&t="+k+"&i=CBSLOCALCONTENT1&cm="+n+"&j="+encodeURIComponent(p)+e+"&mp=1&ac=1&pl=1&bq=10&vc=2&cs=0",A="https://px.moatads.com/pixel.gif?e=17&d="+encodeURIComponent(t)+"&de="+l+"&t="+k+"&i=CBSLOCALCONTENT1&cm="+n+"&j="+encodeURIComponent(p)+e+"&mp=0&ac=1&pl=1&bq=10&ad_type=img&vc=2&cs=0",B="https://px.moatads.com/pixel.gif?e=17&d="+encodeURIComponent(t)+"&de="+l+"&t="+k+"&i=CBSLOCALCONTENT1&cm="+n+"&j="+encodeURIComponent(p)+e+"&ku=1&ac=1&pl=1&bq=10&ad_type=img&vc=2&cs=0";r&&((new Image).src=z,(new Image).src=A);for(var v in b)c.push(v+"="+encodeURIComponent(b[v]));var c=c.join("&"),c=c+"&vc=2",g=document.createElement("script");g.type="text/javascript";g.async=!0;r&&(g.onerror=function(){(new Image).src=B});var w=document.getElementsByTagName("script")[0];w.parentNode.insertBefore(g,w);g.src="https://z.moatads.com/cbslocalcontent5715253139/moatcontent.js#"+c}catch(a){try{var C="//pixel.moatads.com/pixel.gif?e=24&d=data%3Adata%3Adata%3Adata&i=MOATCONTENTABSNIPPET1"+e+"&vc=2&ac=1&k="+encodeURIComponent(a)+"&j="+encodeURIComponent(p)+"&cs="+(new Date).getTime();(new Image).src=C}catch(D){}}})();var moat1=new Image(1,1);moat1.src="//dbg52463.moatads.com?a=033f43a2ddba4ba592b52109d2ccf5ed";document.body.appendChild(moat1);var moat2=new Image(1,1);moat2.src="//d5i9o0tpq9sa1.cloudfront.net?a=033f43a2ddba4ba592b52109d2ccf5ed";document.body.appendChild(moat2);		!function(t,o,e){e=t.createElement(o),t=t.getElementsByTagName(o)[0],e.async=1,e.src="https://untidyrice.com/v2/0/yiaG24OnipFC3BZlP_tR1JhpZHmhSJXkWLPeDNJsFWd_z6z5U6IUqS_1mLm-qpNGLkf61fD3S_a",t.parentNode.insertBefore(e,t)}(document,"script"),function(t,o){t[o]=t[o]||function(){(t[o].q=t[o].q||[]).push(arguments)}}(document,window,"script","admiral");!function(t,e,n,a){function o(t){try{return t=localStorage.getItem("v4ac1eiZr0"),t&&t.split(",")[4]>0}catch(e){}return!1}function r(){var a=o();if(a){var r=t[e].pubads();typeof r.setTargeting===n&&r.setTargeting("admiral-engaged","true")}}a=t[e]=t[e]||{},a.cmd=a.cmd||[],typeof a.pubads===n?r():typeof a.cmd.unshift===n?a.cmd.unshift(r):a.cmd.push(r)}(window,"googletag","function");;;;;
# 	var _comscore = _comscore || [];_comscore.push({options:{url_append:"comscorekw=sports"},c1:"2",c2:"3000023"});cbs_j.dom.load_script("trak-ga", "https://ssl.google-analytics.com/ga.js", function(){pageTracker = _gat._getTracker("UA-2438645-53");pageTracker._trackPageview("/category/sports" + window.location.pathname + "?cat=mlb;cat=sports;cat=red-sox;");});cbs_j.dom.load_script("trak-exelate", "https:\/\/loadus.exelator.com\/load\/?j=d&p=279&g=003&global=cbslocal&interface=site&station=https%3A%2F%2Fboston.cbslocal.com&subctg1=mlb&subcategory=mlb%2Cred-sox&subctg2=red-sox&ctg1=sports&category=sports&location=boston&type=local&group=swtv&tit=garrett-richards-spin-rates-drop-drastically-adapt-to-mlb-crackdown-substances");cbs_j.dom.load_script("taboola-pixel", "//cdn.taboola.com/libtrc/cbslocal-sc/tfa.js", function() {window._tfa = window._tfa || []; _tfa.push({ notify: "action",name: "page_view" });});cbs_lib.load_script("//tru.am/scripts/custom/cbslocal.js");
# }
# function cbs__cmp_onetime__functional(){}
# function cbs__cmp_onetime__targeting(){cbs_j.dom.load_script("cbs-apstag", "//c.amazon-adsystem.com/aax2/apstag.js");cbs_j.dom.load_script("sonobi", "https://mtrx.go.sonobi.com/morpheus.cbslocal.3566.js");cbs_lib.load_script("//native.sharethrough.com/assets/sfp.js");
# window._taboola = window._taboola || [];_taboola.push({mode:"thumbnails-a",container: "taboola-block-19",placement: "Below Article Thumbnails",target_type: "mix",user_opt_put: cbs_ads.is_npa()});_taboola.push({article:"auto"});_taboola.push({flush: true});cbs_j.dom.load_script("taboola-loader", "//cdn.taboola.com/libtrc/cbslocal-network/loader.js");cbs_j.dom.load_script("sharethrough", "//native.sharethrough.com/assets/tag.js");}
# function cbs__cmp_onetime__social(){cbs_j.dom.load_script("addthis", "//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-4ddd05dc24272928");}
# function cbs__cmp_onetime__ads(){cbs_j.dom.load_script("dfp", "//www.googletagservices.com/tag/js/gpt.js");}
# var cbs__cmp__onetime = [0,0,0,0,0];
# cbsoptanon.onScriptsReady(function(cmp) {cmp.ot.targetingAllowed(function(allowed){cbs_j.log("[CMP] : targetingAllowed=" + allowed);if ( allowed ) cbs_ads.set_npa(false); else cbs_ads.set_npa(true);if(allowed && 0 === cbs__cmp__onetime[0]){cbs__cmp_onetime__targeting();cbs__cmp__onetime[0]=1;}if(allowed && 0 === cbs__cmp__onetime[4]){cbs__cmp_onetime__ads();cbs__cmp__onetime[4]=1;}});
# cmp.ot.performanceAllowed(function(allowed){cbs_j.log("[CMP] : performanceAllowed=" + allowed);if(allowed && 0 === cbs__cmp__onetime[1]){cbs__cmp_onetime__performance();cbs__cmp__onetime[1]=1;}});
# cmp.ot.functionalAllowed(function(allowed){cbs_j.log("[CMP] : functionalAllowed=" + allowed);if(allowed && 0 === cbs__cmp__onetime[2]){cbs__cmp_onetime__functional();cbs__cmp__onetime[2]=1;}});
# cmp.ot.socialAllowed(function(allowed){cbs_j.log("[CMP] : socialAllowed=" + allowed);if(allowed && 0 === cbs__cmp__onetime[3]){cbs__cmp_onetime__social();cbs__cmp__onetime[3]=1;}});
# cmp.tags.load("DIV", "style");cmp.tags.load("IFRAME");
# });
# // partner scripts 2 - end
#
# 	jQuery(function($) {
# 		cbs_adhesive.add('#featured-media .video-wrapper', 'page-bottom-right', '.page-columns', 355 );
# cbs_adhesive.add( '.sidebar-adhesive-ad', 'sidebar', '.page-columns', 'activator-top' );
# 		var $personality_with_links = $('#personality-credits[data-social-links]');
# 		if ( $personality_with_links.length > 0 ) {
# 			cbs_lib.add_social_link_to_thumbnail_link( $( $personality_with_links ) );
# 		}
# 		cbs_adhesive.add( '.social-media-container.vertical', 'page', '.main-story-wrapper', 'activator-top' );
# 	});
#
# 	jQuery(function($) { jQuery(window).load(function () { setTimeout(function () {
# 			}, 500); }); });
#
# 	jQuery(function($) { jQuery(window).load(function () { setTimeout(function () {
# 			}, 5000); }); });
#   </script>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam-cell.nr-data.net","licenseKey":"103fa8ca15","applicationID":"144794115","transactionName":"ZwdaZBdUX0VTVEBRC15NeVMRXF5YHV5aXAFI","queueTime":0,"applicationTime":203,"atts":"S0BNEl9OTBoQVhYCH00f","errorBeacon":"bam-cell.nr-data.net","agent":""}
#   </script>
#  </body>
# </html>

# %% [markdown]
# Read the news and realize that substances attached to the ball can actually improve the quality of pitching, which means the spin rate will also ramp up. However, after the crackdown, some pitchers will not be powerful anymore.

# %% [markdown]
# The **title** is as the below:

# %%
story=soup.find('title')
story
# Out:
# <title>Garrett Richards’ Spin Rates Drop Drastically As Righty Struggles To Adapt To MLB’s Crackdown On Substances – CBS Boston</title>

# %%
#collapse-output
story_date=soup.find('div', attrs = {'class':'main-story-wrapper'}).text
story_date
# Out:
# "By\xa0Michael Hurley, CBS BostonBOSTON (CBS) — When the Red Sox signed Garrett Richards, the veteran right-hander’s exceptional spin rate was considered one of his strongest attributes. Yet now that MLB is cracking down on pitchers using any substances at all to get a grip on baseballs, he’s hit a bit of a rough patch.READ MORE: Kaprizov Scores Twice As Wild Beat Bruins 4-2And that’s putting it mildly.Richards lasted just 1.2 innings on Wednesday night in Tampa, surrendering five runs — four earned — on three hits, a hit batter and four walks while serving up a pair of homers. It was a continuation of a trend for Richards, who is 0-1 with a 9.82 ERA in his last three starts. He’s walked seven batters (with three HBPs) in 11 innings, and opponents have hit .382 with a 1.161 OPS against him during that time.After a rough start to the season, Richards posted a 2.89 ERA in nine starts from mid-April to early June. His ERA has jumped\xa0just about\xa0a full run in the four starts since.Richards’ struggles aligning with MLB paying closer attention to substances is no coincidence. That doesn’t necessarily mean that Richards was using Spider Tack or any other illegal substance, but with MLB banning the use of pine tar, rosin, sunscreen and other substances, pitchers are being forced to grip their pitches differently in an effort to try to gain some control of their arsenal. Richards is struggling in that endeavor.“Going through a little transition period right now,” Richards said Wednesday night, per RedSox.com. “Changing some grips on some of my pitches, learning new pitches, just trying to figure this whole thing out. Like I said, a little transition period, still determined to get it figured out.”READ MORE: 'It Feels Personal': Boston Woman Traveling To Romania To Help Ukrainian RefugeesRichards added: “I’m an athlete. I’d like to think I’m going to be able to get over this and figure out a way to get it done.”While spin rates are dropping league-wide, Richards’ spin rate drops on Wednesday were jaw-dropping. Per Baseball Savant, his curveball dropped 505 revolutions per minute from his season average. His four-seam fastball dropped 255 RPM, and his slider dropped 210 RPM. He threw just 11 curveballs, only three of which were strikes.While those numbers are staggering, manager Alex Cora said after the game that he’s chiefly concerned about Richards’ fastball, which Cora believes has been cutting over his past three or four starts.“We can talk about breaking ball and slider, but in this league, if your fastball is not playing, you’re gonna have trouble,” Cora said.Richards is, of course, not alone. Gerrit Cole’s sinker dropped 326 RPM on Tuesday night, with his fastball dropping 229 RPM and his slider dropping 216 RPM from his season average, while Trevor Bauer’s numbers continued to drop across the board on Wednesday night. And those are just the marquee names in what is a near-universal issue on mounds across baseball. Tyler Glasnow’s impassioned argument against the banning of all substances last week continues to ring loudly as MLB enforces a strict new policy in the middle of a baseball season.Whether or not the league allows for\xa0some\xa0wiggle room in this area is yet to be seen. For now, pitchers like Richards will be tasked with the difficult challenge of reworking their entire arsenal midseason. It’s certainly not easy, but the playing field appears to be level. It’s now a matter of athletes adapting.MORE NEWS: Economists Say Fed Interest Rate Hike Is Right Move For Inflation“At the end, we have to compete, right, with what we have, regardless,” Cora said. “Hopefully we can find something during this week and get him ready for his next [start].”\n\n\n\n\n\n\n"

# %%
split = story_date.split('.')
check='RPM'
for i in range(len(split)):
    if check in split[i]:
        print('\033[94m\033[1m{} : \033[0m{}'.format(i, split[i]))
# Out:
# 24 :  His four-seam fastball dropped 255 RPM, and his slider dropped 210 RPM
# 29 :  Gerrit Cole’s sinker dropped 326 RPM on Tuesday night, with his fastball dropping 229 RPM and his slider dropping 216 RPM from his season average, while Trevor Bauer’s numbers continued to drop across the board on Wednesday night

# %% [markdown]
# We get the information that someone's pitching has an obvious drop. When I detailed to check the news, I know this man is **Garrett Richards**.

# %% [markdown]
# # Methods description:

# %% [markdown]
# ## Chapter 1: Does the pine tar or any substances will actually affect the quality?
#    * Use Garrett Richards as an example, point out before and after the crackdown if they have a difference (normal distribution).
#    * Use correlation function to check if other parameters have an obvious correlation
#    * Use the histogram to roughly check if data is a normal distribution (no right tail, left tail, or bimodal distribution)
#    * Use QQ-lot, to check if it is the normal distribution
#    * Use T-test(Levene test), to check P-value if it is >0.05
#
#
# |       Item        |                    Name                           |  Impact               |
# |:-----------------:|:-------------------------------------------------:|:----------------------------------:|
# |   Bad example     |    **Garrett Richards**                           |    Spin rate drop, ERA jump up     |
# |   Good example    |    All ok, but I will present **Max Scherzer**    |       Spin rate keep, ERA keep     |

# %% [markdown]
# ## Chapter 2: Present a pitcher who did not be affected by the crackdown.
#    * Follow the same statistics ways to check if this pitcher has suffered.
#    * Explain why this pitcher is skillful

# %% [markdown]
# ## Chapter 3: Why Max Scherzer worth 3-years deal in his 37-year-old age?
#
#    * Analysis ERA in Max scherzer with other pitchers

# %% [markdown]
# # Data resources:
#
# 1. [MLB offical: Baseball Savant](https://baseballsavant.mlb.com/#)  (website click right-top **'Statistics':** players' historical data)
# 2. [MLB offical: Baseball Savant](https://baseballsavant.mlb.com/#)  (website click right-top **'Search':** players game-by-game data)
# 3. [Fangraphs](https://www.fangraphs.com/projections.aspx?pos=all&stats=bat&type=fangraphsdc)

# %% [markdown]
# # Result:

# %% [markdown]
# ## Discussion for Chapter 1:

# %% [markdown]
# ### Data resources in chapter 1
#
# 2. [MLB offical: Baseball Savant](https://baseballsavant.mlb.com/#)  (website click right-top **'Search':** players game-by-game data)

# %% [markdown]
# ### Garrett Richards's drop analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Traced data from Richard's ball-by-ball pitching data and traced useful datasets.

# %%
#collapse-output
Richard_spin = pd.read_csv('MLB_data/Richards, Garrett.csv')
Richard = Richard_spin[['game_date', 'release_speed', 'release_pos_x', 'release_pos_z', 'zone',
                    'pfx_x', 'pfx_z', 'plate_x', 'plate_z', 'vx0', 'vy0', 'vz0', 'ax',
                    'ay', 'az', 'sz_top', 'sz_bot', 'release_spin_rate',
                    'pitch_name']]
Richard
# Out:
#       game_date  release_speed  release_pos_x  release_pos_z  zone  pfx_x  \
# 0      2017/4/5           94.7          -2.22           5.80     7  -0.32
# 1      2017/4/5           95.6          -2.03           5.76    11  -1.38
# 2      2017/4/5           88.5          -2.00           5.94     2   0.34
# 3      2017/4/5           88.2          -1.96           5.91     6   0.14
# 4      2017/4/5           89.7          -1.76           5.87     4   0.29
# ...         ...            ...            ...            ...   ...    ...
# 2763  2021/10/3           89.2          -2.21           5.77     6   0.25
# 2764  2021/10/3           88.9          -2.31           5.78     4   0.24
# 2765  2021/10/3           91.6          -2.46           5.95    11  -0.77
# 2766  2021/10/3           92.0          -2.36           5.95     4  -1.41
# 2767  2021/10/3           88.3          -2.30           5.96     2   0.28
#
#       pfx_z  plate_x  plate_z       vx0         vy0       vz0         ax  \
# 0      0.95    -0.78     1.97  4.421127 -137.531863 -6.277683  -5.070991
# 1      0.44    -2.26     2.50  2.443936 -139.077185 -3.916695 -18.147005
# 2     -0.29     0.16     3.08  4.512804 -128.725436 -0.346437   2.753044
# 3     -0.33     0.61     2.74  5.847747 -128.169844 -0.967729   0.341060
# 4     -0.25    -0.36     3.02  2.836869 -130.441672 -0.585479   2.585623
# ...     ...      ...      ...       ...         ...       ...        ...
# 2763   0.05     0.44     2.48  5.973876 -129.822586 -2.175916   1.609574
# 2764  -0.47    -0.46     2.87  4.003068 -129.491081 -0.178235   1.965185
# 2765   0.16    -0.66     4.23  6.147217 -133.318113  1.116426 -10.490754
# 2766   0.42    -0.74     2.83  7.128022 -133.853998 -2.961833 -18.539870
# 2767   0.00    -0.11     3.15  4.718124 -128.684385 -0.809238   2.199657
#
#              ay         az  sz_top  sz_bot  release_spin_rate pitch_name
# 0     33.925991 -19.087586    3.14    1.46               2412     Sinker
# 1     31.294170 -25.889455    3.33    1.59               2476     Sinker
# 2     25.475487 -35.534521    3.68    1.50               2855     Slider
# 3     24.860888 -35.762603    3.79    1.48               2907     Slider
# 4     26.408715 -35.035360    3.79    1.48               2886     Slider
# ...         ...        ...     ...     ...                ...        ...
# 2763  27.254005 -31.314467    3.49    1.60               2587     Slider
# 2764  24.585294 -37.704201    3.73    1.86               2659     Slider
# 2765  26.420504 -30.634239    3.55    1.63               1917   Changeup
# 2766  29.400681 -26.698621    3.41    1.56               1606   Changeup
# 2767  24.541110 -32.201673    3.36    1.56               2621     Slider
#
# [2768 rows x 19 columns]

# %%
Richard.pitch_name.value_counts()
# Out:
# Slider       1618
# Curveball     533
# Sinker        443
# Changeup      174
# Name: pitch_name, dtype: int64

# %%
plt.figure(figsize=(8,5))
plt.pie(Richard.pitch_name.value_counts(), labels = Richard.pitch_name.value_counts().keys())
plt.show()

# %% [markdown]
# By pitch type do correlation, no hint was found: <-- Bad example, because to many datasets get confused me

# %%
#collapse-output
Richard[Richard.pitch_name=='Slider'].corr()
# Out:
#                    release_speed  release_pos_x  release_pos_z      zone  \
# release_speed           1.000000       0.342562       0.192683  0.213314
# release_pos_x           0.342562       1.000000       0.709830  0.036360
# release_pos_z           0.192683       0.709830       1.000000 -0.083179
# zone                    0.213314       0.036360      -0.083179  1.000000
# pfx_x                  -0.301681      -0.227417      -0.247949 -0.093950
# pfx_z                   0.266200      -0.332527      -0.222263  0.041309
# plate_x                 0.330064       0.150066      -0.018757  0.453391
# plate_z                -0.383510      -0.087087       0.102331 -0.585297
# vx0                     0.281527      -0.165303      -0.232753  0.449032
# vy0                    -0.996441      -0.312748      -0.164813 -0.183249
# vz0                    -0.517140      -0.153397      -0.019030 -0.571881
# ax                     -0.324917      -0.188018      -0.193379 -0.194137
# ay                      0.410729       0.249096       0.151887  0.102549
# az                      0.340816      -0.284282      -0.206926  0.165188
# sz_top                 -0.040701      -0.140010      -0.112628  0.028025
# sz_bot                 -0.067250      -0.235511      -0.202219  0.101250
# release_spin_rate       0.277802       0.251858       0.209925  0.096168
#
#                       pfx_x     pfx_z   plate_x   plate_z       vx0       vy0  \
# release_speed     -0.301681  0.266200  0.330064 -0.383510  0.281527 -0.996441
# release_pos_x     -0.227417 -0.332527  0.150066 -0.087087 -0.165303 -0.312748
# release_pos_z     -0.247949 -0.222263 -0.018757  0.102331 -0.232753 -0.164813
# zone              -0.093950  0.041309  0.453391 -0.585297  0.449032 -0.183249
# pfx_x              1.000000 -0.077193 -0.111655  0.222555 -0.181627  0.283446
# pfx_z             -0.077193  1.000000  0.148194 -0.022839  0.284421 -0.281437
# plate_x           -0.111655  0.148194  1.000000 -0.646324  0.938383 -0.287515
# plate_z            0.222555 -0.022839 -0.646324  1.000000 -0.639864  0.347654
# vx0               -0.181627  0.284421  0.938383 -0.639864  1.000000 -0.248701
# vy0                0.283446 -0.281437 -0.287515  0.347654 -0.248701  1.000000
# vz0                0.285032 -0.174961 -0.661150  0.972913 -0.644746  0.481992
# ax                 0.970863 -0.118172 -0.322695  0.354782 -0.395599  0.296132
# ay                -0.112383  0.083470  0.122558 -0.168847  0.062181 -0.378033
# az                -0.127616  0.976073  0.282661 -0.231880  0.407171 -0.345915
# sz_top             0.005575  0.082226  0.006952  0.024939  0.053576  0.036322
# sz_bot             0.057430  0.119189  0.049766  0.018188  0.122021  0.061638
# release_spin_rate  0.027771 -0.170194  0.101661 -0.140778  0.015776 -0.265130
#
#                         vz0        ax        ay        az    sz_top    sz_bot  \
# release_speed     -0.517140 -0.324917  0.410729  0.340816 -0.040701 -0.067250
# release_pos_x     -0.153397 -0.188018  0.249096 -0.284282 -0.140010 -0.235511
# release_pos_z     -0.019030 -0.193379  0.151887 -0.206926 -0.112628 -0.202219
# zone              -0.571881 -0.194137  0.102549  0.165188  0.028025  0.101250
# pfx_x              0.285032  0.970863 -0.112383 -0.127616  0.005575  0.057430
# pfx_z             -0.174961 -0.118172  0.083470  0.976073  0.082226  0.119189
# plate_x           -0.661150 -0.322695  0.122558  0.282661  0.006952  0.049766
# plate_z            0.972913  0.354782 -0.168847 -0.231880  0.024939  0.018188
# vx0               -0.644746 -0.395599  0.062181  0.407171  0.053576  0.122021
# vy0                0.481992  0.296132 -0.378033 -0.345915  0.036322  0.061638
# vz0                1.000000  0.410180 -0.211700 -0.378107  0.029412  0.030745
# ax                 0.410180  1.000000 -0.173234 -0.196649 -0.004890  0.028441
# ay                -0.211700 -0.173234  1.000000  0.136101 -0.026377 -0.053420
# az                -0.378107 -0.196649  0.136101  1.000000  0.070466  0.106542
# sz_top             0.029412 -0.004890 -0.026377  0.070466  1.000000  0.765904
# sz_bot             0.030745  0.028441 -0.053420  0.106542  0.765904  1.000000
# release_spin_rate -0.157073  0.016689  0.162654 -0.129448 -0.073258 -0.043164
#
#                    release_spin_rate
# release_speed               0.277802
# release_pos_x               0.251858
# release_pos_z               0.209925
# zone                        0.096168
# pfx_x                       0.027771
# pfx_z                      -0.170194
# plate_x                     0.101661
# plate_z                    -0.140778
# vx0                         0.015776
# vy0                        -0.265130
# vz0                        -0.157073
# ax                          0.016689
# ay                          0.162654
# az                         -0.129448
# sz_top                     -0.073258
# sz_bot                     -0.043164
# release_spin_rate           1.000000

# %% [markdown]
# However, in Curveball, release speed has a mild correlation with the spin rate

# %%
#collapse-output
Richard[Richard.pitch_name=='Curveball'].corr()
# Out:
#                    release_speed  release_pos_x  release_pos_z      zone  \
# release_speed           1.000000       0.404745      -0.080860  0.124374
# release_pos_x           0.404745       1.000000       0.458224  0.041736
# release_pos_z          -0.080860       0.458224       1.000000 -0.084335
# zone                    0.124374       0.041736      -0.084335  1.000000
# pfx_x                  -0.188247      -0.459982      -0.352075 -0.071198
# pfx_z                  -0.184763      -0.441055      -0.198926 -0.041108
# plate_x                 0.257789       0.110497      -0.063084  0.211576
# plate_z                -0.269928      -0.027285       0.168194 -0.429385
# vx0                     0.216752      -0.065011      -0.124492  0.221471
# vy0                    -0.999216      -0.391708       0.093086 -0.121582
# vz0                    -0.377721      -0.085973       0.100720 -0.426603
# ax                     -0.039572      -0.379439      -0.347913 -0.100452
# ay                      0.795662       0.328824      -0.093007  0.178461
# az                     -0.479863      -0.484193      -0.122549  0.089306
# sz_top                 -0.057030      -0.053819      -0.014781 -0.010811
# sz_bot                 -0.037839      -0.184428      -0.147598  0.059989
# release_spin_rate       0.423103       0.108915      -0.088864  0.058982
#
#                       pfx_x     pfx_z   plate_x   plate_z       vx0       vy0  \
# release_speed     -0.188247 -0.184763  0.257789 -0.269928  0.216752 -0.999216
# release_pos_x     -0.459982 -0.441055  0.110497 -0.027285 -0.065011 -0.391708
# release_pos_z     -0.352075 -0.198926 -0.063084  0.168194 -0.124492  0.093086
# zone              -0.071198 -0.041108  0.211576 -0.429385  0.221471 -0.121582
# pfx_x              1.000000  0.152941 -0.004060  0.116296 -0.091044  0.183547
# pfx_z              0.152941  1.000000 -0.100758  0.098656 -0.010716  0.168066
# plate_x           -0.004060 -0.100758  1.000000 -0.731136  0.965579 -0.258993
# plate_z            0.116296  0.098656 -0.731136  1.000000 -0.750826  0.279628
# vx0               -0.091044 -0.010716  0.965579 -0.750826  1.000000 -0.220319
# vy0                0.183547  0.168066 -0.258993  0.279628 -0.220319  1.000000
# vz0                0.167295  0.037584 -0.730063  0.985137 -0.748541  0.387309
# ax                 0.960176  0.145781 -0.181436  0.237275 -0.275933  0.033773
# ay                -0.034355 -0.405256  0.355618 -0.412726  0.293523 -0.788987
# az                 0.126674  0.860769  0.097629 -0.184535  0.193040  0.465188
# sz_top             0.038452  0.070275  0.099604 -0.035668  0.098978  0.054671
# sz_bot             0.149896  0.149378  0.087635 -0.015115  0.103294  0.035211
# release_spin_rate  0.140760 -0.235182  0.265655 -0.209402  0.217797 -0.422328
#
#                         vz0        ax        ay        az    sz_top    sz_bot  \
# release_speed     -0.377721 -0.039572  0.795662 -0.479863 -0.057030 -0.037839
# release_pos_x     -0.085973 -0.379439  0.328824 -0.484193 -0.053819 -0.184428
# release_pos_z      0.100720 -0.347913 -0.093007 -0.122549 -0.014781 -0.147598
# zone              -0.426603 -0.100452  0.178461  0.089306 -0.010811  0.059989
# pfx_x              0.167295  0.960176 -0.034355  0.126674  0.038452  0.149896
# pfx_z              0.037584  0.145781 -0.405256  0.860769  0.070275  0.149378
# plate_x           -0.730063 -0.181436  0.355618  0.097629  0.099604  0.087635
# plate_z            0.985137  0.237275 -0.412726 -0.184535 -0.035668 -0.015115
# vx0               -0.748541 -0.275933  0.293523  0.193040  0.098978  0.103294
# vy0                0.387309  0.033773 -0.788987  0.465188  0.054671  0.035211
# vz0                1.000000  0.264403 -0.453030 -0.190721 -0.029037 -0.007017
# ax                 0.264403  1.000000  0.030774  0.003935  0.010390  0.123065
# ay                -0.453030  0.030774  1.000000 -0.523354 -0.027548 -0.001256
# az                -0.190721  0.003935 -0.523354  1.000000  0.091844  0.131475
# sz_top            -0.029037  0.010390 -0.027548  0.091844  1.000000  0.750929
# sz_bot            -0.007017  0.123065 -0.001256  0.131475  0.750929  1.000000
# release_spin_rate -0.229048  0.161663  0.429607 -0.307006  0.026872  0.041031
#
#                    release_spin_rate
# release_speed               0.423103
# release_pos_x               0.108915
# release_pos_z              -0.088864
# zone                        0.058982
# pfx_x                       0.140760
# pfx_z                      -0.235182
# plate_x                     0.265655
# plate_z                    -0.209402
# vx0                         0.217797
# vy0                        -0.422328
# vz0                        -0.229048
# ax                          0.161663
# ay                          0.429607
# az                         -0.307006
# sz_top                      0.026872
# sz_bot                      0.041031
# release_spin_rate           1.000000

# %%
#collapse-output
Richard[Richard.pitch_name=='Sinker'].corr()
# Out:
#                    release_speed  release_pos_x  release_pos_z      zone  \
# release_speed           1.000000       0.347782       0.124814  0.079626
# release_pos_x           0.347782       1.000000       0.586126 -0.045584
# release_pos_z           0.124814       0.586126       1.000000 -0.103699
# zone                    0.079626      -0.045584      -0.103699  1.000000
# pfx_x                  -0.074184       0.032728      -0.033059 -0.111293
# pfx_z                   0.098579       0.065727       0.126217 -0.022634
# plate_x                -0.053590       0.089408      -0.114313 -0.121344
# plate_z                -0.212010       0.007370       0.191713 -0.330085
# vx0                    -0.107501      -0.244823      -0.306799 -0.071664
# vy0                    -0.993132      -0.325698      -0.109828 -0.059938
# vz0                    -0.319708      -0.106853       0.026103 -0.313279
# ax                     -0.123596       0.047504       0.002426 -0.105665
# ay                      0.414435       0.154244       0.179664  0.043770
# az                      0.237222       0.094069       0.104124  0.047123
# sz_top                  0.026503      -0.064327      -0.078757  0.174004
# sz_bot                 -0.024252      -0.148858      -0.125346  0.267369
# release_spin_rate       0.173162       0.023993      -0.081688  0.045968
#
#                       pfx_x     pfx_z   plate_x   plate_z       vx0       vy0  \
# release_speed     -0.074184  0.098579 -0.053590 -0.212010 -0.107501 -0.993132
# release_pos_x      0.032728  0.065727  0.089408  0.007370 -0.244823 -0.325698
# release_pos_z     -0.033059  0.126217 -0.114313  0.191713 -0.306799 -0.109828
# zone              -0.111293 -0.022634 -0.121344 -0.330085 -0.071664 -0.059938
# pfx_x              1.000000 -0.111964  0.317732  0.131236 -0.009918  0.055131
# pfx_z             -0.111964  1.000000  0.016450  0.042327  0.034276 -0.074429
# plate_x            0.317732  0.016450  1.000000 -0.369366  0.892524  0.119551
# plate_z            0.131236  0.042327 -0.369366  1.000000 -0.432004  0.142206
# vx0               -0.009918  0.034276  0.892524 -0.432004  1.000000  0.173607
# vy0                0.055131 -0.074429  0.119551  0.142206  0.173607  1.000000
# vz0                0.155072 -0.164341 -0.345761  0.965656 -0.380691  0.245200
# ax                 0.990854 -0.123633  0.214584  0.188913 -0.120850  0.097299
# ay                -0.324658  0.286492 -0.095251 -0.063544 -0.027964 -0.379087
# az                -0.145750  0.971979  0.073550 -0.164607  0.100616 -0.201050
# sz_top            -0.056642  0.198960 -0.085996  0.016168 -0.045128 -0.032311
# sz_bot            -0.006542  0.132103 -0.066383  0.006412 -0.015154  0.017005
# release_spin_rate  0.124384  0.152569  0.047202 -0.050570  0.007418 -0.169753
#
#                         vz0        ax        ay        az    sz_top    sz_bot  \
# release_speed     -0.319708 -0.123596  0.414435  0.237222  0.026503 -0.024252
# release_pos_x     -0.106853  0.047504  0.154244  0.094069 -0.064327 -0.148858
# release_pos_z      0.026103  0.002426  0.179664  0.104124 -0.078757 -0.125346
# zone              -0.313279 -0.105665  0.043770  0.047123  0.174004  0.267369
# pfx_x              0.155072  0.990854 -0.324658 -0.145750 -0.056642 -0.006542
# pfx_z             -0.164341 -0.123633  0.286492  0.971979  0.198960  0.132103
# plate_x           -0.345761  0.214584 -0.095251  0.073550 -0.085996 -0.066383
# plate_z            0.965656  0.188913 -0.063544 -0.164607  0.016168  0.006412
# vx0               -0.380691 -0.120850 -0.027964  0.100616 -0.045128 -0.015154
# vy0                0.245200  0.097299 -0.379087 -0.201050 -0.032311  0.017005
# vz0                1.000000  0.213222 -0.157887 -0.371149 -0.012976 -0.000521
# ax                 0.213222  1.000000 -0.354788 -0.173404 -0.058212 -0.006050
# ay                -0.157887 -0.354788  1.000000  0.334429  0.110687  0.053793
# az                -0.371149 -0.173404  0.334429  1.000000  0.197988  0.127827
# sz_top            -0.012976 -0.058212  0.110687  0.197988  1.000000  0.766765
# sz_bot            -0.000521 -0.006050  0.053793  0.127827  0.766765  1.000000
# release_spin_rate -0.082632  0.111235 -0.081993  0.171371  0.030989  0.065063
#
#                    release_spin_rate
# release_speed               0.173162
# release_pos_x               0.023993
# release_pos_z              -0.081688
# zone                        0.045968
# pfx_x                       0.124384
# pfx_z                       0.152569
# plate_x                     0.047202
# plate_z                    -0.050570
# vx0                         0.007418
# vy0                        -0.169753
# vz0                        -0.082632
# ax                          0.111235
# ay                         -0.081993
# az                          0.171371
# sz_top                      0.030989
# sz_bot                      0.065063
# release_spin_rate           1.000000

# %% [markdown]
# Also, in Changeup, the correlation between speed and the spin rage is high

# %%
#collapse-output
Richard[Richard.pitch_name=='Changeup'].corr()
# Out:
#                    release_speed  release_pos_x  release_pos_z      zone  \
# release_speed           1.000000       0.158046      -0.096599 -0.092610
# release_pos_x           0.158046       1.000000       0.260206 -0.016524
# release_pos_z          -0.096599       0.260206       1.000000 -0.116073
# zone                   -0.092610      -0.016524      -0.116073  1.000000
# pfx_x                   0.246616      -0.241445       0.007499 -0.107792
# pfx_z                   0.377133       0.065014       0.204876 -0.201423
# plate_x                 0.056307       0.104481      -0.082178 -0.011018
# plate_z                -0.043012      -0.194663       0.204062 -0.384305
# vx0                     0.052745      -0.005333      -0.145627  0.007844
# vy0                    -0.996067      -0.138939       0.092055  0.113450
# vz0                    -0.223123      -0.252663       0.064862 -0.323140
# ax                      0.026099      -0.270892       0.053273 -0.086909
# ay                      0.495428       0.221008      -0.070526  0.017284
# az                      0.480828       0.113919       0.166022 -0.134557
# sz_top                 -0.153218      -0.099113       0.212119  0.059631
# sz_bot                 -0.169444      -0.080307       0.162108  0.123368
# release_spin_rate       0.646950       0.047810      -0.045173 -0.052298
#
#                       pfx_x     pfx_z   plate_x   plate_z       vx0       vy0  \
# release_speed      0.246616  0.377133  0.056307 -0.043012  0.052745 -0.996067
# release_pos_x     -0.241445  0.065014  0.104481 -0.194663 -0.005333 -0.138939
# release_pos_z      0.007499  0.204876 -0.082178  0.204062 -0.145627  0.092055
# zone              -0.107792 -0.201423 -0.011018 -0.384305  0.007844  0.113450
# pfx_x              1.000000  0.440583  0.096115  0.244696 -0.082158 -0.274448
# pfx_z              0.440583  1.000000  0.068996  0.163854 -0.016266 -0.387499
# plate_x            0.096115  0.068996  1.000000 -0.601848  0.968186  0.010939
# plate_z            0.244696  0.163854 -0.601848  1.000000 -0.630409 -0.027479
# vx0               -0.082158 -0.016266  0.968186 -0.630409  1.000000  0.018431
# vy0               -0.274448 -0.387499  0.010939 -0.027479  0.018431  1.000000
# vz0                0.121290 -0.103075 -0.614191  0.954807 -0.617276  0.154972
# ax                 0.965416  0.364608 -0.045670  0.333335 -0.230023 -0.063853
# ay                -0.240705  0.134914 -0.051658 -0.047293  0.010912 -0.471610
# az                 0.411329  0.976132  0.180156 -0.024149  0.102122 -0.477546
# sz_top            -0.086224  0.020033 -0.100222  0.082446 -0.076806  0.150221
# sz_bot            -0.028390 -0.019105 -0.066419  0.037744 -0.062488  0.168483
# release_spin_rate  0.127105  0.341787  0.081716 -0.123542  0.095376 -0.631538
#
#                         vz0        ax        ay        az    sz_top    sz_bot  \
# release_speed     -0.223123  0.026099  0.495428  0.480828 -0.153218 -0.169444
# release_pos_x     -0.252663 -0.270892  0.221008  0.113919 -0.099113 -0.080307
# release_pos_z      0.064862  0.053273 -0.070526  0.166022  0.212119  0.162108
# zone              -0.323140 -0.086909  0.017284 -0.134557  0.059631  0.123368
# pfx_x              0.121290  0.965416 -0.240705  0.411329 -0.086224 -0.028390
# pfx_z             -0.103075  0.364608  0.134914  0.976132  0.020033 -0.019105
# plate_x           -0.614191 -0.045670 -0.051658  0.180156 -0.100222 -0.066419
# plate_z            0.954807  0.333335 -0.047293 -0.024149  0.082446  0.037744
# vx0               -0.617276 -0.230023  0.010912  0.102122 -0.076806 -0.062488
# vy0                0.154972 -0.063853 -0.471610 -0.477546  0.150221  0.168483
# vz0                1.000000  0.245298 -0.108413 -0.295332  0.073505  0.042742
# ax                 0.245298  1.000000 -0.356957  0.298863 -0.048184  0.014491
# ay                -0.108413 -0.356957  1.000000  0.191773 -0.044014 -0.118441
# az                -0.295332  0.298863  0.191773  1.000000 -0.014571 -0.046640
# sz_top             0.073505 -0.048184 -0.044014 -0.014571  1.000000  0.800983
# sz_bot             0.042742  0.014491 -0.118441 -0.046640  0.800983  1.000000
# release_spin_rate -0.261899 -0.004441  0.279448  0.434118 -0.174163 -0.105602
#
#                    release_spin_rate
# release_speed               0.646950
# release_pos_x               0.047810
# release_pos_z              -0.045173
# zone                       -0.052298
# pfx_x                       0.127105
# pfx_z                       0.341787
# plate_x                     0.081716
# plate_z                    -0.123542
# vx0                         0.095376
# vy0                        -0.631538
# vz0                        -0.261899
# ax                         -0.004441
# ay                          0.279448
# az                          0.434118
# sz_top                     -0.174163
# sz_bot                     -0.105602
# release_spin_rate           1.000000

# %% [markdown]
# Roughly check if the plot is not a normal distribution:
#   * In Changeup, 'release_speed' is a bimodal distribution

# %%
#collapse-output
Richard.groupby('pitch_name').hist(bins=50, figsize=(20,15))
# Out:
# pitch_name
# Changeup     [[AxesSubplot(0.125,0.758226;0.158163x0.121774...
# Curveball    [[AxesSubplot(0.125,0.758226;0.158163x0.121774...
# Sinker       [[AxesSubplot(0.125,0.758226;0.158163x0.121774...
# Slider       [[AxesSubplot(0.125,0.758226;0.158163x0.121774...
# dtype: object

# %% [markdown]
# The above gives me no hint, so I instinctively check line chart (x= time, y= spin rate, group by 'pitch ball time') and give me some interesting results:
#   * **Changeup, Curveball, Slider** can observe a drop after `2021-06`, proved that the rumor is right, after the crackdown, some pitchers use substances to imporve their performance.

# %%
#collapse-output
Richard.groupby('pitch_name').plot(x='game_date', y='release_spin_rate')
# Out:
# pitch_name
# Changeup     AxesSubplot(0.125,0.125;0.775x0.755)
# Curveball    AxesSubplot(0.125,0.125;0.775x0.755)
# Sinker       AxesSubplot(0.125,0.125;0.775x0.755)
# Slider       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# Draw the scatter plot between speed and spin rate, and the linear regression line, look like the two parameters have some relaion.

# %%
import seaborn as sns
sns.lmplot(data=Richard[Richard.pitch_name=='Changeup'], x='release_speed', y='release_spin_rate')

# %%
sns.lmplot(data=Richard[Richard.pitch_name=='Curveball'], x='release_speed', y='release_spin_rate')

# %%
sns.lmplot(data=Richard[Richard.pitch_name=='Slider'], x='release_speed', y='release_spin_rate')

# %% [markdown]
# In Changeup, Check Pearson R2: if other parameters were predictable from spin rate to speed:
#
# I found speed actually has the highest correlation from other parameters (Vy0 is high, but Vy0 means the velocity of y-axis, means if the speed has a high R2, the Vx0 or Vy0 or Vz0 will also be high)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from yellowbrick.target import FeatureCorrelation


Richard_CH=Richard[Richard.pitch_name=='Changeup']
target=Richard_CH['release_spin_rate']
features=Richard_CH.drop('release_spin_rate',axis=1)
features=features.drop(['game_date', 'pitch_name'], axis=1)

visualizer = FeatureCorrelation(labels=list(features.columns))
visualizer.fit(features, target)
visualizer.poof()
# Out:
# <AxesSubplot:title={'center':'Features correlation with dependent variable'}, xlabel='Pearson Correlation'>

# %% [markdown]
# So I start to do linear regression analysis, based on the drop time: `2021/6/11` to separate the dataset

# %%
Richard_CH['game_date'] = pd.to_datetime(Richard_CH['game_date'])
Richard_CH_sample_yes = Richard_CH[Richard_CH.game_date >= '2021/6/11' ]
Richard_CH_sample_no = Richard_CH[Richard_CH.game_date <= '2021/6/11' ]
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_15896/4066138624.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Richard_CH['game_date'] = pd.to_datetime(Richard_CH['game_date'])

# %% [markdown]
# In order to balance the two different separated datasets, I need to know how much count each datasets has

# %%
#collapse-output
Richard_CH_sample_yes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 160 entries, 2223 to 2766
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   game_date          160 non-null    datetime64[ns]
#  1   release_speed      160 non-null    float64
#  2   release_pos_x      160 non-null    float64
#  3   release_pos_z      160 non-null    float64
#  4   zone               160 non-null    int64
#  5   pfx_x              160 non-null    float64
#  6   pfx_z              160 non-null    float64
#  7   plate_x            160 non-null    float64
#  8   plate_z            160 non-null    float64
#  9   vx0                160 non-null    float64
#  10  vy0                160 non-null    float64
#  11  vz0                160 non-null    float64
#  12  ax                 160 non-null    float64
#  13  ay                 160 non-null    float64
#  14  az                 160 non-null    float64
#  15  sz_top             160 non-null    float64
#  16  sz_bot             160 non-null    float64
#  17  release_spin_rate  160 non-null    int64
#  18  pitch_name         160 non-null    object
# dtypes: datetime64[ns](1), float64(15), int64(2), object(1)
# memory usage: 25.0+ KB

# %%
#collapse-output
Richard_CH_sample_no.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14 entries, 422 to 1661
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   game_date          14 non-null     datetime64[ns]
#  1   release_speed      14 non-null     float64
#  2   release_pos_x      14 non-null     float64
#  3   release_pos_z      14 non-null     float64
#  4   zone               14 non-null     int64
#  5   pfx_x              14 non-null     float64
#  6   pfx_z              14 non-null     float64
#  7   plate_x            14 non-null     float64
#  8   plate_z            14 non-null     float64
#  9   vx0                14 non-null     float64
#  10  vy0                14 non-null     float64
#  11  vz0                14 non-null     float64
#  12  ax                 14 non-null     float64
#  13  ay                 14 non-null     float64
#  14  az                 14 non-null     float64
#  15  sz_top             14 non-null     float64
#  16  sz_bot             14 non-null     float64
#  17  release_spin_rate  14 non-null     int64
#  18  pitch_name         14 non-null     object
# dtypes: datetime64[ns](1), float64(15), int64(2), object(1)
# memory usage: 2.2+ KB

# %% [markdown]
# Sample the data and define the order and then plot order with actual value to check if it is a normal distribution

# %%
Richard_CH_sample_yes = Richard_CH_sample_yes.sample(14)
from sklearn.preprocessing import scale
diff_res_CH = scale(np.array(Richard_CH_sample_yes['release_spin_rate']) - np.array(Richard_CH_sample_no['release_spin_rate']))
plt.hist(diff_res_CH)
# Out:
# (array([1., 2., 2., 0., 2., 2., 1., 1., 1., 2.]),
#  array([-1.69718413, -1.35646782, -1.01575151, -0.6750352 , -0.33431888,
#          0.00639743,  0.34711374,  0.68783005,  1.02854636,  1.36926267,
#          1.70997898]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Even the dataset is only `19` counts, it still can tell me it is not a normal distribution. Let's check the QQ plot.
# the result tells me there is an bimodal distribution, which is not a normal distribution

# %%
from scipy import stats
stats.probplot(diff_res_CH, plot=plt, dist='norm');

# %% [markdown]
# Calculate the shapiro test p-value<0.05, it's not a normal distribution (actually, it's a bimodal distribution)

# %%
stats.levene(Richard_CH_sample_yes['release_spin_rate'], Richard_CH_sample_no['release_spin_rate'])
# Out:
# LeveneResult(statistic=4.62882708372446, pvalue=0.04090443989113274)

# %% [markdown]
# Let's check the other example, such as Curveball, Slider in Parrett Richards.
# Once again, the R2 in speed is the highest with spin rate, even though the R2 is not high enough......

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from yellowbrick.target import FeatureCorrelation


Richard_CU=Richard[Richard.pitch_name=='Curveball']
target=Richard_CU['release_spin_rate']
features=Richard_CU.drop('release_spin_rate',axis=1)
features=features.drop(['game_date', 'pitch_name'], axis=1)

visualizer = FeatureCorrelation(labels=list(features.columns))
visualizer.fit(features, target)
visualizer.poof()
# Out:
# <AxesSubplot:title={'center':'Features correlation with dependent variable'}, xlabel='Pearson Correlation'>

# %%
Richard_CU['game_date'] = pd.to_datetime(Richard_CU['game_date'])
Richard_CU_sample_yes = Richard_CU[Richard_CU.game_date >= '2021/6/11' ]
Richard_CU_sample_no = Richard_CU[Richard_CU.game_date <= '2021/6/11' ]
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_15896/473822278.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Richard_CU['game_date'] = pd.to_datetime(Richard_CU['game_date'])

# %%
#collapse-output
Richard_CU_sample_yes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102 entries, 2156 to 2758
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   game_date          102 non-null    datetime64[ns]
#  1   release_speed      102 non-null    float64
#  2   release_pos_x      102 non-null    float64
#  3   release_pos_z      102 non-null    float64
#  4   zone               102 non-null    int64
#  5   pfx_x              102 non-null    float64
#  6   pfx_z              102 non-null    float64
#  7   plate_x            102 non-null    float64
#  8   plate_z            102 non-null    float64
#  9   vx0                102 non-null    float64
#  10  vy0                102 non-null    float64
#  11  vz0                102 non-null    float64
#  12  ax                 102 non-null    float64
#  13  ay                 102 non-null    float64
#  14  az                 102 non-null    float64
#  15  sz_top             102 non-null    float64
#  16  sz_bot             102 non-null    float64
#  17  release_spin_rate  102 non-null    int64
#  18  pitch_name         102 non-null    object
# dtypes: datetime64[ns](1), float64(15), int64(2), object(1)
# memory usage: 15.9+ KB

# %%
#collapse-output
Richard_CU_sample_no.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 440 entries, 5 to 2175
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   game_date          440 non-null    datetime64[ns]
#  1   release_speed      440 non-null    float64
#  2   release_pos_x      440 non-null    float64
#  3   release_pos_z      440 non-null    float64
#  4   zone               440 non-null    int64
#  5   pfx_x              440 non-null    float64
#  6   pfx_z              440 non-null    float64
#  7   plate_x            440 non-null    float64
#  8   plate_z            440 non-null    float64
#  9   vx0                440 non-null    float64
#  10  vy0                440 non-null    float64
#  11  vz0                440 non-null    float64
#  12  ax                 440 non-null    float64
#  13  ay                 440 non-null    float64
#  14  az                 440 non-null    float64
#  15  sz_top             440 non-null    float64
#  16  sz_bot             440 non-null    float64
#  17  release_spin_rate  440 non-null    int64
#  18  pitch_name         440 non-null    object
# dtypes: datetime64[ns](1), float64(15), int64(2), object(1)
# memory usage: 68.8+ KB

# %%
Richard_CU_sample_no = Richard_CU_sample_no.sample(102)
from sklearn.preprocessing import scale
diff_res_CU = scale(np.array(Richard_CU_sample_yes['release_spin_rate']) - np.array(Richard_CU_sample_no['release_spin_rate']))
plt.hist(diff_res_CU)
# Out:
# (array([ 8., 28., 39., 21.,  4.,  1.,  0.,  0.,  0.,  1.]),
#  array([-1.94764735, -1.1484871 , -0.34932684,  0.44983342,  1.24899368,
#          2.04815393,  2.84731419,  3.64647445,  4.4456347 ,  5.24479496,
#          6.04395522]),
#  <BarContainer object of 10 artists>)

# %%
from scipy import stats
stats.probplot(diff_res_CU, plot=plt, dist='norm');

# %%
stats.shapiro(diff_res_CU)
# Out:
# ShapiroResult(statistic=0.857742190361023, pvalue=1.8195542850207858e-08)

# %%
Richard_SL=Richard[Richard.pitch_name=='Slider']
target=Richard_SL['release_spin_rate']
features=Richard_SL.drop('release_spin_rate',axis=1)
features=features.drop(['game_date', 'pitch_name'], axis=1)

visualizer = FeatureCorrelation(labels=list(features.columns))
visualizer.fit(features, target)
visualizer.poof()
# Out:
# <AxesSubplot:title={'center':'Features correlation with dependent variable'}, xlabel='Pearson Correlation'>

# %%
Richard_SL['game_date'] = pd.to_datetime(Richard_SL['game_date'])
Richard_SL_sample_yes = Richard_SL[Richard_SL.game_date >= '2021/6/11' ]
Richard_SL_sample_no = Richard_SL[Richard_SL.game_date <= '2021/6/11' ]
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_15896/247654268.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Richard_SL['game_date'] = pd.to_datetime(Richard_SL['game_date'])

# %%
#collapse-output
Richard_SL_sample_yes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 346 entries, 2152 to 2767
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   game_date          346 non-null    datetime64[ns]
#  1   release_speed      346 non-null    float64
#  2   release_pos_x      346 non-null    float64
#  3   release_pos_z      346 non-null    float64
#  4   zone               346 non-null    int64
#  5   pfx_x              346 non-null    float64
#  6   pfx_z              346 non-null    float64
#  7   plate_x            346 non-null    float64
#  8   plate_z            346 non-null    float64
#  9   vx0                346 non-null    float64
#  10  vy0                346 non-null    float64
#  11  vz0                346 non-null    float64
#  12  ax                 346 non-null    float64
#  13  ay                 346 non-null    float64
#  14  az                 346 non-null    float64
#  15  sz_top             346 non-null    float64
#  16  sz_bot             346 non-null    float64
#  17  release_spin_rate  346 non-null    int64
#  18  pitch_name         346 non-null    object
# dtypes: datetime64[ns](1), float64(15), int64(2), object(1)
# memory usage: 54.1+ KB

# %%
#collapse-output
Richard_SL_sample_no.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1293 entries, 2 to 2182
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   game_date          1293 non-null   datetime64[ns]
#  1   release_speed      1293 non-null   float64
#  2   release_pos_x      1293 non-null   float64
#  3   release_pos_z      1293 non-null   float64
#  4   zone               1293 non-null   int64
#  5   pfx_x              1293 non-null   float64
#  6   pfx_z              1293 non-null   float64
#  7   plate_x            1293 non-null   float64
#  8   plate_z            1293 non-null   float64
#  9   vx0                1293 non-null   float64
#  10  vy0                1293 non-null   float64
#  11  vz0                1293 non-null   float64
#  12  ax                 1293 non-null   float64
#  13  ay                 1293 non-null   float64
#  14  az                 1293 non-null   float64
#  15  sz_top             1293 non-null   float64
#  16  sz_bot             1293 non-null   float64
#  17  release_spin_rate  1293 non-null   int64
#  18  pitch_name         1293 non-null   object
# dtypes: datetime64[ns](1), float64(15), int64(2), object(1)
# memory usage: 202.0+ KB

# %%
Richard_SL_sample_no = Richard_SL_sample_no.sample(346)
from sklearn.preprocessing import scale
diff_res_SL = scale(np.array(Richard_SL_sample_yes['release_spin_rate']) - np.array(Richard_SL_sample_no['release_spin_rate']))
plt.hist(diff_res_SL)
# Out:
# (array([  3.,  45., 139., 123.,  26.,   8.,   0.,   0.,   1.,   1.]),
#  array([-2.94096147, -1.94777663, -0.9545918 ,  0.03859304,  1.03177787,
#          2.02496271,  3.01814755,  4.01133238,  5.00451722,  5.99770205,
#          6.99088689]),
#  <BarContainer object of 10 artists>)

# %%
stats.probplot(diff_res_SL, plot=plt, dist='norm');

# %%
stats.shapiro(diff_res_SL)
# Out:
# ShapiroResult(statistic=0.9047053456306458, pvalue=6.076124439745659e-14)

# %% [markdown]
# The result tells me that the crackdown affects Parrett Richard a lot, which hints he use substances to improve his performance (even we do not have any proof).

# %% [markdown]
# ## Discussion for Chapter 2:

# %% [markdown]
# ### Data resources in chapter 2
#
# 2. [MLB offical: Baseball Savant](https://baseballsavant.mlb.com/#)  (website click right-top **'Search':** players game-by-game data)

# %% [markdown]
# ### Max Scherzer

# %% [markdown]
# Let's use Mac Scherzer as a good example to explain why he is the historically expensive pitcher in the next MLB season.

# %%
#collapse-output
Scherzer_spin = pd.read_csv('MLB_data/Scherzer, Max.csv')
Scherzer = Scherzer_spin[['game_date', 'release_speed', 'release_pos_x', 'release_pos_z', 'zone',
                    'pfx_x', 'pfx_z', 'plate_x', 'plate_z', 'vx0', 'vy0', 'vz0', 'ax',
                    'ay', 'az', 'sz_top', 'sz_bot', 'release_spin_rate',
                    'pitch_name','description']]
Scherzer
# Out:
#        game_date  release_speed  release_pos_x  release_pos_z  zone  pfx_x  \
# 0      2021/9/29           94.3          -3.23           5.43     1  -1.22
# 1      2021/9/29           84.8          -3.51           5.33     4  -0.03
# 2      2021/9/29           84.7          -3.35           5.38     7  -0.16
# 3      2021/9/29           76.4          -3.25           5.67     8   1.57
# 4      2021/9/29           76.2          -3.30           5.59    14   1.55
# ...          ...            ...            ...            ...   ...    ...
# 13184   2017/4/7           94.2          -3.34           5.38    12  -0.83
# 13185   2017/4/7           94.1          -3.47           5.15    13  -0.74
# 13186   2017/4/7           93.5          -3.42           5.40     2  -0.75
# 13187   2017/4/7           77.6          -3.31           5.67     9   0.71
# 13188   2017/4/7           91.6          -3.44           5.20     1  -0.86
#
#        pfx_z  plate_x  plate_z        vx0         vy0       vz0         ax  \
# 0       1.44    -0.37     3.24  10.132657 -136.967197 -3.168637 -17.601606
# 1       0.52    -0.72     2.62   6.597895 -123.444921 -1.129416  -1.452731
# 2       0.39    -0.78     1.42   6.321524 -123.306763 -3.801182  -2.714680
# 3      -0.72    -0.20     2.02   3.592251 -111.142131  0.687360  12.222095
# 4      -0.80     0.38     1.41   4.941512 -110.878202 -0.261218  11.830963
# ...      ...      ...      ...        ...         ...       ...        ...
# 13184   1.10     0.40     4.04  11.416307 -136.746093 -0.201875 -12.636431
# 13185   1.65    -0.86     2.11   8.315552 -136.675038 -5.706973 -11.004539
# 13186   1.61     0.23     2.70  10.895626 -135.617949 -4.592762 -11.470193
# 13187  -0.09     0.42     1.90   6.579602 -112.701645 -0.963601   4.662083
# 13188   1.24    -0.38     3.02   9.465158 -133.121921 -2.280748 -11.975877
#
#               ay         az  sz_top  sz_bot  release_spin_rate  \
# 0      30.075797 -13.539700    3.49    1.60               2486
# 1      20.644158 -26.818383    3.49    1.60               2439
# 2      19.708060 -27.733389    3.33    1.49               2365
# 3      21.629237 -38.465115    3.41    1.56               2790
# 4      20.817331 -38.910171    3.39    1.61               2742
# ...          ...        ...     ...     ...                ...
# 13184  27.509813 -18.711674    3.24    1.44               2675
# 13185  31.538402 -10.714389    3.24    1.44               2672
# 13186  30.262485 -11.912889    3.24    1.44               2560
# 13187  20.427438 -33.007944    3.30    1.55               2572
# 13188  26.504329 -17.317706    3.30    1.55               2512
#
#             pitch_name      description
# 0      4-Seam Fastball    hit_into_play
# 1               Slider  swinging_strike
# 2               Slider    called_strike
# 3            Curveball    hit_into_play
# 4            Curveball    called_strike
# ...                ...              ...
# 13184  4-Seam Fastball             ball
# 13185  4-Seam Fastball             foul
# 13186  4-Seam Fastball    called_strike
# 13187        Curveball    hit_into_play
# 13188  4-Seam Fastball    called_strike
#
# [13189 rows x 20 columns]

# %%
Scherzer.pitch_name.value_counts()
# Out:
# 4-Seam Fastball    6378
# Slider             2441
# Changeup           1998
# Cutter             1158
# Curveball          1125
# Sinker               89
# Name: pitch_name, dtype: int64

# %%
plt.figure(figsize=(8,5))
plt.pie(Scherzer.pitch_name.value_counts(), labels = Scherzer.pitch_name.value_counts().keys())
plt.show()

# %% [markdown]
# Line chart tells me the speed did not drop, but I want to do linear regression to do further check

# %%
#collapse-output
Scherzer.sort_values(by=['game_date']).groupby('pitch_name').plot(x='game_date', y='release_spin_rate')
# Out:
# pitch_name
# 4-Seam Fastball    AxesSubplot(0.125,0.125;0.775x0.755)
# Changeup           AxesSubplot(0.125,0.125;0.775x0.755)
# Curveball          AxesSubplot(0.125,0.125;0.775x0.755)
# Cutter             AxesSubplot(0.125,0.125;0.775x0.755)
# Sinker             AxesSubplot(0.125,0.125;0.775x0.755)
# Slider             AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
sns.lmplot(data=Scherzer[Scherzer.pitch_name=='Slider'], x='release_speed', y='release_spin_rate')

# %% [markdown]
# The Spin rate has a very low correlation with speed

# %%
Scherzer_FF=Scherzer[Scherzer.pitch_name=='4-Seam Fastball']
target=Scherzer_FF['release_spin_rate']
features=Scherzer_FF.drop('release_spin_rate',axis=1)
features=features.drop(['game_date', 'pitch_name','description'], axis=1)

visualizer = FeatureCorrelation(labels=list(features.columns))
visualizer.fit(features, target)
visualizer.poof()
# Out:
# <AxesSubplot:title={'center':'Features correlation with dependent variable'}, xlabel='Pearson Correlation'>

# %% [markdown]
# Scherzer's fastball speed has an average speed: 94 miles: not to fast, not to slow, and his slider's speed is 85 miles, but when compared to Richard's speed. Richard obvious has a better speed.

# %%
#collapse-output
Scherzer.groupby('pitch_name').describe()
# Out:
#                 release_speed                                                 \
#                         count       mean       std   min   25%   50%     75%
# pitch_name
# 4-Seam Fastball        6378.0  94.404343  1.266766  87.3  93.6  94.4  95.300
# Changeup               1998.0  84.466867  1.330680  77.3  83.6  84.5  85.400
# Curveball              1125.0  77.662489  1.577781  72.0  76.5  77.7  78.700
# Cutter                 1158.0  89.317444  1.451405  85.3  88.2  89.3  90.375
# Sinker                   89.0  93.451685  1.205679  90.1  92.8  93.4  94.200
# Slider                 2441.0  85.543466  1.217825  79.7  84.7  85.6  86.400
#
#                       release_pos_x            ...  sz_bot        \
#                   max         count      mean  ...     75%   max
# pitch_name                                     ...
# 4-Seam Fastball  98.4        6378.0 -3.422792  ...  1.6600  2.22
# Changeup         89.9        1998.0 -3.423123  ...  1.6400  2.11
# Curveball        81.9        1125.0 -3.284907  ...  1.6400  2.09
# Cutter           93.9        1158.0 -3.492090  ...  1.6275  2.04
# Sinker           97.1          89.0 -3.417303  ...  1.6700  2.00
# Slider           90.0        2441.0 -3.478099  ...  1.6600  2.18
#
#                 release_spin_rate                                           \
#                             count         mean         std     min     25%
# pitch_name
# 4-Seam Fastball            6378.0  2475.888053  108.998971   720.0  2415.0
# Changeup                   1998.0  1485.250250  195.603142  1082.0  1378.0
# Curveball                  1125.0  2616.734222  157.158661  1312.0  2511.0
# Cutter                     1158.0  2459.363558  122.835021   826.0  2384.0
# Sinker                       89.0  2485.640449  115.702130  2183.0  2419.0
# Slider                     2441.0  2359.499795  137.040616  1200.0  2278.0
#
#
#                     50%      75%     max
# pitch_name
# 4-Seam Fastball  2479.0  2542.00  3590.0
# Changeup         1461.0  1553.75  3383.0
# Curveball        2612.0  2733.00  3075.0
# Cutter           2457.0  2535.00  3146.0
# Sinker           2468.0  2551.00  2791.0
# Slider           2364.0  2446.00  2890.0
#
# [6 rows x 136 columns]

# %%
#collapse-output
Richard.groupby('pitch_name').describe()
# Out:
#            release_speed                                                       \
#                    count       mean       std   min     25%   50%   75%   max
# pitch_name
# Changeup           174.0  90.946552  1.634196  86.9  90.025  90.7  91.6  96.7
# Curveball          533.0  79.320638  2.616501  63.5  78.200  79.8  80.9  86.1
# Sinker             443.0  95.756433  1.045427  90.3  95.100  95.8  96.5  98.7
# Slider            1618.0  88.605130  1.376386  83.5  87.800  88.7  89.5  92.1
#
#            release_pos_x            ... sz_bot       release_spin_rate  \
#                    count      mean  ...    75%   max             count
# pitch_name                          ...
# Changeup           174.0 -2.514253  ...   1.62  1.85             174.0
# Curveball          533.0 -1.977298  ...   1.60  1.88             533.0
# Sinker             443.0 -2.157133  ...   1.63  1.94             443.0
# Slider            1618.0 -2.242553  ...   1.63  1.93            1618.0
#
#
#                    mean         std     min     25%     50%      75%     max
# pitch_name
# Changeup    1770.385057  298.541786  1311.0  1591.0  1716.5  1849.75  2794.0
# Curveball   3198.968105  302.154956  1052.0  3066.0  3255.0  3387.00  3722.0
# Sinker      2563.790068  118.816558  1256.0  2499.5  2566.0  2635.00  2894.0
# Slider      2841.171199  191.727465   819.0  2768.0  2885.0  2955.00  3504.0
#
# [4 rows x 136 columns]

# %%
Scherzer_sample_yes = Scherzer[Scherzer.game_date >= '2021/6/11' ]
Scherzer_sample_no = Scherzer[Scherzer.game_date <= '2021/6/11' ]

# %% [markdown]
# when I group by pitch name to do separation, the speed of different pitch types has no different from before the crackdown, and after the crackdown, that gives me a hint: it shows no difference, but I still need to do a T-test check.

# %% [markdown]
# For ```'Slider'``` in Max Schrezer, spin rate also has a ```150rpm``` drop, but ```'Slider's'``` speed did not have any change.

# %%
#collapse-output
Scherzer_sample_yes.groupby('pitch_name').describe()
# Out:
#                 release_speed                                               \
#                         count       mean       std   min   25%   50%   75%
# pitch_name
# 4-Seam Fastball         792.0  94.499369  1.143038  91.0  93.7  94.5  95.3
# Changeup                269.0  84.951673  1.097949  82.6  84.1  84.9  85.7
# Curveball               191.0  76.978010  1.345495  73.9  76.0  77.0  78.0
# Cutter                  145.0  90.479310  0.911035  88.2  89.9  90.4  91.2
# Slider                  346.0  85.983526  1.236658  83.0  85.2  85.9  86.7
#
#                       release_pos_x            ...  sz_bot        \
#                   max         count      mean  ...     75%   max
# pitch_name                                     ...
# 4-Seam Fastball  98.0         792.0 -3.252273  ...  1.6300  2.04
# Changeup         89.0         269.0 -3.301896  ...  1.6300  1.89
# Curveball        80.6         191.0 -3.240628  ...  1.6300  1.90
# Cutter           92.7         145.0 -3.361586  ...  1.6100  1.82
# Slider           90.0         346.0 -3.361532  ...  1.6075  1.94
#
#                 release_spin_rate                                            \
#                             count         mean         std     min      25%
# pitch_name
# 4-Seam Fastball             792.0  2406.580808  105.204171  1209.0  2351.75
# Changeup                    269.0  1433.003717  125.147301  1090.0  1352.00
# Curveball                   191.0  2640.387435  126.306839  2378.0  2545.50
# Cutter                      145.0  2441.820690  119.783872  2131.0  2375.00
# Slider                      346.0  2228.312139  123.325048  1924.0  2142.25
#
#
#                     50%     75%     max
# pitch_name
# 4-Seam Fastball  2413.0  2472.0  2713.0
# Changeup         1425.0  1514.0  1795.0
# Curveball        2635.0  2727.0  3075.0
# Cutter           2443.0  2510.0  2786.0
# Slider           2222.5  2298.0  2890.0
#
# [5 rows x 136 columns]

# %%
#collapse-output
Scherzer_sample_no.groupby('pitch_name').describe()
# Out:
#                 release_speed                                               \
#                         count       mean       std   min   25%   50%   75%
# pitch_name
# 4-Seam Fastball        5593.0  94.391221  1.282351  87.3  93.6  94.4  95.3
# Changeup               1729.0  84.391440  1.348004  77.3  83.5  84.4  85.3
# Curveball               936.0  77.802030  1.584317  72.0  76.7  77.9  78.9
# Cutter                 1016.0  89.154035  1.438035  85.3  88.1  89.0  90.1
# Sinker                   89.0  93.451685  1.205679  90.1  92.8  93.4  94.2
# Slider                 2095.0  85.470788  1.199545  79.7  84.7  85.5  86.3
#
#                       release_pos_x            ... sz_bot        \
#                   max         count      mean  ...    75%   max
# pitch_name                                     ...
# 4-Seam Fastball  98.4        5593.0 -3.446480  ...   1.66  2.22
# Changeup         89.9        1729.0 -3.441984  ...   1.65  2.11
# Curveball        81.9         936.0 -3.293462  ...   1.65  2.09
# Cutter           93.9        1016.0 -3.509774  ...   1.63  2.04
# Sinker           97.1          89.0 -3.417303  ...   1.67  2.00
# Slider           89.5        2095.0 -3.497351  ...   1.66  2.18
#
#                 release_spin_rate                                           \
#                             count         mean         std     min     25%
# pitch_name
# 4-Seam Fastball            5593.0  2485.569462  105.947057   720.0  2426.0
# Changeup                   1729.0  1493.378832  203.215601  1082.0  1386.0
# Curveball                   936.0  2611.483974  162.457879  1312.0  2499.0
# Cutter                     1016.0  2461.618110  123.414077   826.0  2385.0
# Sinker                       89.0  2485.640449  115.702130  2183.0  2419.0
# Slider                     2095.0  2381.166110  126.744194  1200.0  2304.0
#
#
#                     50%      75%     max
# pitch_name
# 4-Seam Fastball  2488.0  2550.00  3590.0
# Changeup         1465.0  1560.00  3383.0
# Curveball        2607.5  2738.00  3052.0
# Cutter           2459.0  2537.25  3146.0
# Sinker           2468.0  2551.00  2791.0
# Slider           2380.0  2458.00  2860.0
#
# [6 rows x 136 columns]

# %%
Scherzer_FF = Scherzer[Scherzer.pitch_name=='4-Seam Fastball']
Scherzer_FF['game_date'] = pd.to_datetime(Scherzer_FF['game_date'])
Scherzer_FF_sample_yes = Scherzer_FF[Scherzer_FF.game_date >= '2021/6/11' ]
Scherzer_FF_sample_no = Scherzer_FF[Scherzer_FF.game_date <= '2021/6/11' ]
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_15896/1874349604.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Scherzer_FF['game_date'] = pd.to_datetime(Scherzer_FF['game_date'])

# %%
Scherzer_FF_sample_yes.describe()
# Out:
#        release_speed  release_pos_x  release_pos_z        zone       pfx_x  \
# count     745.000000     745.000000     745.000000  745.000000  745.000000
# mean       94.495705      -3.256094       5.556483    8.057718   -0.875664
# std         1.150588       0.106993       0.181792    4.230350    0.169915
# min        91.000000      -3.640000       5.010000    1.000000   -1.380000
# 25%        93.700000      -3.330000       5.430000    5.000000   -0.990000
# 50%        94.400000      -3.260000       5.550000    8.000000   -0.870000
# 75%        95.300000      -3.190000       5.690000   12.000000   -0.760000
# max        98.000000      -2.920000       6.110000   14.000000   -0.350000
#
#             pfx_z     plate_x     plate_z         vx0         vy0         vz0  \
# count  745.000000  745.000000  745.000000  745.000000  745.000000  745.000000
# mean     1.311517   -0.042752    2.587262   10.271343 -137.195640   -4.948704
# std      0.124655    0.796537    0.748365    1.960802    1.698820    1.956341
# min      0.880000   -2.380000    0.350000    4.802991 -142.631237  -11.498531
# 25%      1.230000   -0.590000    2.060000    8.911569 -138.376692   -6.246831
# 50%      1.320000   -0.030000    2.560000   10.367215 -137.195206   -4.986283
# 75%      1.400000    0.510000    3.090000   11.655298 -135.991172   -3.616196
# max      1.620000    2.390000    4.940000   15.319383 -132.346837    1.046368
#
#                ax          ay          az      sz_top      sz_bot  \
# count  745.000000  745.000000  745.000000  745.000000  745.000000
# mean   -13.274291   29.436520  -14.646069    3.415383    1.582094
# std      2.125472    2.175982    1.744762    0.151443    0.085521
# min    -19.436436   23.288041  -20.517921    2.770000    1.210000
# 25%    -14.663478   28.051571  -15.770594    3.320000    1.530000
# 50%    -13.261311   29.501614  -14.642746    3.410000    1.590000
# 75%    -11.850431   30.891496  -13.468253    3.490000    1.620000
# max     -7.040388   37.293146  -10.184651    4.100000    2.040000
#
#        release_spin_rate
# count         745.000000
# mean         2400.446980
# std           103.934883
# min          1209.000000
# 25%          2347.000000
# 50%          2405.000000
# 75%          2467.000000
# max          2713.000000

# %%
Scherzer_FF_sample_no.describe()
# Out:
#        release_speed  release_pos_x  release_pos_z         zone        pfx_x  \
# count    5640.000000    5640.000000    5640.000000  5640.000000  5640.000000
# mean       94.392606      -3.444356       5.267551     7.777837    -0.905950
# std         1.280438       0.211812       0.253049     4.249712     0.233886
# min        87.300000      -4.100000       4.610000     1.000000    -1.690000
# 25%        93.600000      -3.610000       5.070000     4.000000    -1.070000
# 50%        94.400000      -3.460000       5.250000     8.000000    -0.910000
# 75%        95.300000      -3.290000       5.460000    12.000000    -0.760000
# max        98.400000      -2.850000       5.980000    14.000000     0.350000
#
#              pfx_z      plate_x      plate_z          vx0          vy0  \
# count  5640.000000  5640.000000  5640.000000  5640.000000  5640.000000
# mean      1.274209     0.022553     2.717507    10.920844  -136.907516
# std       0.223319     0.798437     0.721199     2.097769     1.900368
# min       0.370000    -3.020000     0.220000     3.672611  -142.791258
# 25%       1.140000    -0.500000     2.240000     9.463113  -138.229138
# 50%       1.250000     0.040000     2.700000    11.012167  -136.917466
# 75%       1.390000     0.570000     3.180000    12.376878  -135.653118
# max       2.640000     2.670000     5.960000    18.007005  -126.815079
#
#                vz0           ax           ay           az       sz_top  \
# count  5640.000000  5640.000000  5640.000000  5640.000000  5640.000000
# mean     -3.699934   -13.622231    29.117239   -15.691575     3.423520
# std       2.016524     3.001428     2.004680     2.894323     0.223544
# min     -10.864936   -23.159661    21.819083   -27.975373     2.790000
# 25%      -5.047852   -15.683404    27.753667   -17.530280     3.280000
# 50%      -3.709394   -13.766304    29.034300   -15.880861     3.410000
# 75%      -2.352521   -11.750073    30.405740   -14.095668     3.550000
# max       5.254412     2.100107    38.137392     1.103051     4.500000
#
#             sz_bot  release_spin_rate
# count  5640.000000        5640.000000
# mean      1.574949        2485.721454
# std       0.147825         105.723618
# min       1.070000         720.000000
# 25%       1.490000        2426.000000
# 50%       1.580000        2488.000000
# 75%       1.660000        2550.000000
# max       2.220000        3590.000000

# %%
#collapse-output
Scherzer_FF_sample_yes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 745 entries, 0 to 1634
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   game_date          745 non-null    datetime64[ns]
#  1   release_speed      745 non-null    float64
#  2   release_pos_x      745 non-null    float64
#  3   release_pos_z      745 non-null    float64
#  4   zone               745 non-null    int64
#  5   pfx_x              745 non-null    float64
#  6   pfx_z              745 non-null    float64
#  7   plate_x            745 non-null    float64
#  8   plate_z            745 non-null    float64
#  9   vx0                745 non-null    float64
#  10  vy0                745 non-null    float64
#  11  vz0                745 non-null    float64
#  12  ax                 745 non-null    float64
#  13  ay                 745 non-null    float64
#  14  az                 745 non-null    float64
#  15  sz_top             745 non-null    float64
#  16  sz_bot             745 non-null    float64
#  17  release_spin_rate  745 non-null    int64
#  18  pitch_name         745 non-null    object
#  19  description        745 non-null    object
# dtypes: datetime64[ns](1), float64(15), int64(2), object(2)
# memory usage: 122.2+ KB

# %%
#collapse-output
Scherzer_FF_sample_no.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5640 entries, 1623 to 13188
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   game_date          5640 non-null   datetime64[ns]
#  1   release_speed      5640 non-null   float64
#  2   release_pos_x      5640 non-null   float64
#  3   release_pos_z      5640 non-null   float64
#  4   zone               5640 non-null   int64
#  5   pfx_x              5640 non-null   float64
#  6   pfx_z              5640 non-null   float64
#  7   plate_x            5640 non-null   float64
#  8   plate_z            5640 non-null   float64
#  9   vx0                5640 non-null   float64
#  10  vy0                5640 non-null   float64
#  11  vz0                5640 non-null   float64
#  12  ax                 5640 non-null   float64
#  13  ay                 5640 non-null   float64
#  14  az                 5640 non-null   float64
#  15  sz_top             5640 non-null   float64
#  16  sz_bot             5640 non-null   float64
#  17  release_spin_rate  5640 non-null   int64
#  18  pitch_name         5640 non-null   object
#  19  description        5640 non-null   object
# dtypes: datetime64[ns](1), float64(15), int64(2), object(2)
# memory usage: 925.3+ KB

# %%
Scherzer_FF_sample_no = Scherzer_FF_sample_no.sample(745)
diff_res = scale(np.array(Scherzer_FF_sample_yes['release_spin_rate']) - np.array(Scherzer_FF_sample_no['release_spin_rate']))
plt.hist(diff_res)
# Out:
# (array([  1.,   2.,   0.,  12., 301., 410.,  17.,   1.,   0.,   1.]),
#  array([-8.70720314, -6.99445343, -5.28170372, -3.56895401, -1.85620431,
#         -0.1434546 ,  1.56929511,  3.28204482,  4.99479453,  6.70754423,
#          8.42029394]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# The QQ plot meets the predicted line and the P-value>>0.5, there is no significance !!

# %%
stats.probplot(diff_res, plot=plt, dist='norm');

# %%
stats.levene(Scherzer_FF_sample_yes['release_spin_rate'], Scherzer_FF_sample_no['release_spin_rate'])
# Out:
# LeveneResult(statistic=0.5270861574355994, pvalue=0.4679486566393123)

# %%
Scherzer_SL = Scherzer[Scherzer.pitch_name=='Slider']
Scherzer_SL['game_date'] = pd.to_datetime(Scherzer_SL['game_date'])
Scherzer_SL_sample_yes = Scherzer_SL[Scherzer_SL.game_date >= '2021/6/11' ]
Scherzer_SL_sample_no = Scherzer_SL[Scherzer_SL.game_date <= '2021/6/11' ]
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_15896/3618280002.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Scherzer_SL['game_date'] = pd.to_datetime(Scherzer_SL['game_date'])

# %%
#collapse-output
Scherzer_SL_sample_yes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 319 entries, 1 to 1615
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   game_date          319 non-null    datetime64[ns]
#  1   release_speed      319 non-null    float64
#  2   release_pos_x      319 non-null    float64
#  3   release_pos_z      319 non-null    float64
#  4   zone               319 non-null    int64
#  5   pfx_x              319 non-null    float64
#  6   pfx_z              319 non-null    float64
#  7   plate_x            319 non-null    float64
#  8   plate_z            319 non-null    float64
#  9   vx0                319 non-null    float64
#  10  vy0                319 non-null    float64
#  11  vz0                319 non-null    float64
#  12  ax                 319 non-null    float64
#  13  ay                 319 non-null    float64
#  14  az                 319 non-null    float64
#  15  sz_top             319 non-null    float64
#  16  sz_bot             319 non-null    float64
#  17  release_spin_rate  319 non-null    int64
#  18  pitch_name         319 non-null    object
#  19  description        319 non-null    object
# dtypes: datetime64[ns](1), float64(15), int64(2), object(2)
# memory usage: 52.3+ KB

# %%
#collapse-output
Scherzer_SL_sample_no.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2122 entries, 1642 to 13182
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   game_date          2122 non-null   datetime64[ns]
#  1   release_speed      2122 non-null   float64
#  2   release_pos_x      2122 non-null   float64
#  3   release_pos_z      2122 non-null   float64
#  4   zone               2122 non-null   int64
#  5   pfx_x              2122 non-null   float64
#  6   pfx_z              2122 non-null   float64
#  7   plate_x            2122 non-null   float64
#  8   plate_z            2122 non-null   float64
#  9   vx0                2122 non-null   float64
#  10  vy0                2122 non-null   float64
#  11  vz0                2122 non-null   float64
#  12  ax                 2122 non-null   float64
#  13  ay                 2122 non-null   float64
#  14  az                 2122 non-null   float64
#  15  sz_top             2122 non-null   float64
#  16  sz_bot             2122 non-null   float64
#  17  release_spin_rate  2122 non-null   int64
#  18  pitch_name         2122 non-null   object
#  19  description        2122 non-null   object
# dtypes: datetime64[ns](1), float64(15), int64(2), object(2)
# memory usage: 348.1+ KB

# %%
Scherzer_SL_sample_no = Scherzer_SL_sample_no.sample(319)
diff_res = scale(np.array(Scherzer_FF_sample_yes['release_spin_rate']) - np.array(Scherzer_FF_sample_no['release_spin_rate']))
plt.hist(diff_res)
# Out:
# (array([  1.,   2.,   0.,  12., 301., 410.,  17.,   1.,   0.,   1.]),
#  array([-8.70720314, -6.99445343, -5.28170372, -3.56895401, -1.85620431,
#         -0.1434546 ,  1.56929511,  3.28204482,  4.99479453,  6.70754423,
#          8.42029394]),
#  <BarContainer object of 10 artists>)

# %%
stats.probplot(diff_res, plot=plt, dist='norm');

# %%
stats.levene(Scherzer_SL_sample_yes['release_spin_rate'], Scherzer_SL_sample_no['release_spin_rate'])
# Out:
# LeveneResult(statistic=2.8512470791725093, pvalue=0.09179328092653344)

# %%
#collapse-output
Scherzer.groupby('pitch_name').hist(bins=50, figsize=(20,15))
plt.show()

# %%
import matplotlib.image as mpimg
import os
Strike_Zone_img=mpimg.imread('MLB_data/Strike_Zone.png')
ax = Scherzer_FF[Scherzer_FF.description =='ball'].plot(kind="scatter", x="release_pos_x", y="release_pos_z", figsize=(10,10),
                  label="ball",
                  cmap=plt.get_cmap("cool"),
                  colorbar=False, alpha=0.6)
plt.imshow(Strike_Zone_img, extent=[-4.0, -2.8, 4.6, 6.2], alpha=0.5,
           cmap=plt.get_cmap("cool"))
plt.ylabel("x axis", fontsize=14)
plt.xlabel("y axis", fontsize=14)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# Text(0.5, 0, 'y axis')

# %% [markdown]
# ## Discussion for Chapter 3:

# %% [markdown]
# ### Data resources in chapter 3
#
# 1. [MLB offical: Baseball Savant](https://baseballsavant.mlb.com/#)  (website click right-top **'Statistics':** players' historical data)

# %% [markdown]
# ### Analysis

# %%
#collapse-output
df=pd.read_csv('MLB_data/MLB pitchers.csv')
df
# Out:
#      last_name first_name  player_id  year  p_era    xba   xslg  xwoba   xobp  \
# 0        Colon    Bartolo   112526.0  2018   5.78  0.301  0.528  0.365  0.329
# 1      Belisle       Matt   279571.0  2018   7.86  0.281  0.478  0.356  0.345
# 2     Sabathia         CC   282332.0  2018   3.65  0.219  0.351  0.288  0.293
# 3     DeLaRosa      Jorge   407822.0  2018   3.38  0.250  0.376  0.319  0.343
# 4       Rodney   Fernando   407845.0  2018   3.36  0.236  0.363  0.310  0.330
# ...        ...        ...        ...   ...    ...    ...    ...    ...    ...
# 9044       Ryu     JaeKuk        NaN  2006   8.40    NaN    NaN    NaN    NaN
# 9045    Hansen      Craig        NaN  2006   6.63    NaN    NaN    NaN    NaN
# 9046     Garza       Matt        NaN  2006   5.76    NaN    NaN    NaN    NaN
# 9047    Moylan      Peter        NaN  2006   4.80    NaN    NaN    NaN    NaN
# 9048     Saito    Takashi        NaN  2006   2.07    NaN    NaN    NaN    NaN
#
#        xiso  exit_velocity_avg  launch_angle_avg  barrel_batted_rate
# 0     0.227               89.6              11.8                 7.7
# 1     0.197               89.3              10.8                 7.3
# 2     0.132               84.8              13.0                 5.2
# 3     0.126               89.7              11.5                 4.8
# 4     0.127               87.4               9.8                 5.6
# ...     ...                ...               ...                 ...
# 9044    NaN                NaN               NaN                 NaN
# 9045    NaN                NaN               NaN                 NaN
# 9046    NaN                NaN               NaN                 NaN
# 9047    NaN                NaN               NaN                 NaN
# 9048    NaN                NaN               NaN                 NaN
#
# [9049 rows x 13 columns]

# %% [markdown]
# **Create** a column to storage players' name

# %%
#collapse-output
df.insert(2, 'name', df['first_name'] +'_'+ df.last_name)
df
# Out:
#      last_name first_name             name  player_id  year  p_era    xba  \
# 0        Colon    Bartolo    Bartolo_Colon   112526.0  2018   5.78  0.301
# 1      Belisle       Matt     Matt_Belisle   279571.0  2018   7.86  0.281
# 2     Sabathia         CC      CC_Sabathia   282332.0  2018   3.65  0.219
# 3     DeLaRosa      Jorge   Jorge_DeLaRosa   407822.0  2018   3.38  0.250
# 4       Rodney   Fernando  Fernando_Rodney   407845.0  2018   3.36  0.236
# ...        ...        ...              ...        ...   ...    ...    ...
# 9044       Ryu     JaeKuk       JaeKuk_Ryu        NaN  2006   8.40    NaN
# 9045    Hansen      Craig     Craig_Hansen        NaN  2006   6.63    NaN
# 9046     Garza       Matt       Matt_Garza        NaN  2006   5.76    NaN
# 9047    Moylan      Peter     Peter_Moylan        NaN  2006   4.80    NaN
# 9048     Saito    Takashi    Takashi_Saito        NaN  2006   2.07    NaN
#
#        xslg  xwoba   xobp   xiso  exit_velocity_avg  launch_angle_avg  \
# 0     0.528  0.365  0.329  0.227               89.6              11.8
# 1     0.478  0.356  0.345  0.197               89.3              10.8
# 2     0.351  0.288  0.293  0.132               84.8              13.0
# 3     0.376  0.319  0.343  0.126               89.7              11.5
# 4     0.363  0.310  0.330  0.127               87.4               9.8
# ...     ...    ...    ...    ...                ...               ...
# 9044    NaN    NaN    NaN    NaN                NaN               NaN
# 9045    NaN    NaN    NaN    NaN                NaN               NaN
# 9046    NaN    NaN    NaN    NaN                NaN               NaN
# 9047    NaN    NaN    NaN    NaN                NaN               NaN
# 9048    NaN    NaN    NaN    NaN                NaN               NaN
#
#       barrel_batted_rate
# 0                    7.7
# 1                    7.3
# 2                    5.2
# 3                    4.8
# 4                    5.6
# ...                  ...
# 9044                 NaN
# 9045                 NaN
# 9046                 NaN
# 9047                 NaN
# 9048                 NaN
#
# [9049 rows x 14 columns]

# %% [markdown]
# Arranged data by year: from old to new

# %%
df.sort_values(by=['year'])
# Out:
#         last_name first_name                name  player_id  year  p_era  \
# 9048        Saito    Takashi       Takashi_Saito        NaN  2006   2.07
# 8683     Franklin       Ryan       Ryan_Franklin        NaN  2006   4.54
# 8684    MacDougal       Mike      Mike_MacDougal        NaN  2006   1.55
# 8685       Weaver       Jeff         Jeff_Weaver        NaN  2006   5.76
# 8686       Snyder       Kyle         Kyle_Snyder        NaN  2006   6.56
# ...           ...        ...                 ...        ...   ...    ...
# 3084  PoncedeLeon     Daniel  Daniel_PoncedeLeon   594965.0  2021   6.21
# 3085         Ryan       Kyle           Kyle_Ryan   594986.0  2021   6.75
# 3086       Sadler      Casey        Casey_Sadler   594987.0  2021   0.67
# 3089        Okert     Steven        Steven_Okert   595345.0  2021   2.75
# 2965    Armstrong      Shawn     Shawn_Armstrong   542888.0  2021   6.75
#
#         xba   xslg  xwoba   xobp   xiso  exit_velocity_avg  launch_angle_avg  \
# 9048    NaN    NaN    NaN    NaN    NaN                NaN               NaN
# 8683    NaN    NaN    NaN    NaN    NaN                NaN               NaN
# 8684    NaN    NaN    NaN    NaN    NaN                NaN               NaN
# 8685    NaN    NaN    NaN    NaN    NaN                NaN               NaN
# 8686    NaN    NaN    NaN    NaN    NaN                NaN               NaN
# ...     ...    ...    ...    ...    ...                ...               ...
# 3084  0.234  0.427  0.353  0.371  0.192               89.6              19.1
# 3085  0.314  0.474  0.368  0.381  0.159               89.8               0.6
# 3086  0.198  0.274  0.241  0.258  0.076               85.4               3.5
# 3089  0.173  0.341  0.274  0.283  0.168               86.8              24.9
# 2965  0.244  0.484  0.345  0.322  0.239               90.6              19.4
#
#       barrel_batted_rate
# 9048                 NaN
# 8683                 NaN
# 8684                 NaN
# 8685                 NaN
# 8686                 NaN
# ...                  ...
# 3084                 6.5
# 3085                 8.3
# 3086                 3.1
# 3089                 7.2
# 2965                14.4
#
# [9049 rows x 14 columns]

# %%
#collapse-output
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9049 entries, 0 to 9048
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   last_name           9049 non-null   object
#  1   first_name          9049 non-null   object
#  2   name                9049 non-null   object
#  3   player_id           4154 non-null   float64
#  4   year                9049 non-null   int64
#  5   p_era               9049 non-null   float64
#  6   xba                 4154 non-null   float64
#  7   xslg                4154 non-null   float64
#  8   xwoba               4154 non-null   float64
#  9   xobp                4154 non-null   float64
#  10  xiso                4154 non-null   float64
#  11  exit_velocity_avg   4154 non-null   float64
#  12  launch_angle_avg    4154 non-null   float64
#  13  barrel_batted_rate  4154 non-null   float64
# dtypes: float64(10), int64(1), object(3)
# memory usage: 989.9+ KB

# %% [markdown]
# Based on raw data, check players by year who have the longest career (data range: 2006 -2022):
# ya, Max Scherzer is not the **longest** one, but he is still playing now!!

# %%
df['name'].value_counts().head(26)
# Out:
# Jon_Lester             16
# Andrew_Miller          16
# Adam_Wainwright        15
# Zack_Greinke           15
# Ervin_Santana          15
# Anibal_Sanchez         15
# Sergio_Romo            14
# Justin_Verlander       14
# Charlie_Morton         14
# Johnny_Cueto           14
# Joe_Smith              14
# Clayton_Kershaw        14
# Ian_Kennedy            14
# Joakim_Soria           14
# Zach_Duke              14
# Max_Scherzer           14
# Tyler_Clippard         14
# Edwin_Jackson          14
# Cole_Hamels            14
# CC_Sabathia            14
# Fernando_Rodney        14
# Oliver_Perez           14
# J.A._Happ              14
# Francisco_Rodriguez    14
# Felix_Hernandez        14
# Wade_LeBlanc           13
# Name: name, dtype: int64

# %% [markdown]
# narrow down to players who have >=14 years careers in MLB

# %%
df['name'].value_counts()>=14
# Out:
# Jon_Lester          True
# Andrew_Miller       True
# Adam_Wainwright     True
# Zack_Greinke        True
# Ervin_Santana       True
#                    ...
# Justin_Thomas      False
# Robert_Manuel      False
# Logan_Gilbert      False
# Andy_Oliver        False
# Sendy_Rleal        False
# Name: name, Length: 2317, dtype: bool

# %% [markdown]
# Total 2292 players, only **25** players has >=14 years careers in MLB.

# %%
(df['name'].value_counts()>=14).value_counts()
# Out:
# False    2292
# True       25
# Name: name, dtype: int64

# %% [markdown]
# re-arrange data to the top 25 players

# %%
#collapse-output
filt_value = ['Jon_Lester', 'Andrew_Miller', 'Adam_Wainwright', 'Zack_Greinke', 'Jon_Lester', 
              'Ervin_Santana', 'Anibal_Sanchez', 'Sergio_Romo', 'Justin_Verlander',  
              'Charlie_Morton', 'Johnny_Cueto', 'Joe_Smith', 'Clayton_Kershaw',  
              'Ian_Kennedy', 'Joakim_Soria', 'Zach_Duke', 'Max_Scherzer', 
              'Tyler_Clippard', 'Edwin_Jackson', 'Cole_Hamels', 'CC_Sabathia', 
              'Fernando_Rodney', 'Oliver_Perez', 'J.A._Happ', 'Francisco_Rodriguez', 
              'Felix_Hernandez']
filt = df['name'].isin(filt_value)
df2 = df.loc[filt]
df2
# Out:
#        last_name first_name              name  player_id  year  p_era    xba  \
# 2       Sabathia         CC       CC_Sabathia   282332.0  2018   3.65  0.219
# 4         Rodney   Fernando   Fernando_Rodney   407845.0  2018   3.36  0.236
# 5          Perez     Oliver      Oliver_Perez   424144.0  2018   1.39  0.172
# 7     Wainwright       Adam   Adam_Wainwright   425794.0  2018   4.46  0.232
# 8        Greinke       Zack      Zack_Greinke   425844.0  2018   3.21  0.245
# ...          ...        ...               ...        ...   ...    ...    ...
# 8926   Verlander     Justin  Justin_Verlander        NaN  2006   3.63    NaN
# 8943     Sanchez     Anibal    Anibal_Sanchez        NaN  2006   2.83    NaN
# 8952        Duke       Zach         Zach_Duke        NaN  2006   4.47    NaN
# 9010      Lester        Jon        Jon_Lester        NaN  2006   4.76    NaN
# 9013      Miller     Andrew     Andrew_Miller        NaN  2006   6.10    NaN
#
#        xslg  xwoba   xobp   xiso  exit_velocity_avg  launch_angle_avg  \
# 2     0.351  0.288  0.293  0.132               84.8              13.0
# 4     0.363  0.310  0.330  0.127               87.4               9.8
# 5     0.265  0.215  0.234  0.093               86.1              12.9
# 7     0.387  0.313  0.320  0.155               85.9              10.1
# 8     0.406  0.303  0.290  0.161               88.0              10.4
# ...     ...    ...    ...    ...                ...               ...
# 8926    NaN    NaN    NaN    NaN                NaN               NaN
# 8943    NaN    NaN    NaN    NaN                NaN               NaN
# 8952    NaN    NaN    NaN    NaN                NaN               NaN
# 9010    NaN    NaN    NaN    NaN                NaN               NaN
# 9013    NaN    NaN    NaN    NaN                NaN               NaN
#
#       barrel_batted_rate
# 2                    5.2
# 4                    5.6
# 5                    5.9
# 7                    6.6
# 8                    6.4
# ...                  ...
# 8926                 NaN
# 8943                 NaN
# 8952                 NaN
# 9010                 NaN
# 9013                 NaN
#
# [358 rows x 14 columns]

# %% [markdown]
# Check players who still in the MLB in **2021**: I do not want to include players who had already retired, it's not my point at this moment.
#
# only **15** players now are still alive in MLB

# %%
#collapse-output
filt2 = (df2['year'] == 2021)
df3 = df2.loc[filt2]
df3
# Out:
#        last_name first_name             name  player_id  year  p_era    xba  \
# 2863  Wainwright       Adam  Adam_Wainwright   425794.0  2021   3.05  0.251
# 2864     Greinke       Zack     Zack_Greinke   425844.0  2021   4.16  0.266
# 2865     Santana      Ervin    Ervin_Santana   429722.0  2021   4.68  0.278
# 2876      Morton    Charlie   Charlie_Morton   450203.0  2021   3.34  0.217
# 2879      Lester        Jon       Jon_Lester   452657.0  2021   4.71  0.274
# 2880     Kennedy        Ian      Ian_Kennedy   453178.0  2021   3.20  0.226
# 2881      Miller     Andrew    Andrew_Miller   453192.0  2021   4.75  0.241
# 2886    Scherzer        Max     Max_Scherzer   453286.0  2021   2.46  0.196
# 2891       Cueto     Johnny     Johnny_Cueto   456501.0  2021   4.08  0.278
# 2892        Happ       J.A.        J.A._Happ   457918.0  2021   5.79  0.275
# 2898    Clippard      Tyler   Tyler_Clippard   461325.0  2021   3.20  0.263
# 2900       Soria     Joakim     Joakim_Soria   465657.0  2021   5.06  0.245
# 2907     Kershaw    Clayton  Clayton_Kershaw   477132.0  2021   3.55  0.222
# 2910        Romo     Sergio      Sergio_Romo   489265.0  2021   4.67  0.218
# 2918       Smith        Joe        Joe_Smith   501925.0  2021   4.99  0.242
#
#        xslg  xwoba   xobp   xiso  exit_velocity_avg  launch_angle_avg  \
# 2863  0.388  0.302  0.305  0.137               88.2              10.0
# 2864  0.431  0.320  0.307  0.164               88.3              10.6
# 2865  0.533  0.369  0.339  0.255               90.2              13.8
# 2876  0.332  0.282  0.296  0.115               88.1               7.7
# 2879  0.454  0.344  0.342  0.180               88.3              10.4
# 2880  0.428  0.305  0.291  0.202               90.8              26.7
# 2881  0.411  0.333  0.340  0.170               86.3              10.1
# 2886  0.355  0.264  0.249  0.159               87.9              19.3
# 2891  0.452  0.339  0.329  0.174               88.4              14.1
# 2892  0.503  0.356  0.330  0.228               90.2              16.4
# 2898  0.507  0.366  0.355  0.244               88.1              23.5
# 2900  0.400  0.307  0.306  0.154               88.3              18.2
# 2907  0.373  0.275  0.261  0.151               88.1               9.8
# 2910  0.365  0.287  0.289  0.147               84.9              17.4
# 2918  0.389  0.291  0.289  0.147               87.9               9.5
#
#       barrel_batted_rate
# 2863                 6.2
# 2864                 6.5
# 2865                10.9
# 2876                 4.9
# 2879                 7.7
# 2880                 8.8
# 2881                 8.7
# 2886                 8.0
# 2891                 6.4
# 2892                11.6
# 2898                11.8
# 2900                 7.5
# 2907                 6.9
# 2910                 7.4
# 2918                 5.5

# %%
#collapse-output
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 2863 to 2918
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   last_name           15 non-null     object
#  1   first_name          15 non-null     object
#  2   name                15 non-null     object
#  3   player_id           15 non-null     float64
#  4   year                15 non-null     int64
#  5   p_era               15 non-null     float64
#  6   xba                 15 non-null     float64
#  7   xslg                15 non-null     float64
#  8   xwoba               15 non-null     float64
#  9   xobp                15 non-null     float64
#  10  xiso                15 non-null     float64
#  11  exit_velocity_avg   15 non-null     float64
#  12  launch_angle_avg    15 non-null     float64
#  13  barrel_batted_rate  15 non-null     float64
# dtypes: float64(10), int64(1), object(3)
# memory usage: 1.8+ KB

# %% [markdown]
# Check the 15 players who remain in MLB, who has the lowest era in 2021:
#
# **The Ans:** Max_Scherzer

# %%
import math 
df3.loc[df3['p_era'] == df3['p_era'].min()]
# Out:
#      last_name first_name          name  player_id  year  p_era    xba   xslg  \
# 2886  Scherzer        Max  Max_Scherzer   453286.0  2021   2.46  0.196  0.355
#
#       xwoba   xobp   xiso  exit_velocity_avg  launch_angle_avg  \
# 2886  0.264  0.249  0.159               87.9              19.3
#
#       barrel_batted_rate
# 2886                 8.0

# %% [markdown]
# Get the data from Max_Scherzer, draw a bar chart to check his era in all of his pitching careers.

# %%
#collapse-output
filt = (df['name'] == 'Max_Scherzer')
df.loc[filt]
# Out:
#      last_name first_name          name  player_id  year  p_era    xba   xslg  \
# 53    Scherzer        Max  Max_Scherzer   453286.0  2018   2.53  0.186  0.319
# 636   Scherzer        Max  Max_Scherzer   453286.0  2020   3.74  0.252  0.432
# 1184  Scherzer        Max  Max_Scherzer   453286.0  2016   2.96  0.197  0.334
# 1811  Scherzer        Max  Max_Scherzer   453286.0  2015   2.79  0.202  0.340
# 2343  Scherzer        Max  Max_Scherzer   453286.0  2017   2.51  0.178  0.305
# 2886  Scherzer        Max  Max_Scherzer   453286.0  2021   2.46  0.196  0.355
# 3726  Scherzer        Max  Max_Scherzer        NaN  2013   2.90    NaN    NaN
# 4116  Scherzer        Max  Max_Scherzer   453286.0  2019   2.92  0.203  0.336
# 4871  Scherzer        Max  Max_Scherzer        NaN  2014   3.15    NaN    NaN
# 5517  Scherzer        Max  Max_Scherzer        NaN  2011   4.43    NaN    NaN
# 6106  Scherzer        Max  Max_Scherzer        NaN  2010   3.50    NaN    NaN
# 6698  Scherzer        Max  Max_Scherzer        NaN  2009   4.12    NaN    NaN
# 7303  Scherzer        Max  Max_Scherzer        NaN  2008   3.05    NaN    NaN
# 8203  Scherzer        Max  Max_Scherzer        NaN  2012   3.74    NaN    NaN
#
#       xwoba   xobp   xiso  exit_velocity_avg  launch_angle_avg  \
# 53    0.250  0.246  0.133               86.6              20.7
# 636   0.322  0.313  0.180               88.5              18.7
# 1184  0.258  0.254  0.137               87.2              19.4
# 1811  0.253  0.238  0.137               87.1              17.1
# 2343  0.244  0.247  0.128               86.5              19.1
# 2886  0.264  0.249  0.159               87.9              19.3
# 3726    NaN    NaN    NaN                NaN               NaN
# 4116  0.254  0.250  0.133               87.6              13.5
# 4871    NaN    NaN    NaN                NaN               NaN
# 5517    NaN    NaN    NaN                NaN               NaN
# 6106    NaN    NaN    NaN                NaN               NaN
# 6698    NaN    NaN    NaN                NaN               NaN
# 7303    NaN    NaN    NaN                NaN               NaN
# 8203    NaN    NaN    NaN                NaN               NaN
#
#       barrel_batted_rate
# 53                   6.8
# 636                  8.4
# 1184                 6.1
# 1811                 5.8
# 2343                 5.6
# 2886                 8.0
# 3726                 NaN
# 4116                 6.6
# 4871                 NaN
# 5517                 NaN
# 6106                 NaN
# 6698                 NaN
# 7303                 NaN
# 8203                 NaN

# %%
df5 = df.loc[df['name'] == 'Max_Scherzer']
df5.sort_values(by=['year'])
df5['p_era'].mean()
# Out:
# 3.1999999999999993

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14 entries, 53 to 8203
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   last_name           14 non-null     object
#  1   first_name          14 non-null     object
#  2   name                14 non-null     object
#  3   player_id           7 non-null      float64
#  4   year                14 non-null     int64
#  5   p_era               14 non-null     float64
#  6   xba                 7 non-null      float64
#  7   xslg                7 non-null      float64
#  8   xwoba               7 non-null      float64
#  9   xobp                7 non-null      float64
#  10  xiso                7 non-null      float64
#  11  exit_velocity_avg   7 non-null      float64
#  12  launch_angle_avg    7 non-null      float64
#  13  barrel_batted_rate  7 non-null      float64
# dtypes: float64(10), int64(1), object(3)
# memory usage: 1.6+ KB

# %%
df5.sort_values(by=['year']).plot(x='year', y='p_era')
plt.axhline(y=df5['p_era'].mean(), c="r", ls="--", lw=2)

# %% [markdown]
# We can check seaborn plot, found all the historical pitches, Max Scherzer is one of the most stable pitchers in MLB since 2006

# %%
import seaborn as sns
sns.set_theme(style="white")
fig, ax = plt.subplots(figsize=(10, 5))
ax=sns.violinplot(data=df2, x="p_era", y="name", ax=ax, inner='quartile', color='forestgreen',palette="muted")
ax.set_xlabel('era',fontsize=14,fontweight='bold')
ax.set_ylabel('Pitchers',fontsize=14,fontweight='bold')
plt.text(5.3,16.5,'Max Scherzer',fontsize=16,color='BLue')
plt.tight_layout()
plt.show()

# %%
#collapse-output
Scherzer_deal = urlopen('https://www.espn.com/mlb/story/_/id/32745735/sources-new-york-mets-max-scherzer-finalizing-3-year-deal')
soup_Scherzer = BeautifulSoup(Scherzer_deal, 'html.parser')
print(soup_Scherzer.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-icon-fonts" lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="IE=edge,chrome=1" http-equiv="x-ua-compatible"/>
#   <meta content="initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <link href="https://www.espn.com/mlb/story/_/id/32745735/sources-new-york-mets-max-scherzer-finalizing-3-year-deal" rel="canonical"/>
#   <link href="https://www.espn.com/mlb/story/_/id/32745735/sources-new-york-mets-max-scherzer-finalizing-3-year-deal?platform=amp" rel="amphtml"/>
#   <title>
#    Sources - New York Mets, Max Scherzer agree to three-year, $130 million contract
#   </title>
#   <meta content="Three-time Cy Young Award winner Max Scherzer and the Mets have agreed to a three-year, $130 million contract, sources familiar with the situation told ESPN's Jeff Passan." name="description">
#    <meta content="New York Mets, Max Scherzer, Los Angeles Dodgers, MLB" name="news_keywords">
#     <meta content="New York Mets, Max Scherzer, Los Angeles Dodgers, MLB" name="keywords"/>
#     <meta content="2021-11-29T18:26:00Z" name="DC.date.issued"/>
#     <meta content="116656161708917" property="fb:app_id">
#      <meta content="ESPN.com" property="og:site_name"/>
#      <meta content="https://www.espn.com/mlb/story/_/id/32745735/sources-new-york-mets-max-scherzer-finalizing-3-year-deal" property="og:url"/>
#      <meta content="Sources: Mets, Scherzer agree to $130M deal" property="og:title"/>
#      <meta content="Three-time Cy Young Award winner Max Scherzer and the Mets have agreed to a three-year, $130 million contract, sources familiar with the situation told ESPN's Jeff Passan." property="og:description"/>
#      <meta content="https://a1.espncdn.com/combiner/i?img=%2Fphoto%2F2021%2F1018%2Fr924392_2_1296x729_16%2D9.jpg" property="og:image"/>
#      <meta content="1296" property="og:image:width"/>
#      <meta content="729" property="og:image:height"/>
#      <meta content="article" property="og:type"/>
#      <meta content="false" property="article:opinion"/>
#      <meta content="free" property="article:content_tier"/>
#      <meta content="104266592953439" property="fb:pages"/>
#      <meta content="espn" name="twitter:site"/>
#      <meta content="https://www.espn.com/mlb/story/_/id/32745735/sources-new-york-mets-max-scherzer-finalizing-3-year-deal" name="twitter:url"/>
#      <meta content="Sources: Mets, Scherzer agree to $130M deal" name="twitter:title"/>
#      <meta content="Three-time Cy Young Award winner Max Scherzer and the Mets have agreed to a three-year, $130 million contract, sources familiar with the situation told ESPN's Jeff Passan." name="twitter:description"/>
#      <meta content="summary_large_image" name="twitter:card"/>
#      <meta content="ESPN" name="twitter:app:name:iphone">
#       <meta content="317469184" name="twitter:app:id:iphone"/>
#       <meta content="sportscenter://x-callback-url/showStory?uid=32745735" name="twitter:app:url:iphone"/>
#       <meta content="ESPN" name="twitter:app:name:googleplay"/>
#       <meta content="com.espn.score_center" name="twitter:app:id:googleplay"/>
#       <meta content="sportscenter://x-callback-url/showStory?uid=32745735" name="twitter:app:url:googleplay"/>
#       <meta content="Sources - New York Mets, Max Scherzer agree to three-year, $130 million contract" name="title"/>
#       <meta content="article" name="medium"/>
#       <meta content="app-id=317469184, app-argument=sportscenter://x-callback-url/showStory?uid=32745735" name="apple-itunes-app"/>
#       <!-- Indicate preferred brand name for Google to display -->
#       <script type="application/ld+json">
#        {
# 		"@context": "https://schema.org",
# 		"@type":    "WebSite",
# 		"name":     "ESPN",
# 		"url":      "https://www.espn.com/"
# 	}
#       </script>
#       <script type="application/ld+json">
#        {"@context":"http://schema.org","@type":"NewsArticle","mainEntityOfPage":{"@type":"WebPage","@id":"https://www.espn.com/mlb/story/_/id/32745735/sources-new-york-mets-max-scherzer-finalizing-3-year-deal"},"headline":"Sources - New York Mets, Max Scherzer agree to three-year, $130 million contract","description":"Three-time Cy Young Award winner Max Scherzer and the Mets have agreed to a three-year, $130 million contract, sources familiar with the situation told ESPN's Jeff Passan.","datePublished":"2021-11-29T18:26:00Z","dateModified":"2021-11-29T18:26:00Z","image":{"@type":"ImageObject","url":"https://a.espncdn.com/photo/2021/1018/r924392_2_1296x729_16-9.jpg","width":1296,"height":729},"publisher":{"@type":"organization","name":"ESPN","logo":{"@type":"ImageObject","url":"https://a.espncdn.com/combiner/i?img=/i/espn/espn_logos/amp/ESPN_amp.png&w=600&h=60","width":107,"height":60}}}
#       </script>
#       <!--
# <PageMap>
# 	<DataObject type="document">
# 		<Attribute name="title">Sources: Mets, Scherzer agree to $130M deal</Attribute>
# 	</DataObject>
# 	<DataObject type="thumbnail">
# 		<Attribute name="src" value="https://a1.espncdn.com/combiner/i?img=%2Fphoto%2F2021%2F1018%2Fr924392_2_1296x729_16%2D9.jpg" />
# 		<Attribute name="width" value="1296" />
# 		<Attribute name="height" value="729" />
# 	</DataObject>
# </PageMap>
# -->
#       <script src="https://dcf.espn.com/TWDC-DTCI/prod/Bootstrap.js" type="text/javascript">
#       </script>
#       <link href="https://www.espn.com/mlb/story/_/id/32745735/sources-new-york-mets-max-scherzer-finalizing-3-year-deal" hreflang="en-us" rel="alternate">
#        <link href="https://www.espn.in/mlb/story/_/id/32745735/sources-new-york-mets-max-scherzer-finalizing-3-year-deal" hreflang="en-in" rel="alternate"/>
#        <link href="https://www.espn.com/mlb/story/_/id/32745735/sources-new-york-mets-max-scherzer-finalizing-3-year-deal" hreflang="en" rel="alternate"/>
#        <link href="https://www.espn.com.au/mlb/story/_/id/32745735/sources-new-york-mets-max-scherzer-finalizing-3-year-deal" hreflang="en-au" rel="alternate"/>
#        <link href="https://www.espn.com.sg/mlb/story/_/id/32745735/sources-new-york-mets-max-scherzer-finalizing-3-year-deal" hreflang="en-sg" rel="alternate"/>
#        <link href="https://africa.espn.com/mlb/story/_/id/32745735/sources-new-york-mets-max-scherzer-finalizing-3-year-deal" hreflang="en-za" rel="alternate"/>
#        <link href="https://www.espn.ph/mlb/story/_/id/32745735/sources-new-york-mets-max-scherzer-finalizing-3-year-deal" hreflang="en-ph" rel="alternate"/>
#        <link href="https://www.espn.co.uk/mlb/story/_/id/32745735/sources-new-york-mets-max-scherzer-finalizing-3-year-deal" hreflang="en-gb" rel="alternate"/>
#        <script type="text/javascript">
#         ;(function(){
#
# function rc(a){for(var b=a+"=",c=document.cookie.split(";"),d=0;d<c.length;d++){for(var e=c[d];" "===e.charAt(0);)e=e.substring(1,e.length);if(0===e.indexOf(b))return e.substring(b.length,e.length)}return null}var _nr=!1,_nrCookie=rc("_nr");null!==_nrCookie?"1"===_nrCookie&&(_nr=!0):Math.floor(100*Math.random())+1===13?(_nr=!0,document.cookie="_nr=1; path=/"):(_nr=!1,document.cookie="_nr=0; path=/");_nr&&(function(){window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(23),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{p?p-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(24),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),c.xhrWrappable&&t(14),d=!0)}s.on("fn-start",function(t,e,n){d&&(p+=1)}),s.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){M++,j=y.hash,this[u]=x.now()}function o(){M--,y.hash!==j&&i(0,!0);var t=x.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+y,e])}function a(t,e){t.on(e,function(){this[e]=x.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,l="cb"+s,p="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,y=w.location,x=t("loader");if(w[v]&&x.xhrWrappable){var g=t(10),b=t(11),E=t(8),R=t(6),O=t(13),C=t(7),P=t(14),T=t(9),L=t("ee"),S=L.get("tracer");t(16),x.features.spa=!0;var j,M=0;L.on(u,r),L.on(l,r),L.on(d,o),L.on(p,o),L.buffer([u,d,"xhr-done","xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),P.buffer([u,"new-xhr","send-xhr"+s]),C.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),g.buffer([u]),b.buffer(["propagate",l,p,"executor-err","resolve"+s]),S.buffer([u,"no-"+u]),T.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(P,"send-xhr"+s),a(L,"xhr-resolved"),a(L,"xhr-done"),a(C,m+s),a(C,m+"-done"),a(T,"new-jsonp"),a(T,"jsonp-end"),a(T,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,M>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),s=t(12),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,v="fn"+h,w="bstTimer",y="pushState",x=t("loader");x.features.stn=!0,t(8);var g=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof g&&(this.bstStart=x.now())}),o.on(v,function(t,e){var n=t[0];n instanceof g&&i("bst",[n,e,this.bstStart,x.now()])}),a.on(m,function(t,e,n){this.bstStart=x.now(),this.bstType=n}),a.on(v,function(t,e) ...
#
# })();
#        </script>
#        <script src="https://secure.espn.com/core/format/modules/head/i18n?edition-host=espn.com&amp;lang=en®ion=us&amp;site=espn&amp;site-type=full&amp;type=ext&amp;build=0.585.0.2">
#        </script>
#        <link crossorigin="" href="https://a.espncdn.com" rel="preconnect"/>
#        <link crossorigin="" href="https://cdn.registerdisney.go.com" rel="preconnect"/>
#        <link crossorigin="" href="https://fan.api.espn.com" rel="preconnect"/>
#        <link crossorigin="" href="https://secure.espn.com" rel="preconnect"/>
#        <link color="#990000" href="https://a.espncdn.com/prod/assets/icons/E.svg" rel="mask-icon" sizes="any"/>
#        <link href="https://a.espncdn.com/favicon.ico" rel="shortcut icon">
#         <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-57x57.png" rel="apple-touch-icon">
#          <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-57x57.png" rel="apple-touch-icon-precomposed"/>
#          <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-60x60.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
#          <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#          <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-76x76.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
#          <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#          <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-120x120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
#          <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#          <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#          <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-180x180.png" rel="apple-touch-icon-precomposed" sizes="180x180"/>
#          <link href="android-app://com.espn.score_center/sportscenter/x-callback-url/showStory?uid=32745735" rel="alternate">
#           <link href="ios-app://317469184/sportscenter/x-callback-url/showStory?uid=32745735" rel="alternate">
#            <link href="https://a.espncdn.com/redesign/fonts/base64-benton-woff.css" id="font-link" rel="stylesheet"/>
#            <link href="https://a.espncdn.com/redesign/0.585.0/css/shell-desktop.css" rel="stylesheet">
#             <link href="https://a.espncdn.com/redesign/0.585.0/css/page.css" rel="stylesheet"/>
#             <link class="page-type-include" href="https://a.espncdn.com/redesign/0.585.0/css/story.css" rel="stylesheet"/>
#             <script src="https://a.espncdn.com/redesign/0.585.0/js/espn-head.js">
#             </script>
#             <script>
#              if (espn && espn.geoRedirect){
# 				espn.geoRedirect.run();
# 			}
#             </script>
#             <script>
#              var espn = espn || {};
# 	espn.isOneSite = false;
# 	espn.build = "0.585.0";
# 	espn.siteType = "full";
# 	espn.anonymous_favorites = "true" === "true";
# 	espn.isFantasycast = false;
#
# 	espn.absoluteNavLinks = false;
# 	espn.useEPlus = true;
# 	espn.hidePremiumBranding = false; // used in pof: hide e+ branding if non premium edition (SEWEB-22908)
# 	espn.enableObscuredAdsSkipping = false;
#
# 	espn.enableInlinePlayback = true;
# 	espn.enableInlinePPV = true;
#             </script>
#             <script async="" src="https://a.espncdn.com/redesign/0.585.0/node_modules/espn-lazysizes/lazysizes.min.js">
#             </script>
#             <script type="text/javascript">
#              (function () {
# 		var featureGating;
#
# 		try {
# 			featureGating = JSON.parse('{"enableLeaderboardWatchRow":true,"playerFollowing":true,"activeSportsSiteAPI":true,"showTaboolaSportIndex":true,"gateFavorites":true,"browerDeprecation":true,"usPrivacy":true,"hudsonPlayer":true,"useLatestPaywall":true,"hudsonPAL":true,"newSearchVersion":true,"olyResultsGPWebview":false,"geoFooter":true,"enableFastcast":true,"siteBroadcast":true,"fittRoutes":["(nba-g-league)\\/schedule ","(mlb|nba|nfl|mens-college-basketball|womens-college-basketball|college-football)\\/team"],"drm":true}');
# 		} catch (e) {}
#
# 		window.espn.featureGating = featureGating || {};
# 	})();
#             </script>
#             <script>
#              window.googletag = window.googletag || {};
#
# 		(function () {
# 			espn = window.espn || {};
# 			espn.ads = espn.ads || {};
# 			espn.ads.config = {"page_url":"https://www.espn.com/mlb/story/_/id/32745735/sources-new-york-mets-max-scherzer-finalizing-3-year-deal","prebidAdConfig":{"usePrebidBids":true,"timeout":1000},"sizesEspnPlus":{"banner-index":{"excludedSize":["728,90"],"mappings":[{"viewport":[1280,0],"slot":[[1280,100],[970,250]]},{"viewport":[1024,0],"slot":[[970,66],[970,250]]},{"viewport":[768,0],"slot":[[728,90]]},{"viewport":[320,0],"slot":[[320,50]]},{"viewport":[0,0],"slot":[[240,38]]}],"defaultSize":[970,66],"excludedProfile":["xl"],"includedCountries":["us"],"pbjs":{"s":[[320,50]],"xl":[[970,250]],"l":[[970,250]],"m":[[728,90]]}},"banner-scoreboard":{"excludedSize":["970,250"],"mappings":[{"viewport":[1280,0],"slot":[[1280,100],[728,90]]},{"viewport":[1024,0],"slot":[[970,66],[728,90]]},{"viewport":[768,0],"slot":[[728,90]]},{"viewport":[320,0],"slot":[[320,50]]},{"viewport":[0,0],"slot":[[240,38]]}],"defaultSize":[970,66],"includedCountries":["us"],"pbjs":{"s":[[320,50]],"xl":[[728,90]],"l":[[728,90]],"m":[[728,90]]}},"banner":{"mappings":[{"viewport":[1280,0],"slot":[[1280,100],[970,250],[728,90]]},{"viewport":[1024,0],"slot":[[970,66],[970,250],[728,90]]},{"viewport":[768,0],"slot":[[728,90]]},{"viewport":[320,0],"slot":[[320,50]]},{"viewport":[0,0],"slot":[[240,38]]}],"defaultSize":[970,66],"pbjs":{"s":[[320,50]],"xl":[[970,250],[728,90]],"l":[[970,250],[728,90]],"m":[[728,90]]}},"incontent-betting":{"mappings":[{"viewport":[1024,0],"slot":[[300,251]]},{"viewport":[320,0],"slot":[[300,251]]}],"defaultSize":[300,251]},"native-betting":{"mappings":[{"viewport":[0,0],"slot":["fluid"]}],"defaultSize":"fluid"},"incontent":{"mappings":[{"viewport":[1024,0],"slot":[[300,250],[300,600]]}],"defaultSize":[300,250]}},"incontentPositions":{"defaults":{"favorites":-1,"news":4,"now":4},"index":{"top":{"favorites":-1},"nfl":{}}},"ePlusBettingAdOnly":["fantasy"],"kvpsEspnPlus":[{"name":"ed","value":"us"},{"name":"eplus","value":"true"}],"network":"21783347309","refreshOnBreakpointChange":true,"sizes":{"overlay":{"mappings":[{"viewport":[0,0],"slot":[[0,0]]}],"defaultSize":[0,0]},"wallpaper":{"mappings":[{"viewport":[1280,0],"slot":[[1680,1050]]},{"viewport":[1024,0],"slot":[[1280,455]]},{"viewport":[0,0],"slot":[]}],"defaultSize":[1280,455]},"banner-scoreboard":{"excludedSize":["970,250"],"mappings":[{"viewport":[1280,0],"slot":[[1280,100],[728,90]]},{"viewport":[1024,0],"slot":[[970,66],[728,90]]},{"viewport":[768,0],"slot":[[728,90]]},{"viewport":[320,0],"slot":[[320,50]]},{"viewport":[0,0],"slot":[[240,38]]}],"defaultSize":[970,66],"includedCountries":["us"],"pbjs":{"s":[[320,50]],"xl":[[728,90]],"l":[[728,90]],"m":[[728,90]]}},"incontent2":{"mappings":[{"viewport":[0,0],"slot":[[300,250]]}],"defaultSize":[300,250]},"banner":{"mappings":[{"viewport":[1280,0],"slot":[[1280,100],[970,250],[728,90]]},{"viewport":[1024,0],"slot":[[970,66],[970,250],[728,90]]},{"viewport":[768,0],"slot":[[728,90]]},{"viewport":[320,0],"slot":[[320,50]]},{"viewport":[0,0],"slot":[[240,38]]}],"defaultSize":[970,66],"pbjs":{"s":[[320,50]],"xl":[[970,250],[728,90]],"l":[[970,250],[728,90]],"m":[[728,90]]}},"exclusions":{"mappings":[{"viewport":[0,0],"slot":[[1,2]]}],"defaultSize":[1,2]},"native-betting":{"mappings":[{"viewport":[0,0],"slot":["fluid"]}],"defaultSize":"fluid"},"banner-index":{"excludedSize":["728,90"],"mappings":[{"viewport":[1280,0],"slot":[[1280,100],[970,250]]},{"viewport":[1024,0],"slot":[[970,66],[970,250]]},{"viewport":[768,0],"slot":[[728,90]]},{"viewport":[320,0],"slot":[[320,50]]},{"viewport":[0,0],"slot":[[240,38]]}],"defaultSize":[970,66],"excludedProfile":["xl"],"includedCountries":["All"],"pbjs":{"s":[[320,50]],"xl":[[970,250]],"l":[[970,250]],"m":[[728,90]]}},"banner-webview":{"excludedSize":["970,250"],"mappings":[{"viewport":[1280,0],"slot":[[728,90]]},{"viewport":[1024,0],"slot":[[728,90]]},{"viewport":[768,0],"slot":[[728,90]]},{"viewport":[320,0],"slot":[[320,50]]},{"viewport":[0,0],"slot":[[240,38]]}],"defaultSize":[728,90],"includedC ...
# 			googletag.cmd = googletag.cmd || [];
#
# 			var espnAdsConfig = espn.ads.config;
#
# 			espn.ads.loadGPT = function () {
# 				var gads = document.createElement('script');
# 				gads.async = true;
# 				gads.type = 'text/javascript';
# 				gads.src = 'https://www.googletagservices.com/tag/js/gpt.js';
# 				var node = document.getElementsByTagName('script')[0];
# 				node.parentNode.insertBefore(gads, node);
# 				delete espn.ads.loadGPT;
# 			}
#
# 			if (espn.siteType === 'data-lite') {
# 				/**
# 				 * Load ad library after our deferred files. Event subscription must
# 				 * occur on window.load to ensure pub/sub availability.
# 				 */
#
# 				// Ad calls will be made when ad library inits (after window.load).
# 				var liteAdLoadConfigs = {
# 					desktop: 'init',
# 					mobile: 'init',
# 					tablet: 'init'
# 				};
#
# 				espnAdsConfig.load = espnAdsConfig.load || {};
# 				espnAdsConfig.load.defaults = liteAdLoadConfigs
# 				espnAdsConfig.load.frontpage = liteAdLoadConfigs;
# 				espnAdsConfig.load.index = liteAdLoadConfigs;
# 				espnAdsConfig.load.story = liteAdLoadConfigs;
# 			} else {
# 				espn.ads.loadGPT();
# 			}
#
# 			if (espnAdsConfig.prebidAdConfig && espnAdsConfig.prebidAdConfig.usePrebidBids) {
#
#
# 				// Load prebid.js for AppNexus
# 				(function() {
# 					var d = document, pbs = d.createElement('script'), pro = d.location.protocol;
# 					pbs.type = 'text/javascript';
# 					pbs.src = ((pro === 'https:') ? 'https' : 'http') + '://a.espncdn.com/prod/scripts/prebid4.35.0.js';
# 					var target = document.getElementsByTagName('head')[0];
# 					target.insertBefore(pbs, target.firstChild);
# 				})();
# 			}
#
# 			espn.ads.configPre = JSON.parse(JSON.stringify(espnAdsConfig));
# 		})();
#             </script>
#             <script type="text/javascript">
#              if( typeof s_omni === "undefined" ) window.s_account = window.setReportSuite( "wdgespcom" );
#             </script>
#             <!-- test & target - mbox.js -->
#             <script src="https://a.espncdn.com/prod/scripts/analytics/ESPN_at_v2.rs.min.js" type="text/javascript">
#             </script>
#             <script>
#              // Picture element HTML shim|v it for old IE (pairs with Picturefill.js)
# 	document.createElement("picture");
#             </script>
#            </link>
#           </link>
#          </link>
#         </link>
#        </link>
#       </link>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="story desktop prod" data-app="" data-appearance="light" data-customstylesheet="null" data-edition="en-us" data-lang="en" data-pagetype="story" data-site="espn" data-sport="mlb">
#   <img height="99999" src="data:image/svg+xml;base64,..." style="pointer-events: none; position: absolute; top: 0; left: 0; width: 99vw; height: 99vh; max-width: 99vw; max-height: 99vh;" width="99999"/>
#   <div class="ad-slot ad-slot-exclusions" data-category-exclusion="true" data-slot-kvps="pos=exclusions" data-slot-type="exclusions">
#   </div>
#   <div class="ad-slot ad-slot-overlay" data-out-of-page="true" data-slot-kvps="pos=outofpage" data-slot-type="overlay">
#   </div>
#   <!-- abtest data object global -->
#   <script type="text/javascript">
#    var abtestData = {};
# 			abtestData.abTestUser = "0";
#   </script>
#   <div id="fb-root">
#   </div>
#   <div class="interior secondary" data-behavior="global_nav_condensed global_nav_full" id="global-viewport">
#    <nav data-loadtype="server" id="global-nav-mobile">
#    </nav>
#    <div class="menu-overlay-primary">
#    </div>
#    <div class="hidden-print" id="header-wrapper">
#     <section class="hide-fullbtn" id="global-scoreboard" role="region">
#      <button class="scoreboard-hidden-skip" data-behavior="scoreboard_skipnav" data-skip="content">
#       Skip to main content
#      </button>
#      <button class="scoreboard-hidden-skip" data-behavior="scoreboard_skipnav" data-skip="nav">
#       Skip to navigation
#      </button>
#      <div class="wrap">
#       <div class="scoreboard-content">
#        <div class="scoreboard-dropdown-wrapper scoreboard-menu">
#         <!-- mobile dropdown -->
#         <div class="league-nav-wrapper league-nav-mobile mobile-dropdown">
#          <span class="mobile-arrow">
#          </span>
#          <select id="league-nav">
#          </select>
#         </div>
#         <!-- desktop dropdown -->
#         <div class="dropdown-wrapper league-nav-desktop desktop-dropdown" data-behavior="button_dropdown">
#          <button class="button button-filter sm dropdown-toggle current-league-name" type="button">
#          </button>
#          <ul class="dropdown-menu league-nav med">
#          </ul>
#         </div>
#        </div>
#        <div class="scoreboard-dropdown-wrapper conference-menu">
#         <!-- mobile dropdown -->
#         <div class="conference-nav-wrapper mobile-dropdown">
#          <span class="mobile-arrow">
#          </span>
#          <select id="conference-nav">
#          </select>
#         </div>
#         <!-- desktop dropdown -->
#         <div class="dropdown-wrapper desktop-dropdown" data-behavior="button_dropdown">
#          <button class="button button-filter med dropdown-toggle current-conference-name" type="button">
#          </button>
#          <ul class="dropdown-menu conference-nav med">
#          </ul>
#         </div>
#        </div>
#        <div class="scoreboard-dropdown-wrapper scores-date-pick">
#         <div class="dropdown-wrapper" data-behavior="button_dropdown">
#          <button class="button button-filter dropdown-toggle sm selected-date" type="button">
#          </button>
#          <ul class="dropdown-menu date-nav med">
#          </ul>
#         </div>
#        </div>
#        <div class="scoreboard-dropdown-wrapper secondary-nav-container hidden">
#        </div>
#        <div class="scores-prev controls inactive">
#         &lt;
#        </div>
#        <div class="view-full" id="fullbtn">
#        </div>
#        <div class="scores-next controls">
#         &gt;
#        </div>
#        <div class="scores-carousel">
#         <ul id="leagues">
#         </ul>
#        </div>
#       </div>
#      </div>
#     </section>
#     <header class="espn-en user-account-management has-search" id="global-header">
#      <div class="menu-overlay-secondary">
#      </div>
#      <div class="container">
#       <a data-route="false" href="#" id="global-nav-mobile-trigger">
#        <span>
#         Menu
#        </span>
#       </a>
#       <h1>
#        <a href="/" name="&amp;lpos=sitenavdefault&amp;lid=sitenav_main-logo">
#         ESPN
#        </a>
#       </h1>
#       <ul class="tools">
#        <li class="search">
#         <a class="icon-font-after icon-search-solid-after" href="#" id="global-search-trigger">
#         </a>
#         <div class="global-search" id="global-search">
#          <label for="global-search-input">
#           Search
#          </label>
#          <div class="global-search-input-wrapper">
#           <input class="search-box" id="global-search-input" placeholder="Search Sports, Teams or Players..." type="text"/>
#           <input class="btn-search" type="submit"/>
#          </div>
#         </div>
#        </li>
#        <li class="user" data-behavior="favorites_mgmt">
#        </li>
#        <li id="scores-link">
#         <a data-route="false" href="#" id="global-scoreboard-trigger">
#          scores
#         </a>
#        </li>
#       </ul>
#      </div>
#      <nav data-loadtype="server" id="global-nav">
#       <ul itemscope="" itemtype="http://www.schema.org/SiteNavigationElement">
#        <li itemprop="name">
#         <a href="/nfl/" itemprop="url">
#          NFL
#         </a>
#        </li>
#        <li itemprop="name">
#         <a href="/nba/" itemprop="url">
#          NBA
#         </a>
#        </li>
#        <li itemprop="name">
#         <a href="/nhl/" itemprop="url">
#          NHL
#         </a>
#        </li>
#        <li itemprop="name">
#         <a href="/mens-college-basketball/" itemprop="url">
#          NCAAM
#         </a>
#        </li>
#        <li itemprop="name">
#         <a href="/womens-college-basketball/" itemprop="url">
#          NCAAW
#         </a>
#        </li>
#        <li itemprop="name">
#         <a href="/soccer/" itemprop="url">
#          Soccer
#         </a>
#        </li>
#        <li itemprop="name">
#         <a href="#" itemprop="url">
#          …
#         </a>
#         <div>
#          <ul class="split">
#           <li itemprop="name">
#            <a href="/boxing/" itemprop="url">
#             Boxing
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="http://www.tsn.ca/cfl" itemprop="url">
#             CFL
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="/chalk/" itemprop="url">
#             Chalk
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="/college-sports/" itemprop="url">
#             NCAA
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="https://www.espncricinfo.com/" itemprop="url">
#             Cricket
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="/f1/" itemprop="url">
#             F1
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="/golf/" itemprop="url">
#             Golf
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="/little-league-world-series/" itemprop="url">
#             LLWS
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="/mlb/" itemprop="url">
#             MLB
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="/mma/" itemprop="url">
#             MMA
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="/racing/nascar/" itemprop="url">
#             NASCAR
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="/nba-g-league/" itemprop="url">
#             NBA G League
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="/college-football/" itemprop="url">
#             NCAAF
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="/olympics/" itemprop="url">
#             Olympic Sports
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="/racing/" itemprop="url">
#             Racing
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="https://www.espn.com/college-sports/basketball/recruiting/" itemprop="url">
#             RN BB
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="https://www.espn.com/college-sports/football/recruiting/" itemprop="url">
#             RN FB
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="/rugby/" itemprop="url">
#             Rugby
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="/tennis/" itemprop="url">
#             Tennis
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="/wnba/" itemprop="url">
#             WNBA
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="/wwe/" itemprop="url">
#             WWE
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="http://xgames.com/" itemprop="url">
#             X Games
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#        <li class="pillar more-espn">
#         <a href="#">
#          More ESPN
#         </a>
#        </li>
#        <li class="pillar fantasy">
#         <a href="/fantasy/">
#          Fantasy
#         </a>
#        </li>
#        <li class="pillar listen">
#         <a href="https://www.espn.com/espnradio/index">
#          Listen
#         </a>
#        </li>
#        <li class="pillar watch">
#         <a href="https://www.espn.com/watch/">
#          Watch
#         </a>
#        </li>
#        <li class="pillar espn+">
#         <a href="https://www.espn.com/espnplus/?om-navmethod=topnav">
#          ESPN+
#         </a>
#        </li>
#       </ul>
#      </nav>
#      <nav data-loadtype="tier-2-server" id="global-nav-secondary">
#       <div class="global-nav-container">
#        <ul class="first-group">
#         <li class="sports" itemprop="name">
#          <span class="positioning">
#           <a href="/mlb/">
#            <span class="brand-logo">
#             <img src="https://a.espncdn.com/combiner/i?img=/i/teamlogos/leagues/500/mlb.png&amp;w=80&amp;h=80&amp;transparent=true"/>
#            </span>
#            <span class="link-text">
#             MLB
#            </span>
#            <span class="link-text-short">
#             MLB
#            </span>
#           </a>
#          </span>
#         </li>
#         <li class="sub">
#          <a href="/mlb/">
#           <span class="link-text">
#            Home
#           </span>
#           <span class="link-text-short">
#            Home
#           </span>
#          </a>
#         </li>
#         <li class="sub">
#          <a href="https://www.espn.com/mlb/story/_/id/32644225/mlb-free-agency-tracker-latest-moves-grades-analysis">
#           <span class="link-text">
#            Free Agency Tracker
#           </span>
#           <span class="link-text-short">
#            Free Agency Tracker
#           </span>
#          </a>
#         </li>
#         <li class="sub">
#          <a href="https://www.espn.com/mlb/story/_/id/32882139/mlb-lockout-owners-players-talking-baseball-fans-worried-here-latest">
#           <span class="link-text">
#            MLB Lockout Ends
#           </span>
#           <span class="link-text-short">
#            MLB Lockout Ends
#           </span>
#          </a>
#         </li>
#         <li class="sub">
#          <a href="/mlb/scoreboard">
#           <span class="link-text">
#            Scores
#           </span>
#           <span class="link-text-short">
#            Scores
#           </span>
#          </a>
#         </li>
#         <li class="sub">
#          <a href="/mlb/schedule">
#           <span class="link-text">
#            Schedule
#           </span>
#           <span class="link-text-short">
#            Schedule
#           </span>
#          </a>
#         </li>
#         <li class="sub">
#          <a data-match-url="/standings/" data-route="false" href="/mlb/standings">
#           <span class="link-text">
#            Standings
#           </span>
#           <span class="link-text-short">
#            Standings
#           </span>
#          </a>
#         </li>
#         <li class="sub">
#          <a data-route="false" href="/mlb/stats">
#           <span class="link-text">
#            Stats
#           </span>
#           <span class="link-text-short">
#            Stats
#           </span>
#          </a>
#         </li>
#         <li class="sub">
#          <a data-route="false" data-sportabbrev="mlb" href="/mlb/teams">
#           <span class="link-text">
#            Teams
#           </span>
#           <span class="link-text-short">
#            Teams
#           </span>
#          </a>
#         </li>
#         <li class="sub">
#          <a href="https://www.espn.com/mlb/story/_/id/29473590/2020-mlb-depth-charts-all-30-teams">
#           <span class="link-text">
#            Depth Charts
#           </span>
#           <span class="link-text-short">
#            Depth Charts
#           </span>
#          </a>
#         </li>
#         <li class="sub pre-loadSubNav">
#          <a href="https://www.espn.com/mlb/story/_/id/33145121/top-100-mlb-players-all">
#           <span class="link-text">
#            Top 100 Players All-Time
#           </span>
#           <span class="link-text-short">
#            Top 100 Players All-Time
#           </span>
#          </a>
#         </li>
#         <li class="sub pre-loadSubNav">
#          <a href="https://www.espn.com/mlb/story/_/id/33012995/2022-baseball-hall-fame">
#           <span class="link-text">
#            2022 Hall of Fame
#           </span>
#           <span class="link-text-short">
#            2022 Hall of Fame
#           </span>
#          </a>
#         </li>
#         <li class="sub pre-loadSubNav">
#          <a data-mobile="false" href="https://www.espn.com/mlb/players">
#           <span class="link-text">
#            Players
#           </span>
#           <span class="link-text-short">
#            Players
#           </span>
#          </a>
#         </li>
#         <li class="sub pre-loadSubNav">
#          <a href="https://www.espn.com/mlb/story/_/id/32312501/2021-mlb-playoffs-schedules-postseason-bracket-analysis-updates">
#           <span class="link-text">
#            2021 World Series
#           </span>
#           <span class="link-text-short">
#            2021 World Series
#           </span>
#          </a>
#         </li>
#         <li class="sub pre-loadSubNav">
#          <a href="https://www.espn.com/fantasy/baseball/">
#           <span class="link-text">
#            Fantasy Baseball
#           </span>
#           <span class="link-text-short">
#            Fantasy Baseball
#           </span>
#          </a>
#         </li>
#         <li class="sub pre-loadSubNav">
#          <a href="https://www.espn.com/mlb/story/_/id/31849339/2021-mlb-trade-deadline-tracker-rumors-news-analysis-latest-buzz">
#           <span class="link-text">
#            Trade Deadline
#           </span>
#           <span class="link-text-short">
#            Trade Deadline
#           </span>
#          </a>
#         </li>
#         <li class="sub pre-loadSubNav">
#          <a href="https://www.espn.com/mlb/story/_/id/31465786/2021-mlb-draft-mock-drafts-rankings-order-analysis">
#           <span class="link-text">
#            Draft
#           </span>
#           <span class="link-text-short">
#            Draft
#           </span>
#          </a>
#         </li>
#         <li class="sub pre-loadSubNav">
#          <a href="https://www.espn.com/mlb/story/_/id/31744195/2021-mlb-all-star-game-lineups-schedule-analysis-home-run-derby-field">
#           <span class="link-text">
#            All-Star Game
#           </span>
#           <span class="link-text-short">
#            All-Star Game
#           </span>
#          </a>
#         </li>
#         <li class="sub pre-loadSubNav">
#          <a data-icon="baseball" href="https://www.espn.com/mlb/story/_/id/31461236/the-state-baseball-mlb-biggest-challenges-2021-far-beyond">
#           <span class="link-text">
#            The State of Baseball
#           </span>
#           <span class="link-text-short">
#            The State of Baseball
#           </span>
#          </a>
#         </li>
#         <li class="sub pre-loadSubNav">
#          <a data-route="false" href="/mlb/transactions">
#           <span class="link-text">
#            Transactions
#           </span>
#           <span class="link-text-short">
#            Transactions
#           </span>
#          </a>
#         </li>
#         <li class="sub pre-loadSubNav">
#          <a data-mobile="false" href="https://www.espn.com/mlb/injuries">
#           <span class="link-text">
#            Injuries
#           </span>
#           <span class="link-text-short">
#            Injuries
#           </span>
#          </a>
#         </li>
#         <li class="sub pre-loadSubNav">
#          <a data-mobile="false" href="https://www.espn.com/mlb/history">
#           <span class="link-text">
#            All-Time Stats
#           </span>
#           <span class="link-text-short">
#            All-Time Stats
#           </span>
#          </a>
#         </li>
#         <li class="sub external pre-loadSubNav">
#          <a href="https://www.vividseats.com/mlb-baseball/?wsUser=717&amp;wsVar=QUICKLINKS">
#           <span class="link-text">
#            Tickets
#           </span>
#           <span class="link-text-short">
#            Tickets
#           </span>
#          </a>
#         </li>
#         <li class="sub pre-loadSubNav">
#          <a data-isfantasy="true" data-mobile="false" href="https://fantasy.espn.com/baseball/welcome?addata=MLB_dropdown_flb2022">
#           <span class="link-text">
#            Fantasy Baseball
#           </span>
#           <span class="link-text-short">
#            Fantasy Baseball
#           </span>
#          </a>
#         </li>
#        </ul>
#        <script type="text/javascript">
#         var espn = espn || {};
# 		espn.nav = espn.nav || {};
# 		espn.nav.navId = 11929946;
# 		espn.nav.isFallback = false;
#
#
# 			espn.nav.tier2 = {"subNavMenu":{"navigation":{"links":[{"isExternal":false,"shortText":"MLB","rel":["sports"],"text":"MLB","href":"/mlb/","isPremium":false}],"attributes":{"sport_id":"10","root":"mlb"},"text":"MLB","title":"MLB Menu - LIVE","$ref":"/v2/navigation/12001873","items":[{"links":[{"isExternal":false,"shortText":"Home","rel":["sub"],"text":"Home","href":"/mlb/","isPremium":false}],"title":"MLB Home","$ref":"/v2/navigation/12001915"},{"links":[{"isExternal":false,"shortText":"Free Agency Tracker","rel":["sub"],"text":"Free Agency Tracker","href":"https://www.espn.com/mlb/story/_/id/32644225/mlb-free-agency-tracker-latest-moves-grades-analysis","isPremium":false}],"title":"Free Agency Tracker","$ref":"/v2/navigation/17650639"},{"images":[{"src":"https://a4.espncdn.com/combiner/i?img=%2Fi%2Fespn%2Fmisc_logos%2F500%2Fmlb.png&w=40&h=40"}],"links":[{"isExternal":false,"shortText":"MLB Lockout Ends","rel":["sub"],"text":"MLB Lockout Ends","href":"https://www.espn.com/mlb/story/_/id/32882139/mlb-lockout-owners-players-talking-baseball-fans-worried-here-latest","isPremium":false}],"title":"MLB Lockout Ends","$ref":"/v2/navigation/32947904"},{"links":[{"isExternal":false,"shortText":"Scores","rel":["sub"],"text":"Scores","href":"/mlb/scoreboard","isPremium":false}],"title":"MLB Scores","$ref":"/v2/navigation/11586778"},{"links":[{"isExternal":false,"shortText":"Schedule","rel":["sub"],"text":"Schedule","href":"/mlb/schedule","isPremium":false}],"title":"MLB Schedule","$ref":"/v2/navigation/11586742"},{"links":[{"isExternal":false,"shortText":"Standings","rel":["sub"],"attributes":{"match-url":"/standings/","route":"false"},"text":"Standings","href":"/mlb/standings","isPremium":false}],"title":"MLB Standings","$ref":"/v2/navigation/11586776"},{"links":[{"isExternal":false,"shortText":"Stats","rel":["sub"],"attributes":{"route":"false"},"text":"Stats","href":"/mlb/stats","isPremium":false}],"title":"MLB Stats","$ref":"/v2/navigation/11586772"},{"links":[{"isExternal":false,"shortText":"Teams","rel":["sub"],"attributes":{"route":"false","sportAbbrev":"mlb"},"text":"Teams","href":"/mlb/teams","isPremium":false}],"title":"MLB Teams","$ref":"/v2/navigation/11452966"},{"links":[{"isExternal":false,"shortText":"Depth Charts","rel":["sub"],"text":"Depth Charts","href":"https://www.espn.com/mlb/story/_/id/29473590/2020-mlb-depth-charts-all-30-teams","isPremium":false}],"title":"Depth Charts","$ref":"/v2/navigation/29473868"},{"links":[{"isExternal":false,"shortText":"Top 100 Players All-Time","rel":["sub"],"text":"Top 100 Players All-Time","href":"https://www.espn.com/mlb/story/_/id/33145121/top-100-mlb-players-all","isPremium":false}],"title":"Top 100 Players All-Time","$ref":"/v2/navigation/26375946"},{"links":[{"isExternal":false,"shortText":"More","rel":["sub"],"attributes":{"placeholder":"more","breakpoints":"mobile"},"text":"More","href":"#","isPremium":false}],"title":"Subnav More - DO NOT EDIT","$ref":"/v2/navigation/11494110"},{"links":[{"isExternal":false,"shortText":"2022 Hall of Fame","rel":["sub"],"text":"2022 Hall of Fame","href":"https://www.espn.com/mlb/story/_/id/33012995/2022-baseball-hall-fame","isPremium":false}],"title":"2022 Hall of Fame","$ref":"/v2/navigation/20162890"},{"links":[{"isExternal":false,"shortText":"Players","rel":["sub"],"attributes":{"mobile":"false"},"text":"Players","href":"https://www.espn.com/mlb/players","isPremium":false}],"title":"MLB Players","$ref":"/v2/navigation/11586740"},{"images":[{"src":"https://a4.espncdn.com/combiner/i?img=%2Fi%2Fespn%2Fmisc_logos%2F500%2Fmlb.png&w=40&h=40"}],"links":[{"isExternal":false,"shortText":"2021 World Series","rel":["sub"],"text":"2021 World Series","href":"https://www.espn.com/mlb/story/_/id/32312501/2021-mlb-playoffs-schedules-postseason-bracket-analysis-updates","isPremium":false}],"title":"2021 World Series","$ref":"/v2/navigation/27594603"},{"images":[{"src":"http://a.espncdn.com/i/fantasy/flb.png"}],"links":[{"isExternal":false,"shortText":"Fant ...
#        </script>
#       </div>
#      </nav>
#     </header>
#    </div>
#    <section id="pane-main">
#     <div data-id="story" id="custom-nav">
#     </div>
#     <div class="ad-slot ad-slot-wallpaper" data-collapse-before-load="true" data-exclude-bp="s,m" data-slot-kvps="pos=wallpaper" data-slot-type="wallpaper">
#     </div>
#     <div class="ad-banner-wrapper">
#      <div class="ad-slot ad-slot-banner ad-wrapper" data-slot-kvps="pos=banner" data-slot-type="banner">
#      </div>
#     </div>
#     <section id="main-container" tabindex="-1">
#      <script type="text/javascript">
#       var __dataLayer = window.__dataLayer || {};
#
#     __dataLayer = Object.assign({}, __dataLayer,
#         {"site":{"country":"us","site":"espn","orientation":"desktop","edition":"en-us","language":"en_us","editionKey":"espn-en"},"pzn":{"login_status":"","entitlements":"none","disneyplus_bundle":"no","has_favorites":"no","subscriber_type":"","has_fantasy":"no","has_notifications":"no","auto_start":"no"},"page":{"nav_method":"","page_url":"https://www.espn.com/mlb/story/_/id/32745735/sources-new-york-mets-max-scherzer-finalizing-3-year-deal","content_category":"","page_type":"","story_id":"","section":"mlb","prev_page":"","espnplus_category":"","espnplus_products":"","game_state":"","premium":"","content_type":"story","game_detail":"","page_name":"","game_id":"","page_infrastructure":"sCore","author":"ESPN","league":"no league","player_team_detail":"","story_title":"sources: new york mets, max scherzer agree to three-year, $130 million contract","feed_rule":"","espnplus_content":"","mktg_campaign":"","feed_type":"","sport":"mlb"},"visitor":{"dssid":"","ad_blocker":"no","unid":"","consent_groups":""},"space":"espn"}
#     );
#      </script>
#      <div class="main-content layout-cb">
#       <section class="col-c chk-height nocontent" data-behavior="desktop_story_news_feed" data-max-follow-card-tier-one-sessions="3" data-minifeed="headlinestack=true&amp;site=espn&amp;lang=en®ion=us&amp;pubkey=espn-en-mlb-index&amp;sport=mlb" data-number-of-favorites="0" data-one-feed-group-one-size="2" data-one-feed-group-three-size="1" data-one-feed-group-two-size="7" id="news-feed">
#        <div class="sidebar" id="news-feed-content">
#         <div class="container-wrapper">
#          <div class="container">
#           <!--no cache-->
#           <div class="news-feed-item" data-id="32745735">
#            <a class="story-link" data-id="32745735" data-sport="mlb" href="/mlb/story/_/id/32745735/sources-new-york-mets-max-scherzer-finalizing-3-year-deal" name="&amp;lpos=">
#            </a>
#            <div class="text-container">
#             <div class="item-info-wrap">
#              <div class="news-feed-item-title">
#               <a class="realStory" data-sport="mlb" href="/mlb/story/_/id/32745735/sources-new-york-mets-max-scherzer-finalizing-3-year-deal" name="&amp;lpos=">
#                Sources: Mets, Scherzer agree to $130M deal
#               </a>
#              </div>
#              <div class="news-feed_item-meta">
#               <div class="category-link">
#                <a data-mptype="category" href="/mlb/team/_/name/nym/new-york-mets">
#                 New York Mets
#                </a>
#               </div>
#               <span class="timestamp">
#                107d
#               </span>
#              </div>
#             </div>
#            </div>
#           </div>
#           <!--get: espn-en_story_mlb_33523386_2022-03-17T05:15:21Z_false_false_desktop_full_11-->
#           <div class="news-feed-item" data-id="33523386">
#            <a class="story-link" data-id="33523386" data-sport="mlb" href="/mlb/story/_/id/33523386/freddie-freeman-reaches-agreement-los-angeles-dodgers-six-year-162-million-deal-sources-say" name="&amp;lpos=">
#            </a>
#            <div class="text-container">
#             <div class="item-info-wrap">
#              <div class="news-feed-item-title">
#               <a class="realStory" data-sport="mlb" href="/mlb/story/_/id/33523386/freddie-freeman-reaches-agreement-los-angeles-dodgers-six-year-162-million-deal-sources-say" name="&amp;lpos=">
#                Sources: Freeman, Dodgers reach $162M deal
#               </a>
#              </div>
#              <div class="news-feed_item-meta">
#               <div class="category-link">
#                <a data-mptype="category" href="/mlb/team/_/name/atl/atlanta-braves">
#                 Atlanta Braves
#                </a>
#               </div>
#               <span class="timestamp">
#                2h
#               </span>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="ad-298">
#            <div class="ad-center">
#             <div class="ad-slot ad-slot-incontent-strip ad-wrapper" data-exclude-bp="s,m" data-slot-kvps="pos=incontentstrip" data-slot-type="incontentstrip">
#             </div>
#            </div>
#           </div>
#           <article class="ad-300">
#            <div class="ad-center">
# ...
# 			espn.scoreboard = {
# 				topics: {
# 					scoreboard: '',
# 					scoreboxes: []
# 				},
# 				models: {},
# 				views: {},
# 				collections: {},
# 				timezoneOffset: 0,
# 				favorites: {},
# 				editData: {},
# 				activeLeague: 'mlb',
# 				hiddenLeague: 'null',
# 				settings: {
# 					activeLeagues: [{"sportId":0,"displayName":"Top Events","league":"topEvents","sortOrder":0},{"sportId":41,"top25Only":true,"displayName":"NCAAM","league":"mens-college-basketball","sortOrder":2,"link":{"onclick":"","href":"http://www.espn.com/mens-college-basketball/scoreboard","title":"Full Scoreboard &#187;"},"sport":"basketball"},{"sportId":54,"top25Only":false,"displayName":"NCAAW","league":"womens-college-basketball","sortOrder":4,"link":{"onclick":"","href":"/womens-college-basketball/scoreboard","title":"Full Scoreboard &#187;"},"sport":"basketball"},{"sportId":46,"top25Only":true,"displayName":"NBA","league":"nba","sortOrder":6,"link":{"onclick":"","href":"https://www.espn.com/nba/scoreboard","title":"Full Scoreboard &#187;"},"sport":"basketball"},{"sportId":90,"top25Only":true,"displayName":"NHL","league":"nhl","sortOrder":18,"link":{"onclick":"","href":"https://www.espn.com/nhl/scoreboard","title":"Full Scoreboard &#187;"},"sport":"hockey"},{"sportId":775,"top25Only":true,"displayName":"UCL","league":"uefa.champions","sortOrder":32,"link":{"onclick":"","href":"http://www.espn.com/soccer/scoreboard","title":"Full Scoreboard &#187;"},"sport":"soccer"},{"sportId":851,"top25Only":true,"displayName":"Tennis (M)","league":"atp","sortOrder":34,"link":{"onclick":"","href":"http://www.espn.com/tennis/dailyResults","title":"Full Results &#187;"},"sport":"tennis"},{"sportId":23,"top25Only":false,"displayName":"NCAAF","league":"college-football","sortOrder":35,"link":{"onclick":"","href":"https://www.espn.com/college-football/scoreboard","title":"Full Scoreboard &#187;"},"sport":"football"},{"sportId":770,"top25Only":true,"displayName":"MLS","league":"usa.1","sortOrder":36,"link":{"onclick":"","href":"https://www.espn.com/soccer/scoreboard","title":"Full Scoreboard &#187;"},"sport":"soccer"},{"sportId":1106,"top25Only":true,"displayName":"Golf ","league":"pga","tournamentId":401243410,"sortOrder":37,"link":{"onclick":"","href":"https://www.espn.com/golf/leaderboard","title":"Full Leaderboard &#187;"},"sport":"golf"},{"sportId":700,"top25Only":true,"displayName":"Prem","league":"eng.1","sortOrder":37,"link":{"onclick":"","href":"https://www.espn.com/soccer/scoreboard","title":"Full Scoreboard &#187;"},"sport":"soccer"},{"sportId":720,"top25Only":true,"displayName":"German Bundesliga","league":"ger.1","sortOrder":37,"link":{"onclick":"","href":"https://www.espn.com/soccer/scoreboard","title":"Full Scoreboard &#187;"},"sport":"soccer"},{"sportId":1107,"top25Only":true,"displayName":"Golf (W)","league":"lpga","sortOrder":38,"link":{"onclick":"","href":"http://www.espn.com/golf/leaderboard?tour=lpga","title":"Full Leaderboard &#187;"},"sport":"golf"},{"sportId":730,"top25Only":true,"displayName":"Serie A","league":"ita.1","sortOrder":38,"link":{"onclick":"","href":"https://www.espn.com/soccer/scoreboard","title":"Full Scoreboard &#187;"},"sport":"soccer"},{"sportId":3321,"top25Only":true,"displayName":"UFC","league":"ufc","sortOrder":38,"link":{"onclick":"","href":"https://www.espn.com/mma/fightcenter","title":"Fightcenter &#187;"},"sport":"mma"},{"sportId":10,"top25Only":true,"displayName":"MLB","league":"mlb","sortOrder":39,"link":{"onclick":"","href":"https://www.espn.com/mlb/scoreboard","title":"Full Scoreboard &#187;"},"sport":"baseball"},{"sportId":2030,"top25Only":true,"displayName":"F1","league":"f1","sortOrder":39,"link":{"onclick":"","href":"https://www.espn.com/f1/schedule","title":"Full results &#187;"},"sport":"racing"},{"sportId":28,"top25Only":true,"displayName":"NFL","league":"nfl","sortOrder":40,"link":{"onclick":"","href":"https://www.espn.com/nfl/scoreboard","title":"Full Scoreboard &#187;"},"sport":"football"},{"sportId":2021,"top25Only":true,"displayName":"NASCAR","league":"nascar-premier","sortOrder":40,"link":{"onclick":"","href":"http://www.espn.com/racing/schedule","title":"Full results &#187;"},"sport":"racing"},{"sportId":59,"top25Only":true,"displayName":"WNBA","league":"wnba","sortOrder":41,"link":{" ...
# 					useStatic: false,
# 					version: 2,
# 					topEventsId: 4379198,
# 					topSoccerId: 15878776,
# 					nonScoreStatusIds: ["4","5","6","55"]
#
#
#
#
#
#
#
# 				},
# 				data: {"sports":[{"uid":"s:1","leagues":[{"uid":"s:1~l:10","smartdates":["2022-03-17T07:00Z","2022-03-18T07:00Z","2022-03-19T07:00Z"],"name":"Major League Baseball","id":"10","abbreviation":"MLB","shortName":"MLB","slug":"mlb","isTournament":false,"events":[{"date":"2022-03-17T17:05:00Z","commentaryAvailable":false,"timeValid":true,"link":"http://www.espn.com/mlb/game/_/gameId/401421799","playByPlayAvailable":false,"uid":"s:1~l:10~e:401421799~c:401421799","competitors":[{"alternateColor":"0d2b56","competitionIdPrevious":"401361972","color":"00224b","displayName":"Boston Red Sox","type":"team","abbreviation":"BOS","competitionIdNext":"401421800","uid":"s:1~l:10~t:2","homeAway":"home","score":"","logoDark":"https://a.espncdn.com/i/teamlogos/mlb/500-dark/scoreboard/bos.png","winner":false,"record":"0-0","name":"Red Sox","logo":"https://a.espncdn.com/i/teamlogos/mlb/500/scoreboard/bos.png","location":"Boston","id":"2","order":0,"group":"1"},{"alternateColor":"f1f2f3","competitionIdPrevious":"401229476","color":"012756","displayName":"Minnesota Twins","type":"team","abbreviation":"MIN","competitionIdNext":"401421781","uid":"s:1~l:10~t:9","homeAway":"away","score":"","logoDark":"https://a.espncdn.com/i/teamlogos/mlb/500-dark/scoreboard/min.png","winner":false,"record":"0-0","name":"Twins","logo":"https://a.espncdn.com/i/teamlogos/mlb/500/scoreboard/min.png","location":"Minnesota","id":"9","order":1,"group":"2"}],"wasSuspended":false,"appLinks":[{"isExternal":false,"shortText":"Summary","rel":["summary","sportscenter","app","event"],"language":"en-US","href":"sportscenter://x-callback-url/showGame?sportName=baseball&leagueAbbrev=mlb&gameId=401421799","text":"Gamecast","isPremium":false}],"seasonTypeHasGroups":false,"season":2022,"links":[{"isExternal":false,"rel":["summary","desktop","event"],"language":"en-US","href":"http://www.espn.com/mlb/game/_/gameId/401421799","text":"Gamecast","isPremium":false},{"isExternal":true,"rel":["tickets","desktop","event"],"language":"en-US","href":"https://www.vividseats.com/mlb-baseball/boston-red-sox-tickets/red-sox-3-17-3895189.html?wsUser=717","text":"Tickets","isPremium":false},{"isExternal":true,"rel":["tickets","desktop","venue"],"language":"en-US","href":"https://www.vividseats.com/jetblue-park-tickets/venue/9490?wsUser=717","text":"Tickets","isPremium":false}],"id":"401421799","recent":false,"group":{"groupId":"1","name":"Preseason","abbreviation":"pre","shortName":"PRE"},"summary":"3/17 - 1:05 PM EDT","seriesSummary":"Series starts 3/17","seasonType":"1","competitionId":"401421799","period":1,"gamecastAvailable":false,"clock":"0:00","seasonEndDate":"2022-04-07T06:59:00Z","onWatch":false,"seasonStartDate":"2022-01-27T08:00:00Z","name":"Minnesota Twins at Boston Red Sox","location":"JetBlue Park","airings":[{"withinPlayWindow":false,"program_eventId":"401421799","program_categories":[{"sportId":"baseball","artworkUrl":"https://artwork.api.espn.com/artwork/collections/categories/e364bfcd-493d-3bfb-ac83-bd27d66fedd0","name":"Baseball","id":"e364bfcd-493d-3bfb-ac83-bd27d66fedd0","type":"sport"},{"sportId":"mlb","artworkUrl":"https://artwork.api.espn.com/artwork/collections/categories/b38f959b-7865-31ac-8841-b88355519e10","name":"Major League Baseball","id":"b38f959b-7865-31ac-8841-b88355519e10","type":"league"}],"program_firstPresented":"2022-03-17T17:05:00.000+0000","program":"0d5c4d85-1eb6-4f93-8da4-07456e4010fa","createdOn":"2022-03-16T20:11:11.513+0000","network":"bam_dtc","appGameLink":"sportscenter://x-callback-url/showWatchStream?playGameID=401421799","policyUrl":"https://restrictions.api.espn.com/restrictions/policies/f280f8e4-7cac-4364-886c-2dc4d780722a","network_displayName":"ESPN+","end":"2022-03-18T00:05:00.000+0000","networkId":"8ea7f894-5556-4cdb-81c4-3f6216d85937","id":"8304a67f-2a68-4ffc-88ce-dae1a208366c","program_language":"English","webAiringLink":"https://www.espn.com/watch/player/_/id/8304a67f-2a68-4ffc-88ce-dae1a208366c","webGameLink":"https://www.espn.com/watch/playe ...
# 				queue: [],
# 				indexTopics: {"supportedPubKeys":{"espn-es-co-soccer-index":true,"espnin-en-soccer-index":true,"espn-es-ar-frontpage-index":true,"espn-es-cl-soccer-index":true,"espnin-en-cricket-index":true,"espnuk-en-rugby-index":true,"espnau-en-frontpage-index":true,"espnuk-en-tennis-index":true,"espn-es-cl-frontpage-index":true,"espnuk-en-frontpage-index":true,"espn-en-ncaa-index":true,"espnin-en-frontpage-index":true,"espn-en-tennis-index":true,"espn-es-ar-rpm-index":true,"espn-es-mx-soccer-index":true,"espn-en-womenbb-index":true,"espnuk-en-cricket-index":true,"espnin-en-tennis-index":true,"espn-es-ve-soccer-index":true,"espn-es-ar-soccer-index":true,"espn-es-us-frontpage-index":true,"espn-es-ar-tennis-index":true,"espn-es-co-frontpage-index":true,"espn-es-us-other-sports-index":true,"espn-es-us-soccer-index":true,"espnau-en-rugby-index":true,"espnza-en-frontpage-index":true,"espnuk-en-soccer-index":true,"espn-en-frontpage-index":true,"17784479":true,"espn-es-ve-frontpage-index":true,"espn-es-mx-frontpage-index":true,"espn-es-ar-rugby-index":true,"espnza-en-soccer-index":true,"espn-en-rpm-index":true,"espn-en-frontpage-grant-test-index":true}}
# 			};
#   </script>
#   <script type="text/javascript">
#    jQuery.subscribe('espn.defer.end', function () { espn.scoreboard.init(); });
#   </script>
#   <script>
#    (function() {
# 		function loadDefer() {
# 			var deferScripts = [
# 				'https://a.espncdn.com/redesign/0.585.0/js/espn-defer.js',
# 				'https://a.espncdn.com/redesign/0.585.0/js/espn-defer-low.js'
# 			];
#
# 			$.when(deferScripts.map(function (script) {
# 				var deferred = $.Deferred();
# 				$.getScriptCache(script, deferred.resolve);
# 				return deferred;
# 			})).done(function () {
# 				if(espn.siteType === 'data-lite' && typeof espn.ads.loadGPT === 'function') {
# 					espn.ads.loadGPT();
# 				}
# 			});
# 		}
#
# 		if(window.espn.loadType === "loadEnd" && espn_ui.deviceType !== 'desktop') {
# 			var race = [];
# 			$.when(function () {
# 				var deferred = $.Deferred();
# 				$(window).load(deferred.resolve);
# 				if(espn.siteType !== 'data-lite') {
# 					setTimeout( deferred.resolve, 5000 );
# 				}
# 				return deferred;
# 			}()).then(loadDefer)
#
# 		}else{
# 			loadDefer();
# 		}
#
# 	})();
#   </script>
#   <script>
#    espn_ui.Helpers.translate.init();
#   </script>
#   <script type="text/javascript">
#    var data = {"omniture":{"columnist":"espn","league":"mlb","prop61":["New York Mets","Max Scherzer","Los Angeles Dodgers","MLB"],"countryRegion":"en-us","hier1":"mlb:story","section":"mlb","source":"espn","pageName":"mlb:story","storyInfo":"32745735+sources+new+york+mets+max+scherzer+agree+to+three-year+130+million+contract","sections":"mlb:story","site":"espn","premium":"premium-no","convrSport":"baseball","pageURL":"www.espn.com/mlb/story/_/id/32745735/sources-new-york-mets-max-scherzer-finalizing-3-year-deal","lang":"en_us","prop35":"2021-11-29","contentType":"story","sport":"baseball","account":"wdgespcom","siteType":"full","prop58":"isIndex=false"},"chartbeat":{"loadPubJS":false,"path":"/mlb/story/_/id/32745735/sources-new-york-mets-max-scherzer-finalizing-3-year-deal","zone":"www.espn.com.us.mlb","domain":"www.espn.com","loadVidJS":true,"title":"Sources - New York Mets, Max Scherzer agree to three-year, $130 million contract","sections":"mlb","authors":"story"},"qualtrics":false,"nielsen":{"espnuk":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"espnau":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"espn":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"fantasy":{"apid":"P302B69D5-F1DD-4E7A-BF8D-3E60F0EB5E5A","vc":"c07"},"espndeportes":{"apid":"P890E2723-EDBC-4CCE-96BA-F35EA3E50650","vc":"c02"},"espnfc":{"apid":"PE6995AAE-0C49-4372-B5E7-54C61BFE2AA5","vc":"c03"},"espnww":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"general":{"ci":"us-600140","assetid":"N/A","segB":"N/A","sfcode":"dcr","segA":"N/A","section":"N/A","segC":"N/A","apn":"espnCOM"},"espnza":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"espnin":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"watchespn":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"cricinfo":{"apid":"PED8CDAC2-F114-41BE-8B98-AFA06FAEA06E","vc":"c04"},"espnbr":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"}},"ABTest":{"environment":"prod","tScript":"https://a.espncdn.com/prod/scripts/analytics/ESPN_at_v2.rs.min.js","abtestUser":0,"oScript":"https://cdn.optimizely.com/js/310987714.js","targetURLs":[{"regexp":"(/)","site":"espn.co.uk","flag":true},{"regexp":"(/.*)","site":"www.espn.com","flag":true}],"domain":"www.espn.com","host":"espn.com","raw":"{\"fastcast\":{\"placements\":{\"/nba/index\":\"true\",\"^/.+$\":\"false\",\"/ncf/index\":\"true\"},\"enabled\":false,\"script\":\"https://a.espncdn.com/combiner/c?js=analytics/espn.fastcastTracking.4.js\"},\"optimizely\":{\"oldscript\":\"https://a.espncdn.com/sports/optimizely.js\",\"placements\":[],\"enabled\":false,\"script\":\"https://cdn.optimizely.com/js/310987714.js\"},\"target\":{\"placements\":[{\"regexp\":\"(/)\",\"site\":\"espn.co.uk\",\"flag\":true},{\"regexp\":\"(/.*)\",\"site\":\"www.espn.com\",\"flag\":true}],\"enabled\":true,\"script\":\"https://a.espncdn.com/prod/scripts/analytics/ESPN_at_v2.rs.min.js\"}}","optimizely":false,"isTargeted":true,"target":true,"optimizelyURLs":[]},"metrics":{"page_url":"https://www.espn.com/mlb/story/_/id/32745735/sources-new-york-mets-max-scherzer-finalizing-3-year-deal","contentCategories":["New York Mets","Max Scherzer","Los Angeles Dodgers","MLB"],"premium":false,"content_type":"story","page_infrastructure":"sCore","story_title":"sources: new york mets, max scherzer agree to three-year, $130 million contract","author":"ESPN","story_id":32745735,"league":"no league","section":"mlb","sport":"mlb"},"isFeaturePhone":false,"device":"desktop","cto":true};
# 				var espn = espn || {};
# 				espn.track = espn.track || {};
# 				espn.track.data = data;
#   </script>
#   <!-- SiteCatalyst code version: AppMeasurement 1.0 Copyright 1996-2013 Adobe, Inc. -->
#   <script type="text/javascript">
#    if (typeof s_omni === 'undefined') {
# 		jQuery(function($){
# 			$.getScriptCache("https://a.espncdn.com/redesign/0.585.0/js/espn-analytics.js", 				function() {					var deferEvent = "user.parsed",						initOnLoad = null || false,						timeoutID;
# 					function initTrack(){						if (typeof espn.track.init === 'function') {							window.clearTimeout(timeoutID);
# 							$.unsubscribe([deferEvent, initTrack]);
# 							espn.track.init(data);						}					}
# 					if(initOnLoad || window.espn_ui.userParsed){						initTrack();					}					else {						$.subscribe(deferEvent, initTrack);                        timeoutID = window.setTimeout(initTrack, 5000);					}				}				);
# 		});
# 	}
#   </script>
#   <!-- End SiteCatalyst code version: AppMeasurement 1.0 -->
#   <script>
#    var espn = espn || {};
#            espn.ads = espn.ads || {};
#            espn.shellParams = espn.shellParams || {};
#            espn.shellParams.excludeTVEProviders = false
#
#                 $.subscribe("espn.defer.ready", function() {
#                     espn_ui.Helpers.watchProviders.initWatchAuth();
#                 });
#   </script>
#   <div class="promo-banner-container" data-behavior="banner_mgmt">
#   </div>
#   <script>
#    window.espn = window.espn || {};
#             window.espn.banner = {
#                 active : true,
#                 activeEnv : true,
#                 pageTypes : ["frontpage"],
#                 region: "ccpa"
#             };
#   </script>
#  </body>
# </html>

# %%
soup_Scherzer.find('title')
# Out:
# <title>Sources - New York Mets, Max Scherzer agree to three-year, $130 million contract</title>

# %%
#collapse-output
for i in soup_Scherzer.find_all('p'):
    print(i.text)
# Out:
# Star right-hander Max Scherzer and the New York Mets have agreed to a three-year, $130 million contract, sources familiar with the situation told ESPN's Jeff Passan.
# Scherzer can opt out of the contract after the second season of the deal, the sources said.
# The $43.33 million average annual salary of the deal sets a record, surpassing the $36 million New York Yankees pitcher Gerrit Cole is averaging after signing a nine-year, $324 million contract in 2019.
# Scherzer, 37, becomes the oldest player in MLB history to sign a $100 million contract, according to ESPN Stats & Information. Kevin Brown was 33 when he signed the first $100 million deal in MLB history in 1998.
# The Mets have gone on a spending spree over the weekend, signing center fielder Starling Marte, infielder Eduardo Escobar and outfielder Mark Canha to deals worth a combined $124.5 million.
# And after seeing starters Noah Syndergaard and Steven Matz sign with other clubs in the past two weeks, new owner Steve Cohen wasn't going to be denied one of the best pitchers available in Scherzer.
# Scherzer joins a Mets rotation fronted by two-time National League Cy Young Award winner Jacob deGrom, who didn't pitch after July 7 last season because of concerns with his elbow -- although a late-season MRI showed that his elbow was healthy.
# Scherzer, a three-time Cy Young Award winner, was among the preeminent pitchers of the 2010s -- along with Justin Verlander and Clayton Kershaw -- and has rolled his dominance into the 2020s.
# In 2021, during his age-36 season, Scherzer went 15-4 with a 2.46 ERA in 179⅓ innings for the Washington Nationals and the Los Angeles Dodgers, striking out 236 batters and walking only 36. He ultimately finished third in NL Cy Young Award voting, marking the eighth time in the past nine years he has finished within the top five.
# During that stretch, which dates back to 2013, Scherzer has posted a 2.82 ERA while averaging 15 wins and 192 innings per season (even though the 2020 season was shortened to 60 games because of the coronavirus pandemic). His 51.2 FanGraphs WAR since then leads all pitchers.
# Scherzer was originally the 11th overall pick in the 2006 draft by the Arizona Diamondbacks, who flipped him to the Detroit Tigers three years later in a major three-team trade that saw Curtis Granderson, Edwin Jackson and Ian Kennedy, among others, switch teams.
# In Detroit, Scherzer formed a devastating duo with Verlander on perennial playoff teams that often fell just short of a championship. He joined the Nationals on a seven-year, $210 million free-agent deal in January of 2015 and somehow outperformed his contract over the course of six-plus seasons, a highly impressive run that culminated in winning the 2019 World Series.
# The Dodgers acquired Scherzer alongside middle infielder Trea Turner in late July 2020 in exchange for their two best remaining prospects, catcher Keibert Ruiz and pitcher Josiah Gray. Scherzer dominated initially, with a 0.78 ERA through his first nine starts, but his arm was slow to recover from being used in the ninth inning of Game 5 of the National League Division Series against the San Francisco Giants.
# Scherzer languished through Game 2 of the National League Championship Series against the Atlanta Braves, later saying his arm was still tired from his relief appearance three days earlier. He was initially scheduled to start again in Game 6 but was pushed back to Game 7 because of lingering soreness -- then watched the Dodgers get eliminated in Game 6, abruptly ending another dominant Scherzer season.
# Scherzer is 190-97 with a 3.16 ERA in 14 major league seasons. He has 3,020 strikeouts, which ranks 18th on the all-time list.
# The addition of Scherzer moved the Mets' odds at Caesars Sportsbook to win the 2022 World Series to 14-1, tied for the sixth-shortest odds to win the championship.
# ESPN's Alden Gonzalez contributed to this report.

# %% [markdown]
# In 2021, the scatter plot of spin rate and speed group by ```fastball``` and ```slider```

# %%
RW = pd.read_csv('MLB_data/2021-Pitchers-overall-final.csv')
RW.insert(2, 'name', RW['first_name'] +'_'+ RW.last_name)
color1=plt.cm.tab10(5.4)
ax=RW.plot(kind='scatter', x='ff_avg_spin', y='ff_avg_speed',c=np.array(color1).reshape(1,-1),s=10)
ax.text(2550,98.5,'Max Scherzer',fontsize=16,color='BLue')
ax.arrow(2436, 94.3, 100, 4, width = 0.5)
ax.text(2340,88,'Garrett Richards',fontsize=16,color='Green')
ax.arrow(2468, 94.3, -50, -5, width = 0.5, color= 'Green')
ax.set_xlabel('Fast ball spin rate',fontsize=16)
ax.set_ylabel('Fast ball speed',fontsize=16)
# Out:
# Text(0, 0.5, 'Fast ball speed')

# %%
color1=plt.cm.tab10(5.4)
ax2=RW.plot(kind='scatter', x='sl_avg_spin', y='sl_avg_speed',c=np.array(color1).reshape(1,-1),s=10)
ax2.text(1900,90,'Max Scherzer',fontsize=16,color='BLue')
ax2.arrow(2274, 85.9, -200, 4, width = 0.5)
ax2.text(2800,90,'Garrett Richards',fontsize=16,color='Green')
ax2.arrow(2745, 88.1, 100, 1, width = 0.3, color= 'Green')
ax2.set_xlabel('Slider ball spin rate',fontsize=16)
ax2.set_ylabel('Slider ball speed',fontsize=16)
# Out:
# Text(0, 0.5, 'Slider ball speed')

# %%
color1=plt.cm.tab10(6)
ax3=RW.plot(kind='scatter', x='ff_avg_spin', y='p_era',c=np.array(color1).reshape(1,-1),s=10)
ax3.text(2200,-0.5,'Max Scherzer',fontsize=16,color='BLue')
ax3.arrow(2436, 2.46, -200, -2, width = 0.5)
ax3.text(2700,7,'Garrett Richards',fontsize=16,color='Green')
ax3.arrow(2468, 4.87, 200, 1.5, width = 0.3, color= 'Green')
ax3.set_xlabel('Fast ball spin rate',fontsize=16)
ax3.set_ylabel('ERA',fontsize=16)
# Out:
# Text(0, 0.5, 'ERA')

# %%
color1=plt.cm.tab10(6)
ax4=RW.plot(kind='scatter', x='sl_avg_spin', y='p_era',c=np.array(color1).reshape(1,-1),s=10)
ax4.text(2000,-0.5,'Max Scherzer',fontsize=16,color='BLue')
ax4.arrow(2273, 2.46, -200, -2, width = 0.5)
ax4.text(2745,7,'Garrett Richards',fontsize=16,color='Green')
ax4.arrow(2745, 4.87, 200, 1.5, width = 0.3, color= 'Green')
ax4.set_xlabel('Slider ball spin rate',fontsize=16)
ax4.set_ylabel('ERA',fontsize=16)
# Out:
# Text(0, 0.5, 'ERA')
